# %% [markdown]
# ## How to run workflow with validation?

# %% [markdown]
# Here, our FLOW will utilize the overall task you have provided to automatically generate the subtasks and agents within the workflow. When providing an overall task, please endeavor to articulate your requirements with clarity, including the desired output format and the specific content you expect. The more detailed your description, the more refined and accurate the results will be.

# %% [markdown]
# ### Requirement
# You need to have an OpenAI API Key.
# Notice that our default model is gpt4omini, please feel free to replace it with the model you wish to use in the config.py file.

# %%
import os
import sys

# Add the parent folder to the path
sys.path.append(os.path.abspath(".."))


os.environ["OPENAI_API_KEY"] = "Your API Key"

# %% [markdown]
# ### Import necessary module

# %%
import asyncio
import nest_asyncio
import json
from flow import Flow
from summary import Summary

# %% [markdown]
# ### Set your overall task

# %% [markdown]
# As you can observe, we have furnished an example herein for generating a website that contains context of ICLR 2025. Within this overall task, we have delineated the requisite output format along with the specific content details. At the very bottom of this notebook, you are able to witness the outcome of the execution.

# %%
overall_task: str = '''Create a Tetris game using Python with the pygame library. 
The game should feature a standard 10x20 grid for gameplay. 
Display the current falling tetromino and the next upcoming piece. 
Include a score counter, a display for the number of cleared lines, and a simple border to distinguish the game area. 
Each tetromino type should have a unique, vibrant color for clear visibility. 
The interface should be clean and modern, emphasizing gameplay clarity and user experience.'''

# %% [markdown]
# ### Run your workflow

# %%
manager = Flow(overall_task = overall_task, refine_threhold = 3, max_refine_itt=5, n_candidate_graphs=10, workflow=None, max_validation_itt=4)
nest_asyncio.apply()
asyncio.run(manager.run_async())
# Out:
# 2025-03-17 22:49:38 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-17 22:49:38 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall game architecture, outlining modules for game mechanics, UI rendering, scoring, and user input handling."
#     },
#     {
#       "id": 1,
#       "objective": "Develop the core game mechanics including the 10x20 grid, tetromino representation, movement, collision detection, rotation logic, and management of the falling tetromino along with the next piece preview."
#     },
#     {
#       "id": 2,
#       "objective": "Implement the scoring system and line clearing functionality, ensuring the score counter and cleared lines display update accurately throughout gameplay."
#     },
#     {
#       "id": 3,
#       "objective": "Create the user interface using pygame, rendering a clean and modern display that features a simple border for the game area, unique vibrant colors for each tetromino, and clear visibility for game elements like the current tetromino, next piece preview, score, and cleared lines."
#     },
#     {
#       "id": 4,
#       "objective": "Integrate the game mechanics with the UI, tying together the gameplay loop, rendering updates, and user input to form a cohesive Tetris game experience."
#     },
#     {
#       "id": 5,
#       "objective": "Perform final refinements and code cleanup focused on enhancing user experience, optimizing performance, and ensuring the game interface is responsive and modern."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 3 },
#     { "parent": 1, "child": 4 },
#     { "parent": 2, "child": 4 },
#     { "parent": 3, "child": 4 },
#     { "parent": 4, "child": 5 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "System Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Game Mechanics Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Game Logic and Scoring Engineer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "UI/Pygame Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Integration Specialist",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "UX Refinement Engineer",
#       "subtasks": [5]
#     }
#   ]
# }
# 2025-03-17 22:49:40 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-17 22:49:40 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library.",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Define the game requirements and design the project structure, including module separation for game logic, tetromino definitions, UI rendering, and game loop control."
#     },
#     {
#       "id": 1,
#       "objective": "Develop the core Tetris game logic, including grid management (10x20 standard grid), collision detection, piece placement, line clearing, and score tracking."
#     },
#     {
#       "id": 2,
#       "objective": "Implement tetromino classes with unique, vibrant colors. Include functionality for generating the current falling piece and the upcoming piece preview."
#     },
#     {
#       "id": 3,
#       "objective": "Create the game interface using pygame. Render the gameplay area with a clear border, display the current tetromino in motion, preview the next tetromino, and show score and cleared line counters."
#     },
#     {
#       "id": 4,
#       "objective": "Integrate the game logic with the UI and incorporate user input handling to control tetromino movements. Finalize the game loop ensuring seamless interaction between game state updates and rendering."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 0, "child": 3 },
#     { "parent": 1, "child": 4 },
#     { "parent": 2, "child": 4 },
#     { "parent": 3, "child": 4 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "Project Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Game Logic Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Tetromino Specialist",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "UI Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Integration Specialist",
#       "subtasks": [4]
#     }
#   ]
# }
# 2025-03-17 22:49:42 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-17 22:49:42 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library featuring a standard 10x20 gameplay grid, current and next tetromino displays, a score counter, cleared lines count, a game area border, and uniquely colored tetrominoes.",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall architecture and game flow, defining modules for the game engine, tetromino representations, and the user interface."
#     },
#     {
#       "id": 1,
#       "objective": "Develop the core game engine handling the grid mechanics, falling tetromino behavior, collision detection, line clearing, and score tracking."
#     },
#     {
#       "id": 2,
#       "objective": "Implement tetromino logic by designing data structures for each tetromino type with unique, vibrant colors and setting up the generation of the current piece and the next upcoming piece."
#     },
#     {
#       "id": 3,
#       "objective": "Create the graphical user interface using pygame to render the 10x20 grid, border, score counter, cleared lines display, and the visual representation of the current and next tetrominoes."
#     },
#     {
#       "id": 4,
#       "objective": "Integrate the core game engine, tetromino module, and user interface to form a cohesive game. Polish interactions between components to ensure smooth gameplay and consistent UI behavior."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 0, "child": 3 },
#     { "parent": 1, "child": 4 },
#     { "parent": 2, "child": 4 },
#     { "parent": 3, "child": 4 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "System Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Game Engine Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Gameplay Mechanics Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "UI/Graphics Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Integration Specialist",
#       "subtasks": [4]
#     }
#   ]
# }
# 2025-03-17 22:49:43 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-17 22:49:43 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library.",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall system architecture for the Tetris game, outlining modules for game mechanics, tetromino representation, user interface, and integration strategy."
#     },
#     {
#       "id": 1,
#       "objective": "Develop the core game mechanics including the 10x20 grid, tetromino movement, collision detection, and line-clearing logic."
#     },
#     {
#       "id": 2,
#       "objective": "Implement tetromino modules: define each tetromino shape with unique, vibrant colors and add functionality for generating the next upcoming piece."
#     },
#     {
#       "id": 3,
#       "objective": "Build the user interface using pygame: render the game grid with a clear modern look, include a simple border, score counter, and cleared lines display."
#     },
#     {
#       "id": 4,
#       "objective": "Integrate game mechanics with the UI by combining the modules into a cohesive game loop that handles user input, updates game state, and renders visuals smoothly."
#     },
#     {
#       "id": 5,
#       "objective": "Polish and optimize the integrated game by refining user experience, debugging issues, and enhancing performance for reliable gameplay."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 0, "child": 3 },
#     { "parent": 1, "child": 4 },
#     { "parent": 2, "child": 4 },
#     { "parent": 3, "child": 4 },
#     { "parent": 4, "child": 5 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "System Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Game Mechanics Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Tetromino Module Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "UI Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Integration Specialist",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "Quality & Polishing Engineer",
#       "subtasks": [5]
#     }
#   ]
# }
# 2025-03-17 22:49:44 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-17 22:49:44 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall game architecture and module interaction plan, outlining the responsibilities for the grid system, tetromino logic, UI, and input handling."
#     },
#     {
#       "id": 1,
#       "objective": "Develop the game board module that implements the standard 10x20 grid, including collision detection and management of placed tetrominoes."
#     },
#     {
#       "id": 2,
#       "objective": "Implement the tetromino module by defining all tetromino shapes, rotation logic, unique vibrant colors for each type, and a mechanism to generate both the current falling piece and the upcoming piece."
#     },
#     {
#       "id": 3,
#       "objective": "Create the user interface module using pygame to render the game board, display the falling tetromino, the next upcoming piece, the score counter, cleared lines, and a simple border with a clean, modern look."
#     },
#     {
#       "id": 4,
#       "objective": "Implement the input handling and main game loop to process keyboard events, control tetromino movements, update game state, and drive real-time gameplay."
#     },
#     {
#       "id": 5,
#       "objective": "Integrate the game board, tetromino, UI, and input handling modules to form a cohesive Tetris game, ensuring smooth interactions and consistent behavior across the system."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 0, "child": 3 },
#     { "parent": 0, "child": 4 },
#     { "parent": 1, "child": 5 },
#     { "parent": 2, "child": 5 },
#     { "parent": 3, "child": 5 },
#     { "parent": 4, "child": 5 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "System Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Game Board Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Tetromino Logic Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "UI Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Input & Game Loop Developer",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "Integration Specialist",
#       "subtasks": [5]
#     }
#   ]
# }
# 2025-03-17 22:49:44 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-17 22:49:44 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall system architecture, outlining modules for the game loop, board management, tetromino mechanics, UI elements (score, lines cleared, border), and integration strategy."
#     },
#     {
#       "id": 1,
#       "objective": "Set up the pygame window and implement the main game loop with event handling to drive gameplay."
#     },
#     {
#       "id": 2,
#       "objective": "Develop the game board and grid management module to represent a standard 10x20 grid, including rendering a simple border to delineate the game area."
#     },
#     {
#       "id": 3,
#       "objective": "Implement tetromino logic including piece shapes, rotations, falling mechanics, collision detection, and assign each tetromino a unique, vibrant color."
#     },
#     {
#       "id": 4,
#       "objective": "Create the next tetromino preview feature to display the upcoming piece alongside the current falling tetromino."
#     },
#     {
#       "id": 5,
#       "objective": "Develop the scoring and line-clearing module to update the score counter and display the number of cleared lines as gameplay progresses."
#     },
#     {
#       "id": 6,
#       "objective": "Integrate the game loop, board, tetromino mechanics, preview, and scoring modules to ensure smooth interaction and overall gameplay consistency."
#     },
#     {
#       "id": 7,
#       "objective": "Polish the user interface by refining visuals and ensuring a clean, modern design that emphasizes gameplay clarity and an enhanced user experience."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 0, "child": 3 },
#     { "parent": 3, "child": 4 },
#     { "parent": 2, "child": 5 },
#     { "parent": 3, "child": 5 },
#     { "parent": 1, "child": 6 },
#     { "parent": 2, "child": 6 },
#     { "parent": 3, "child": 6 },
#     { "parent": 4, "child": 6 },
#     { "parent": 5, "child": 6 },
#     { "parent": 6, "child": 7 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "System Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Game Loop Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Board & Grid Manager",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "Tetromino Mechanics Engineer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Preview Feature Developer",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "Score & Line-Clear Specialist",
#       "subtasks": [5]
#     },
#     {
#       "id": "Agent 6",
#       "role": "Integration Specialist",
#       "subtasks": [6]
#     },
#     {
#       "id": "Agent 7",
#       "role": "UI/UX Designer",
#       "subtasks": [7]
#     }
#   ]
# }
# 2025-03-17 22:49:44 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-17 22:49:44 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library featuring a 10x20 gameplay grid, real-time falling tetrominoes with a next-piece preview, score and cleared lines counters, a distinct game border, and a clean, modern user interface.",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall system architecture and game flow, outlining modules for display management, tetromino handling, game mechanics, and UI components."
#     },
#     {
#       "id": 1,
#       "objective": "Set up the pygame window with a 10x20 grid and a simple border to delineate the game area."
#     },
#     {
#       "id": 2,
#       "objective": "Implement tetromino definitions including shape configurations, unique vibrant colors, and rotation logic."
#     },
#     {
#       "id": 3,
#       "objective": "Develop core gameplay mechanics, including falling tetromino movement, collision detection, locking pieces, and line clearing functionality."
#     },
#     {
#       "id": 4,
#       "objective": "Create the next-piece preview module that displays the upcoming tetromino using the defined tetromino specifications."
#     },
#     {
#       "id": 5,
#       "objective": "Implement the scoring system and cleared lines counter that updates based on gameplay events."
#     },
#     {
#       "id": 6,
#       "objective": "Design and integrate a clean, modern user interface that unifies the game grid, score counter, lines cleared, and next-piece display for enhanced gameplay clarity."
#     },
#     {
#       "id": 7,
#       "objective": "Integrate all modules, ensuring seamless interaction between gameplay mechanics, UI elements, and game flow for a smooth user experience."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 2, "child": 3 },
#     { "parent": 2, "child": 4 },
#     { "parent": 3, "child": 5 },
#     { "parent": 1, "child": 6 },
#     { "parent": 4, "child": 6 },
#     { "parent": 5, "child": 6 },
#     { "parent": 3, "child": 7 },
#     { "parent": 4, "child": 7 },
#     { "parent": 5, "child": 7 },
#     { "parent": 6, "child": 7 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "System Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Pygame Window Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Tetromino Module Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "Gameplay Mechanics Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Next-Piece Display Specialist",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "Score and Lines Counter Developer",
#       "subtasks": [5]
#     },
#     {
#       "id": "Agent 6",
#       "role": "User Interface Integrator",
#       "subtasks": [6]
#     },
#     {
#       "id": "Agent 7",
#       "role": "Integration Specialist",
#       "subtasks": [7]
#     }
#   ]
# }
# 2025-03-17 22:49:46 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-17 22:49:46 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall architecture for the Tetris game, outlining major components (game board, tetromino objects, game mechanics, UI elements) and their interactions."
#     },
#     {
#       "id": 1,
#       "objective": "Set up the Python environment, initialize pygame, and configure the main display window and clock."
#     },
#     {
#       "id": 2,
#       "objective": "Develop the 10x20 game board representation and implement drawing functions to render the grid with a clear border."
#     },
#     {
#       "id": 3,
#       "objective": "Create tetromino classes for each shape including properties for rotation, position, and unique vibrant colors. Also, implement functionality for selecting the current falling tetromino and the next upcoming piece."
#     },
#     {
#       "id": 4,
#       "objective": "Implement core game mechanics including tetromino movement, collision detection against board boundaries and placed pieces, and line clearing logic."
#     },
#     {
#       "id": 5,
#       "objective": "Design and build the UI components such as the score counter, cleared lines display, and the preview area for the next tetromino, ensuring a clean, modern interface."
#     },
#     {
#       "id": 6,
#       "objective": "Integrate the event loop and game state management to handle user inputs, update game mechanics, and coordinate rendering in real time."
#     },
#     {
#       "id": 7,
#       "objective": "Perform final integration and code refinement, ensuring smooth interaction between modules and that the game meets all gameplay clarity and user experience requirements."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 0, "child": 3 },
#     { "parent": 2, "child": 4 },
#     { "parent": 3, "child": 4 },
#     { "parent": 0, "child": 5 },
#     { "parent": 4, "child": 6 },
#     { "parent": 1, "child": 6 },
#     { "parent": 5, "child": 6 },
#     { "parent": 6, "child": 7 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "System Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Environment Specialist",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Graphics Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "Game Logic Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Mechanics Engineer",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "UI/UX Designer",
#       "subtasks": [5]
#     },
#     {
#       "id": "Agent 6",
#       "role": "Integration Specialist",
#       "subtasks": [6]
#     },
#     {
#       "id": "Agent 7",
#       "role": "Code Refinement Engineer",
#       "subtasks": [7]
#     }
#   ]
# }
# 2025-03-17 22:49:46 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-17 22:49:46 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall software architecture and module breakdown for the Tetris game, outlining core components such as the grid, tetromino definitions, game mechanics, UI, and event handling."
#     },
#     {
#       "id": 1,
#       "objective": "Develop the board module that sets up a standard 10x20 grid along with a simple border to distinguish the game area."
#     },
#     {
#       "id": 2,
#       "objective": "Create the tetromino module, defining all tetromino shapes with their unique, vibrant colors and implementing functionality for generating the current and next pieces."
#     },
#     {
#       "id": 3,
#       "objective": "Implement the game mechanics module to manage falling tetrominoes, collision detection, locking pieces into the grid, clearing filled lines, and updating the score and cleared lines counter. (Depends on the grid and tetromino modules)"
#     },
#     {
#       "id": 4,
#       "objective": "Develop the display and UI module that renders the game board, falling tetromino, upcoming piece, score counter, and cleared lines, ensuring the interface remains clean and modern."
#     },
#     {
#       "id": 5,
#       "objective": "Implement the event handling and game loop module to process user inputs, manage game timing, and orchestrate the interaction between game mechanics and the display."
#     },
#     {
#       "id": 6,
#       "objective": "Integrate all modules (board, tetromino, mechanics, UI, and event handling) and perform final adjustments to ensure smooth and cohesive gameplay."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 1, "child": 3 },
#     { "parent": 2, "child": 3 },
#     { "parent": 3, "child": 4 },
#     { "parent": 3, "child": 5 },
#     { "parent": 4, "child": 6 },
#     { "parent": 5, "child": 6 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "System Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Grid/Board Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Tetromino & Color Specialist",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "Game Mechanics Engineer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "UI and Display Developer",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "Event Handling and Game Loop Developer",
#       "subtasks": [5]
#     },
#     {
#       "id": "Agent 6",
#       "role": "Integration Specialist",
#       "subtasks": [6]
#     }
#   ]
# }
# 2025-03-17 22:49:48 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-17 22:49:48 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library. The game must use a standard 10x20 grid, display the current falling tetromino with a preview of the next piece, show a score counter and a cleared lines display, and include a simple border to define the game area. Each tetromino should sport a distinct, vibrant color, and the user interface must be clean and modern to enhance gameplay clarity and user experience.",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Develop a game architecture and design plan that outlines the overall structure, data models (grid and tetromino representations with unique colors), and game flow."
#     },
#     {
#       "id": 1,
#       "objective": "Implement the core gameplay mechanics by coding the 10x20 game grid, defining tetromino data structures with vibrant colors, and developing falling mechanics, collision detection, and line clearing logic."
#     },
#     {
#       "id": 2,
#       "objective": "Design and build the user interface using pygame, including rendering the game grid, current falling tetromino, next piece preview, game area border, score counter, and cleared lines display with a clean and modern look."
#     },
#     {
#       "id": 3,
#       "objective": "Develop the input handling system to capture and process user interactions (movement, rotation, faster drop) and integrate these controls with the game mechanics."
#     },
#     {
#       "id": 4,
#       "objective": "Integrate all components into a main game loop, ensuring smooth and cohesive interaction between game logic, rendering, and user inputs."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 0, "child": 3 },
#     { "parent": 1, "child": 4 },
#     { "parent": 2, "child": 4 },
#     { "parent": 3, "child": 4 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "Game Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Core Mechanics Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "UI Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "Input Specialist",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Integration Specialist",
#       "subtasks": [4]
#     }
#   ]
# }
# 2025-03-17 22:49:48 [INFO] Executing task 'Design the overall system architecture, outlining modules for the game loop, board management, tetromino mechanics, UI elements (score, lines cleared, border), and integration strategy.' with context: No completed previous tasks context available....
# 2025-03-17 22:49:48 [INFO] Task 'Design the overall system architecture, outlining modules for the game loop, board management, tetromino mechanics, UI elements (score, lines cleared, border), and integration strategy.' started by agent '0'.
# Comparing...
#  Here is the detailed data.
# Dependency complexities:
# [1.0, 0.4898979485566356, 0.4898979485566356, 0.9428090415820634, 0.9428090415820634, 1.4142135623730951, 0.7071067811865476, 1.0, 0.6998542122237652, 0.4898979485566356]
# Parallelisms:
# [2.5, 2.3333333333333335, 2.3333333333333335, 2.5, 3.0, 3.8, 2.5, 3.0, 2.6, 2.3333333333333335]
# ***********run start*********************
#
#
# "# **Instructions:**
# "
# "1. Solve only your assigned subtask, referring to the context only if necessary.
# "
# "2. Ensure your solution aligns with the overall goal and is formatted so that it can be directly used as input for downstream tasks.
# "
# "3. Do not repeat any previous output verbatim.
# "
# "4. Output required result without adding any justifications."
# "5. Strictly follow the format constraint."
# ---
#
# # **The Overall Goal**
# Create a Tetris game using Python with the pygame library. The game should feature a standard 10x20 grid for gameplay. Display the current falling tetromino and the next upcoming piece. Include a score counter, a display for the number of cleared lines, and a simple border to distinguish the game area. Each tetromino type should have a unique, vibrant color for clear visibility. The interface should be clean and modern, emphasizing gameplay clarity and user experience.
#
# ---
#
# # **Context from Upstream Tasks**
# No completed previous tasks context available.
#
# ---
#
# # **Downstream Tasks objectivesv**
# Task task1:
#   Objective: Set up the pygame window and implement the main game loop with event handling to drive gameplay.
# Task task2:
#   Objective: Develop the game board and grid management module to represent a standard 10x20 grid, including rendering a simple border to delineate the game area.
# Task task3:
#   Objective: Implement tetromino logic including piece shapes, rotations, falling mechanics, collision detection, and assign each tetromino a unique, vibrant color.
#
#
# ---
#
# # **Current Task Requirements**
# Design the overall system architecture, outlining modules for the game loop, board management, tetromino mechanics, UI elements (score, lines cleared, border), and integration strategy.
#
# ---
#
#
# ***********run end*********************
# 2025-03-17 22:49:54 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ------Run pythonValidator.is_python_code()------
# 2025-03-17 22:49:57 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-17 22:50:03 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-17 22:50:03 [INFO] Task task0 done. Total completed so far: 1
# 2025-03-17 22:50:03 [INFO] Executing task 'Set up the pygame window and implement the main game loop with event handling to drive gameplay.' with context: Task task0:
#   Objective: Design the overall system architecture, outlining modules for the game loop...
# 2025-03-17 22:50:03 [INFO] Task 'Set up the pygame window and implement the main game loop with event handling to drive gameplay.' started by agent '1'.
# 2025-03-17 22:50:03 [INFO] Executing task 'Develop the game board and grid management module to represent a standard 10x20 grid, including rendering a simple border to delineate the game area.' with context: Task task0:
#   Objective: Design the overall system architecture, outlining modules for the game loop...
# 2025-03-17 22:50:03 [INFO] Task 'Develop the game board and grid management module to represent a standard 10x20 grid, including rendering a simple border to delineate the game area.' started by agent '2'.
# 2025-03-17 22:50:03 [INFO] Executing task 'Implement tetromino logic including piece shapes, rotations, falling mechanics, collision detection, and assign each tetromino a unique, vibrant color.' with context: Task task0:
#   Objective: Design the overall system architecture, outlining modules for the game loop...
# 2025-03-17 22:50:03 [INFO] Task 'Implement tetromino logic including piece shapes, rotations, falling mechanics, collision detection, and assign each tetromino a unique, vibrant color.' started by agent '3'.
# task0 ---Final status: completed
# 1 3
# ***********run start*********************
#
#
# "# **Instructions:**
# "
# "1. Solve only your assigned subtask, referring to the context only if necessary.
# "
# "2. Ensure your solution aligns with the overall goal and is formatted so that it can be directly used as input for downstream tasks.
# "
# "3. Do not repeat any previous output verbatim.
# "
# "4. Output required result without adding any justifications."
# "5. Strictly follow the format constraint."
# ---
#
# # **The Overall Goal**
# Create a Tetris game using Python with the pygame library. The game should feature a standard 10x20 grid for gameplay. Display the current falling tetromino and the next upcoming piece. Include a score counter, a display for the number of cleared lines, and a simple border to distinguish the game area. Each tetromino type should have a unique, vibrant color for clear visibility. The interface should be clean and modern, emphasizing gameplay clarity and user experience.
#
# ---
#
# # **Context from Upstream Tasks**
# Task task0:
#   Objective: Design the overall system architecture, outlining modules for the game loop, board management, tetromino mechanics, UI elements (score, lines cleared, border), and integration strategy.
#   Result: System Architecture Outline:
#
# 1. Main Module (Game Loop)
#    • Initialize pygame and set up the game window.
#    • Handle event processing (keyboard inputs, window events).
#    • Manage timing and game state updates.
#    • Coordinate calls to board, tetromino, and UI modules.
#    • Implement the main game loop that iterates through state updates and rendering.
#
# 2. Board Management Module
#    • Represent the standard 10x20 grid using a 2D array.
#    • Manage grid state including occupied cells and vacant cells.
#    • Render the gameplay grid and draw a border around the game area.
#    • Provide collision detection support by verifying positions against grid bounds and occupied cells.
#    • Interface with tetromino mechanics to update the grid upon piece landing.
#
# 3. Tetromino Mechanics Module
#    • Define data structures for tetromino shapes, orientations, and positions.
#    • Assign each tetromino a unique, vibrant color.
#    • Implement rotation mechanics and piece movement (left, right, down, and drop).
#    • Check for collision during movement and rotations using the board’s grid data.
#    • Handle the falling mechanics with proper timing to simulate gravity.
#    • Provide functionality to generate a new tetromino and track the next upcoming piece.
#
# 4. User Interface (UI) Module
#    • Display current score and update it based on gameplay events.
#    • Render the number of cleared lines and update upon line completion.
#    • Show the current falling tetromino and the next upcoming tetromino.
#    • Ensure a clean and modern layout to enhance gameplay clarity.
#    • Manage UI element positions relative to the game board.
#
# 5. Integration Strategy
#    • Main Module orchestrates the interplay among modules, calling Board, Tetromino, and UI updates per game loop iteration.
#    • Board Module provides collision and grid state queries to Tetromino Mechanics Module.
#    • Tetromino Mechanics Module updates the board data structure when pieces settle.
#    • UI Module fetches game state information (score, cleared lines, next piece) from corresponding modules.
#    • Maintain modular boundaries to allow for independent testing and future enhancements.
#
#
#
# ---
#
# # **Downstream Tasks objectivesv**
# Task task6:
#   Objective: Integrate the game loop, board, tetromino mechanics, preview, and scoring modules to ensure smooth interaction and overall gameplay consistency.
#
#
# ---
#
# # **Current Task Requirements**
# Set up the pygame window and implement the main game loop with event handling to drive gameplay.
#
# ---
#
#
# ***********run end*********************
# ***********run start*********************
#
#
# "# **Instructions:**
# "
# "1. Solve only your assigned subtask, referring to the context only if necessary.
# "
# "2. Ensure your solution aligns with the overall goal and is formatted so that it can be directly used as input for downstream tasks.
# "
# "3. Do not repeat any previous output verbatim.
# "
# "4. Output required result without adding any justifications."
# "5. Strictly follow the format constraint."
# ---
#
# # **The Overall Goal**
# Create a Tetris game using Python with the pygame library. The game should feature a standard 10x20 grid for gameplay. Display the current falling tetromino and the next upcoming piece. Include a score counter, a display for the number of cleared lines, and a simple border to distinguish the game area. Each tetromino type should have a unique, vibrant color for clear visibility. The interface should be clean and modern, emphasizing gameplay clarity and user experience.
#
# ---
#
# # **Context from Upstream Tasks**
# Task task0:
#   Objective: Design the overall system architecture, outlining modules for the game loop, board management, tetromino mechanics, UI elements (score, lines cleared, border), and integration strategy.
#   Result: System Architecture Outline:
#
# 1. Main Module (Game Loop)
#    • Initialize pygame and set up the game window.
#    • Handle event processing (keyboard inputs, window events).
#    • Manage timing and game state updates.
#    • Coordinate calls to board, tetromino, and UI modules.
#    • Implement the main game loop that iterates through state updates and rendering.
#
# 2. Board Management Module
#    • Represent the standard 10x20 grid using a 2D array.
#    • Manage grid state including occupied cells and vacant cells.
#    • Render the gameplay grid and draw a border around the game area.
#    • Provide collision detection support by verifying positions against grid bounds and occupied cells.
#    • Interface with tetromino mechanics to update the grid upon piece landing.
#
# 3. Tetromino Mechanics Module
#    • Define data structures for tetromino shapes, orientations, and positions.
#    • Assign each tetromino a unique, vibrant color.
#    • Implement rotation mechanics and piece movement (left, right, down, and drop).
#    • Check for collision during movement and rotations using the board’s grid data.
#    • Handle the falling mechanics with proper timing to simulate gravity.
#    • Provide functionality to generate a new tetromino and track the next upcoming piece.
#
# 4. User Interface (UI) Module
#    • Display current score and update it based on gameplay events.
#    • Render the number of cleared lines and update upon line completion.
#    • Show the current falling tetromino and the next upcoming tetromino.
#    • Ensure a clean and modern layout to enhance gameplay clarity.
#    • Manage UI element positions relative to the game board.
#
# 5. Integration Strategy
#    • Main Module orchestrates the interplay among modules, calling Board, Tetromino, and UI updates per game loop iteration.
#    • Board Module provides collision and grid state queries to Tetromino Mechanics Module.
#    • Tetromino Mechanics Module updates the board data structure when pieces settle.
#    • UI Module fetches game state information (score, cleared lines, next piece) from corresponding modules.
#    • Maintain modular boundaries to allow for independent testing and future enhancements.
#
#
#
# ---
#
# # **Downstream Tasks objectivesv**
# Task task5:
#   Objective: Develop the scoring and line-clearing module to update the score counter and display the number of cleared lines as gameplay progresses.
# Task task6:
#   Objective: Integrate the game loop, board, tetromino mechanics, preview, and scoring modules to ensure smooth interaction and overall gameplay consistency.
#
#
# ---
#
# # **Current Task Requirements**
# Develop the game board and grid management module to represent a standard 10x20 grid, including rendering a simple border to delineate the game area.
#
# ---
#
#
# ***********run end*********************
# ***********run start*********************
#
#
# "# **Instructions:**
# "
# "1. Solve only your assigned subtask, referring to the context only if necessary.
# "
# "2. Ensure your solution aligns with the overall goal and is formatted so that it can be directly used as input for downstream tasks.
# "
# "3. Do not repeat any previous output verbatim.
# "
# "4. Output required result without adding any justifications."
# "5. Strictly follow the format constraint."
# ---
#
# # **The Overall Goal**
# Create a Tetris game using Python with the pygame library. The game should feature a standard 10x20 grid for gameplay. Display the current falling tetromino and the next upcoming piece. Include a score counter, a display for the number of cleared lines, and a simple border to distinguish the game area. Each tetromino type should have a unique, vibrant color for clear visibility. The interface should be clean and modern, emphasizing gameplay clarity and user experience.
#
# ---
#
# # **Context from Upstream Tasks**
# Task task0:
#   Objective: Design the overall system architecture, outlining modules for the game loop, board management, tetromino mechanics, UI elements (score, lines cleared, border), and integration strategy.
#   Result: System Architecture Outline:
#
# 1. Main Module (Game Loop)
#    • Initialize pygame and set up the game window.
#    • Handle event processing (keyboard inputs, window events).
#    • Manage timing and game state updates.
#    • Coordinate calls to board, tetromino, and UI modules.
#    • Implement the main game loop that iterates through state updates and rendering.
#
# 2. Board Management Module
#    • Represent the standard 10x20 grid using a 2D array.
#    • Manage grid state including occupied cells and vacant cells.
#    • Render the gameplay grid and draw a border around the game area.
#    • Provide collision detection support by verifying positions against grid bounds and occupied cells.
#    • Interface with tetromino mechanics to update the grid upon piece landing.
#
# 3. Tetromino Mechanics Module
#    • Define data structures for tetromino shapes, orientations, and positions.
#    • Assign each tetromino a unique, vibrant color.
#    • Implement rotation mechanics and piece movement (left, right, down, and drop).
#    • Check for collision during movement and rotations using the board’s grid data.
#    • Handle the falling mechanics with proper timing to simulate gravity.
#    • Provide functionality to generate a new tetromino and track the next upcoming piece.
#
# 4. User Interface (UI) Module
#    • Display current score and update it based on gameplay events.
#    • Render the number of cleared lines and update upon line completion.
#    • Show the current falling tetromino and the next upcoming tetromino.
#    • Ensure a clean and modern layout to enhance gameplay clarity.
#    • Manage UI element positions relative to the game board.
#
# 5. Integration Strategy
#    • Main Module orchestrates the interplay among modules, calling Board, Tetromino, and UI updates per game loop iteration.
#    • Board Module provides collision and grid state queries to Tetromino Mechanics Module.
#    • Tetromino Mechanics Module updates the board data structure when pieces settle.
#    • UI Module fetches game state information (score, cleared lines, next piece) from corresponding modules.
#    • Maintain modular boundaries to allow for independent testing and future enhancements.
#
#
#
# ---
#
# # **Downstream Tasks objectivesv**
# Task task4:
#   Objective: Create the next tetromino preview feature to display the upcoming piece alongside the current falling tetromino.
# Task task5:
#   Objective: Develop the scoring and line-clearing module to update the score counter and display the number of cleared lines as gameplay progresses.
# Task task6:
#   Objective: Integrate the game loop, board, tetromino mechanics, preview, and scoring modules to ensure smooth interaction and overall gameplay consistency.
#
#
# ---
#
# # **Current Task Requirements**
# Implement tetromino logic including piece shapes, rotations, falling mechanics, collision detection, and assign each tetromino a unique, vibrant color.
#
# ---
#
#
# ***********run end*********************
# 2025-03-17 22:50:10 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ------Run pythonValidator.is_python_code()------
# 2025-03-17 22:50:13 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ********remove pops begin************
# 2025-03-17 22:50:15 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ------Run pythonValidator.is_python_code()------
# 2025-03-17 22:50:17 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ********remove pops begin************
# 2025-03-17 22:50:19 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# import pygame
# import sys
#
# pygame.init()
# WINDOW_WIDTH, WINDOW_HEIGHT = 400, 800
# SCREEN = pygame.display.set_mode((WINDOW_WIDTH, WINDOW_HEIGHT))
# pygame.display.set_caption("Tetris")
# CLOCK = pygame.time.Clock()
#
# def main():
#     running = True
#     while running:
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 running = False
#             if event.type == pygame.KEYDOWN:
#                 if event.key == pygame.K_LEFT:
#                     pass  # Handle move left
#                 elif event.key == pygame.K_RIGHT:
#                     pass  # Handle move right
#                 elif event.key == pygame.K_DOWN:
#                     pass  # Handle move down
#                 elif event.key == pygame.K_UP:
#                     pass  # Handle rotation
#                 elif event.key == pygame.K_SPACE:
#                     pass  # Handle drop
#
#         SCREEN.fill((0, 0, 0))
#         # Update game state and render gameplay elements here
#
#         pygame.display.update()
#         CLOCK.tick(60)
#
#     pygame.quit()
#     sys.exit()
#
# if __name__ == "__main__":
#     main()
# ********remove pops end************
# 2025-03-17 22:50:20 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ------Run pythonValidator.is_python_code()------
# 2025-03-17 22:50:22 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ********remove pops begin************
# 2025-03-17 22:50:23 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-17 22:50:23 [INFO] Task task1 done. Total completed so far: 2
# ***Python code with no bugs***
# task1 ---Final status: completed
# 2 3
# 2025-03-17 22:50:27 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# import pygame
# import sys
#
# class Board:
#     def __init__(self, x, y, cell_size, cols=10, rows=20, border_width=3):
#         self.x = x
#         self.y = y
#         self.cell_size = cell_size
#         self.cols = cols
#         self.rows = rows
#         self.border_width = border_width
#         self.grid = [[None for _ in range(self.cols)] for _ in range(self.rows)]
#
#     def draw(self, surface):
#         board_width = self.cols * self.cell_size
#         board_height = self.rows * self.cell_size
#         for row in range(self.rows):
#             for col in range(self.cols):
#                 cell_rect = pygame.Rect(
#                     self.x + col * self.cell_size,
#                     self.y + row * self.cell_size,
#                     self.cell_size,
#                     self.cell_size
#                 )
#                 pygame.draw.rect(surface, (180, 180, 180), cell_rect, 1)
#         pygame.draw.rect(
#             surface,
#             (255, 255, 255),
#             (self.x, self.y, board_width, board_height),
#             self.border_width
#         )
#
# if __name__ == "__main__":
#     pygame.init()
#     window_width, window_height = 400, 600
# #     screen = pygame.display.set_mode((window_width, window_height))
#     pygame.display.set_caption("Tetris Board Test")
#     clock = pygame.time.Clock()
#
#     cell_size = 30
#     board_x = (window_width - cell_size * 10) // 2
#     board_y = (window_height - cell_size * 20) // 2
#     board = Board(board_x, board_y, cell_size)
#
#     running = True
#     while running:
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 running = False
#
#         screen.fill((0, 0, 0))
#         board.draw(screen)
#         pygame.display.flip()
#         clock.tick(60)
#
#     pygame.quit()
#     sys.exit()
# ********remove pops end************
# 2025-03-17 22:50:33 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# import pygame
# import random
#
# # Define tetromino shapes as matrices
# TETROMINO_SHAPES = {
#     'I': [[1, 1, 1, 1]],
#     'O': [
#         [1, 1],
#         [1, 1]
#     ],
#     'T': [
#         [0, 1, 0],
#         [1, 1, 1]
#     ],
#     'S': [
#         [0, 1, 1],
#         [1, 1, 0]
#     ],
#     'Z': [
#         [1, 1, 0],
#         [0, 1, 1]
#     ],
#     'J': [
#         [1, 0, 0],
#         [1, 1, 1]
#     ],
#     'L': [
#         [0, 0, 1],
#         [1, 1, 1]
#     ]
# }
#
# # Assign unique, vibrant colors to each tetromino
# TETROMINO_COLORS = {
#     'I': (0, 255, 255),
#     'O': (255, 255, 0),
#     'T': (128, 0, 128),
#     'S': (0, 255, 0),
#     'Z': (255, 0, 0),
#     'J': (0, 0, 255),
#     'L': (255, 165, 0)
# }
#
# # Board dimensions
# BOARD_WIDTH = 10
# BOARD_HEIGHT = 20
#
# def rotate_matrix(matrix):
#     """Rotate a matrix 90 degrees clockwise."""
#     return [list(row) for row in zip(*matrix[::-1])]
#
# def check_collision(board, shape_matrix, offset_x, offset_y):
#     for y, row in enumerate(shape_matrix):
#         for x, cell in enumerate(row):
#             if cell:
#                 board_x = offset_x + x
#                 board_y = offset_y + y
#                 if board_x < 0 or board_x >= BOARD_WIDTH or board_y < 0 or board_y >= BOARD_HEIGHT:
#                     return True
# ...
# }
#
# SCORING = {1: 40, 2: 100, 3: 300, 4: 1200}
#
# def rotate_matrix(matrix):
#     return [list(row) for row in zip(*matrix[::-1])]
#
# def check_collision(board, shape_matrix, offset_x, offset_y):
#     for y, row in enumerate(shape_matrix):
#         for x, cell in enumerate(row):
#             if cell:
#                 board_x = offset_x + x
#                 board_y = offset_y + y
#                 if board_x < 0 or board_x >= BOARD_WIDTH or board_y < 0 or board_y >= BOARD_HEIGHT:
#                     return True
#                 if board[board_y][board_x]:
#                     return True
#     return False
#
# class Tetromino:
#     def __init__(self, shape_key):
#         self.shape_key = shape_key
#         self.shape_matrix = TETROMINO_SHAPES[shape_key]
#         self.color = TETROMINO_COLORS[shape_key]
#         self.x = BOARD_WIDTH // 2 - len(self.shape_matrix[0]) // 2
#         self.y = 0
#
#     def get_cells(self):
#         cells = []
#         for y, row in enumerate(self.shape_matrix):
#             for x, cell in enumerate(row):
#                 if cell:
#                     cells.append((self.x + x, self.y + y))
#         return cells
#
#     def rotate(self, board):
#         rotated_shape = rotate_matrix(self.shape_matrix)
#         if not check_collision(board, rotated_shape, self.x, self.y):
#             self.shape_matrix = rotated_shape
#
#     def move(self, dx, dy, board):
#         new_x = self.x + dx
#         new_y = self.y + dy
#         if not check_collision(board, self.shape_matrix, new_x, new_y):
#             self.x = new_x
#             self.y = new_y
#             return True
#         return False
#
#     def fall(self, board):
#         return self.move(0, 1, board)
#
# def create_board():
#     return [[0 for _ in range(BOARD_WIDTH)] for _ in range(BOARD_HEIGHT)]
#
# def clear_full_lines(board):
#     new_board = [row for row in board if any(cell == 0 for cell in row)]
#     cleared = BOARD_HEIGHT - len(new_board)
#     for _ in range(cleared):
#         new_board.insert(0, [0 for _ in range(BOARD_WIDTH)])
#     return new_board, cleared
#
# class ScoreManager:
#     def __init__(self):
#         self.score = 0
#         self.cleared_lines = 0
#         self.font = pygame.font.SysFont("comicsans", 24, bold=True)
#
#     def update(self, lines_cleared):
#         if lines_cleared > 0:
#             self.cleared_lines += lines_cleared
#             self.score += SCORING.get(lines_cleared, lines_cleared * 40)
#
#     def draw(self, surface, pos):
#         score_text = self.font.render(f"Score: {self.score}", True, (240, 240, 240))
#         lines_text = self.font.render(f"Lines: {self.cleared_lines}", True, (240, 240, 240))
#         surface.blit(score_text, pos)
#         surface.blit(lines_text, (pos[0], pos[1] + 30))
#
# class Board:
#     def __init__(self, x, y, cell_size, cols, rows, border_width=3):
#         self.x = x
#         self.y = y
#         self.cell_size = cell_size
#         self.cols = cols
#         self.rows = rows
#         self.border_width = border_width
#
#     def draw_grid(self, surface):
#         board_width = self.cols * self.cell_size
#         board_height = self.rows * self.cell_size
#         for row in range(self.rows):
#             for col in range(self.cols):
#                 cell_rect = pygame.Rect(self.x + col * self.cell_size, self.y + row * self.cell_size, self.cell_size, self.cell_size)
#                 pygame.draw.rect(surface, (50, 50, 50), cell_rect, 1)
#         pygame.draw.rect(surface, (200, 200, 200), (self.x, self.y, board_width, board_height), self.border_width)
#
# def draw_shadow(surface, rect, shadow_color=(0,0,0), offset=3):
#     shadow_rect = pygame.Rect(rect.x + offset, rect.y + offset, rect.width, rect.height)
#     pygame.draw.rect(surface, shadow_color, shadow_rect)
#
# def main():
#     pygame.init()
#     screen = pygame.display.set_mode((WINDOW_WIDTH, WINDOW_HEIGHT))
#     pygame.display.set_caption("Tetris")
#     clock = pygame.time.Clock()
#
#     board_state = create_board()
#     board_x = 10
#     board_y = 10
#     game_board = Board(board_x, board_y, CELL_SIZE, BOARD_WIDTH, BOARD_HEIGHT)
#     score_manager = ScoreManager()
#
#     current_tetromino = Tetromino(random.choice(list(TETROMINO_SHAPES.keys())))
#     next_tetromino = Tetromino(random.choice(list(TETROMINO_SHAPES.keys())))
#
#     fall_event = pygame.USEREVENT + 1
#     pygame.time.set_timer(fall_event, 500)
#
#     font_large = pygame.font.SysFont("comicsans", 28, bold=True)
#
#     running = True
#     while running:
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 running = False
#             elif event.type == fall_event:
#                 if not current_tetromino.fall(board_state):
#                     for x, y in current_tetromino.get_cells():
#                         if 0 <= y < BOARD_HEIGHT and 0 <= x < BOARD_WIDTH:
#                             board_state[y][x] = current_tetromino.color
#                     board_state, cleared = clear_full_lines(board_state)
#                     score_manager.update(cleared)
#                     current_tetromino = next_tetromino
#                     next_tetromino = Tetromino(random.choice(list(TETROMINO_SHAPES.keys())))
#                     if check_collision(board_state, current_tetromino.shape_matrix, current_tetromino.x, current_tetromino.y):
#                         running = False
#             elif event.type == pygame.KEYDOWN:
#                 if event.key == pygame.K_LEFT:
#                     current_tetromino.move(-1, 0, board_state)
#                 elif event.key == pygame.K_RIGHT:
#                     current_tetromino.move(1, 0, board_state)
#                 elif event.key == pygame.K_DOWN:
#                     current_tetromino.fall(board_state)
#                 elif event.key == pygame.K_UP:
#                     current_tetromino.rotate(board_state)
#                 elif event.key == pygame.K_SPACE:
#                     while current_tetromino.move(0, 1, board_state):
#                         pass
#
#         screen.fill((30, 30, 30))
#         board_background = pygame.Rect(board_x, board_y, BOARD_WIDTH * CELL_SIZE, BOARD_HEIGHT * CELL_SIZE)
#         pygame.draw.rect(screen, (20, 20, 20), board_background)
#         for row in range(BOARD_HEIGHT):
#             for col in range(BOARD_WIDTH):
#                 cell_value = board_state[row][col]
#                 cell_rect = pygame.Rect(board_x + col * CELL_SIZE, board_y + row * CELL_SIZE, CELL_SIZE, CELL_SIZE)
#                 if cell_value:
#                     draw_shadow(screen, cell_rect, offset=3)
#                     pygame.draw.rect(screen, cell_value, cell_rect)
#                     pygame.draw.rect(screen, (0, 0, 0), cell_rect, 1)
#         for x, y in current_tetromino.get_cells():
#             cell_rect = pygame.Rect(board_x + x * CELL_SIZE, board_y + y * CELL_SIZE, CELL_SIZE, CELL_SIZE)
#             draw_shadow(screen, cell_rect, offset=3)
#             pygame.draw.rect(screen, current_tetromino.color, cell_rect)
#             pygame.draw.rect(screen, (0, 0, 0), cell_rect, 1)
#         game_board.draw_grid(screen)
#         preview_area_x = MAIN_WIDTH + 40
#         preview_area_y = 50
#         preview_box_width = 100
#         preview_box_height = 100
#         preview_box = pygame.Rect(preview_area_x - 5, preview_area_y - 5, preview_box_width + 10, preview_box_height + 10)
#         pygame.draw.rect(screen, (128, 128, 128), preview_box, 2)
#         next_label = font_large.render("Next Piece", True, (240, 240, 240))
#         screen.blit(next_label, (preview_area_x, preview_area_y - 35))
#         shape_matrix = next_tetromino.shape_matrix
#         offset_x = preview_area_x + (preview_box_width - len(shape_matrix[0]) * CELL_SIZE) // 2
#         offset_y = preview_area_y + (preview_box_height - len(shape_matrix) * CELL_SIZE) // 2
#         for y_idx, row in enumerate(shape_matrix):
#             for x_idx, cell in enumerate(row):
#                 if cell:
#                     cell_rect = pygame.Rect(offset_x + x_idx * CELL_SIZE, offset_y + y_idx * CELL_SIZE, CELL_SIZE, CELL_SIZE)
#                     draw_shadow(screen, cell_rect, offset=2)
#                     pygame.draw.rect(screen, next_tetromino.color, cell_rect)
#                     pygame.draw.rect(screen, (0, 0, 0), cell_rect, 1)
#         score_manager.draw(screen, (MAIN_WIDTH + 40, preview_area_y + preview_box_height + 20))
#         pygame.display.update()
#         clock.tick(60)
#
#     pygame.quit()
#     sys.exit()
#
# if __name__ == "__main__":
#     main()
# 2025-03-17 22:56:26 [INFO]  - task8: import unittest
# import pygame
# import random
#
# # Initialize pygame for tests that require fonts/rendering.
# pygame.init()
#
# # Constants and modules identical to main code.
# BOARD_WIDTH, BOARD_HEIGHT = 10, 20
# CELL_SIZE = 30
#
# TETROMINO_SHAPES = {
#     'I': [[1, 1, 1, 1]],
#     'O': [[1, 1],
#           [1, 1]],
#     'T': [[0, 1, 0],
#           [1, 1, 1]],
#     'S': [[0, 1, 1],
#           [1, 1, 0]],
#     'Z': [[1, 1, 0],
#           [0, 1, 1]],
#     'J': [[1, 0, 0],
#           [1, 1, 1]],
#     'L': [[0, 0, 1],
#           [1, 1, 1]]
# }
#
# TETROMINO_COLORS = {
#     'I': (0, 255, 255),
#     'O': (255, 255, 0),
#     'T': (128, 0, 128),
#     'S': (0, 255, 0),
#     'Z': (255, 0, 0),
#     'J': (0, 0, 255),
#     'L': (255, 165, 0)
# }
#
# SCORING = {1: 40, 2: 100, 3: 300, 4: 1200}
#
# def rotate_matrix(matrix):
#     return [list(row) for row in zip(*matrix[::-1])]
#
# def check_collision(board, shape_matrix, offset_x, offset_y):
#     for y, row in enumerate(shape_matrix):
#         for x, cell in enumerate(row):
#             if cell:
#                 board_x = offset_x + x
#                 board_y = offset_y + y
#                 if board_x < 0 or board_x >= BOARD_WIDTH or board_y < 0 or board_y >= BOARD_HEIGHT:
#                     return True
#                 if board[board_y][board_x]:
#                     return True
#     return False
#
# class Tetromino:
#     def __init__(self, shape_key):
#         self.shape_key = shape_key
#         self.shape_matrix = TETROMINO_SHAPES[shape_key]
#         self.color = TETROMINO_COLORS[shape_key]
#         self.x = BOARD_WIDTH // 2 - len(self.shape_matrix[0]) // 2
#         self.y = 0
#
#     def get_cells(self):
#         cells = []
#         for y, row in enumerate(self.shape_matrix):
#             for x, cell in enumerate(row):
#                 if cell:
#                     cells.append((self.x + x, self.y + y))
#         return cells
#
#     def rotate(self, board):
#         rotated_shape = rotate_matrix(self.shape_matrix)
#         if not check_collision(board, rotated_shape, self.x, self.y):
#             self.shape_matrix = rotated_shape
#
#     def move(self, dx, dy, board):
#         new_x = self.x + dx
#         new_y = self.y + dy
#         if not check_collision(board, self.shape_matrix, new_x, new_y):
#             self.x = new_x
#             self.y = new_y
#             return True
#         return False
#
#     def fall(self, board):
#         return self.move(0, 1, board)
#
# def create_board():
#     return [[0 for _ in range(BOARD_WIDTH)] for _ in range(BOARD_HEIGHT)]
#
# def clear_full_lines(board):
#     new_board = [row for row in board if any(cell == 0 for cell in row)]
#     cleared = BOARD_HEIGHT - len(new_board)
#     for _ in range(cleared):
#         new_board.insert(0, [0 for _ in range(BOARD_WIDTH)])
#     return new_board, cleared
#
# class ScoreManager:
#     def __init__(self):
#         self.score = 0
#         self.cleared_lines = 0
#         self.font = pygame.font.SysFont("comicsans", 24, bold=True)
#
#     def update(self, lines_cleared):
#         if lines_cleared > 0:
#             self.cleared_lines += lines_cleared
#             self.score += SCORING.get(lines_cleared, lines_cleared * 40)
#
#     def draw(self, surface, pos):
#         score_text = self.font.render(f"Score: {self.score}", True, (240, 240, 240))
#         lines_text = self.font.render(f"Lines: {self.cleared_lines}", True, (240, 240, 240))
#         surface.blit(score_text, pos)
#         surface.blit(lines_text, (pos[0], pos[1] + 30))
#
# class Board:
#     def __init__(self, x, y, cell_size, cols, rows, border_width=3):
#         self.x = x
#         self.y = y
#         self.cell_size = cell_size
#         self.cols = cols
#         self.rows = rows
#         self.border_width = border_width
#
#     def draw_grid(self, surface):
#         board_width = self.cols * self.cell_size
#         board_height = self.rows * self.cell_size
#         for row in range(self.rows):
#             for col in range(self.cols):
#                 cell_rect = pygame.Rect(self.x + col * self.cell_size,
#                                         self.y + row * self.cell_size,
#                                         self.cell_size, self.cell_size)
#                 pygame.draw.rect(surface, (50, 50, 50), cell_rect, 1)
#         pygame.draw.rect(surface, (200, 200, 200),
#                          (self.x, self.y, board_width, board_height),
#                          self.border_width)
#
# class TestTetrisModules(unittest.TestCase):
#
#     def test_rotate_matrix(self):
#         matrix = [
#             [1, 0],
#             [1, 1]
#         ]
#         rotated = rotate_matrix(matrix)
#         expected = [
#             [1, 1],
#             [1, 0]
#         ]
#         self.assertEqual(rotated, expected)
#
#     def test_check_collision_empty_board(self):
#         board = create_board()
#         shape = [[1, 1],
#                  [1, 1]]
#         # In bounds, no collision.
#         self.assertFalse(check_collision(board, shape, 4, 5))
#         # Out of bounds collision.
#         self.assertTrue(check_collision(board, shape, -1, 5))
#         self.assertTrue(check_collision(board, shape, 9, 5))
#         self.assertTrue(check_collision(board, shape, 4, 19))
#
#     def test_tetromino_move(self):
#         board = create_board()
#         tetro = Tetromino('O')
#         initial_position = (tetro.x, tetro.y)
#         moved = tetro.move(1, 0, board)
#         self.assertTrue(moved)
#         self.assertEqual((tetro.x, tetro.y), (initial_position[0] + 1, initial_position[1]))
#         # Block movement by filling a cell.
#         board[tetro.y][tetro.x + 1] = (100, 100, 100)
#         moved = tetro.move(1, 0, board)
#         self.assertFalse(moved)
#
#     def test_tetromino_fall_and_collision(self):
#         board = create_board()
#         tetro = Tetromino('I')
#         # Force tetromino to near bottom.
#         tetro.y = BOARD_HEIGHT - 1
#         fell = tetro.fall(board)
#         self.assertFalse(fell)
#         # Add tetromino cells into board.
#         for x, y in tetro.get_cells():
#             if 0 <= y < BOARD_HEIGHT and 0 <= x < BOARD_WIDTH:
#                 board[y][x] = tetro.color
#         # Create new tetromino at starting position; if collision, it should be game over.
#         new_tetro = Tetromino('I')
#         collision = check_collision(board, new_tetro.shape_matrix, new_tetro.x, new_tetro.y)
#         self.assertEqual(collision, False)
#
#     def test_clear_full_lines(self):
#         board = create_board()
#         # Fill row 19 completely.
#         board[-1] = [(10, 10, 10)] * BOARD_WIDTH
#         new_board, cleared = clear_full_lines(board)
#         self.assertEqual(cleared, 1)
#         # Ensure new board has 20 rows.
#         self.assertEqual(len(new_board), BOARD_HEIGHT)
#         # Check that the top row is empty.
#         self.assertEqual(new_board[0], [0]*BOARD_WIDTH)
#
#     def test_score_manager_update(self):
#         sm = ScoreManager()
#         sm.update(1)
#         self.assertEqual(sm.score, SCORING[1])
#         self.assertEqual(sm.cleared_lines, 1)
#         sm.update(2)
#         self.assertEqual(sm.score, SCORING[1] + SCORING[2])
#         self.assertEqual(sm.cleared_lines, 3)
#         # Non-standard line clear count.
#         sm.update(5)
#         self.assertEqual(sm.score, SCORING[1] + SCORING[2] + 5*40)
#         self.assertEqual(sm.cleared_lines, 8)
#
#     def test_board_draw_grid(self):
#         # Create a dummy surface.
#         surface = pygame.Surface((300, 600))
#         board = Board(0, 0, CELL_SIZE, BOARD_WIDTH, BOARD_HEIGHT)
#         board.draw_grid(surface)
#         # Ensure surface remains a Surface.
#         self.assertIsInstance(surface, pygame.Surface)
#
# if __name__ == '__main__':
#     unittest.main()
# ------Run pythonValidator.execute_python_code------
# ***Python code with no bugs***
# task8 ---Final status: completed
# 3 3

# %% [markdown]
# ### Store necessary information and summary the output

# %%
workflow_data = {}

for tid, task in manager.workflow.tasks.items():
    custom_task_data = {
        'id': task.id,
        'objective': task.objective,
        'agent_id': task.agent_id,
        'next': task.next,
        'prev': task.prev,
        'status': task.status,
        'remaining_dependencies': task.remaining_dependencies,
        'agent': task.agent,
        'history': task.history.get_latest_result(),
    }
    
    workflow_data[tid] = custom_task_data
    
# Store the final workflow
with open('manually_result.json', 'w', encoding='utf-8') as file:
    json.dump(workflow_data, file, indent=4)

summary = Summary()

# Generate and save a summary of the workflow results
chat_result = summary.summary(overall_task, workflow_data)
with open("example.txt", "w", encoding="utf-8") as file:
    file.write(chat_result)
# Out:
# 2025-03-17 22:57:18 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"

# %% [markdown]
# The following python file represents the outcome generated by our FLOW.

# %%
import sys, random, pygame, time

# -------------------- Constants & Global Settings --------------------
WINDOW_WIDTH = 400
WINDOW_HEIGHT = 500
GRID_COLS = 10
GRID_ROWS = 20
CELL_SIZE = 24
GRID_ORIGIN = (20, 20)
NEXT_ORIGIN = (300, 50)
SCORE_POS = (300, 250)
BG_COLOR = (30, 30, 30)
BORDER_COLOR = (50, 50, 50)
TEXT_COLOR = (255, 255, 255)
FALL_DELAY = 500  # milliseconds delay for tetromino fall

# Tetromino Shapes (list of (dx, dy) offsets relative to a pivot)
SHAPES = {
    "I": [(-1, 0), (0, 0), (1, 0), (2, 0)],
    "O": [(0, 0), (1, 0), (0, 1), (1, 1)],
    "T": [(-1, 0), (0, 0), (1, 0), (0, 1)],
    "S": [(0, 0), (1, 0), (-1, 1), (0, 1)],
    "Z": [(-1, 0), (0, 0), (0, 1), (1, 1)],
    "J": [(-1, 0), (0, 0), (1, 0), (-1, 1)],
    "L": [(-1, 0), (0, 0), (1, 0), (1, 1)]
}

# Mapping tetromino shape to gem color strings
COLOR_MAPPING = {
    "I": "cyan",
    "O": "yellow",
    "T": "purple",
    "S": "green",
    "Z": "red",
    "J": "blue",
    "L": "orange"
}

# Map color names to RGB values (for display in grid)
RGB_GEMS = {
    "cyan":   (0, 255, 255),
    "yellow": (255, 255, 0),
    "purple": (128, 0, 128),
    "green":  (0, 255, 0),
    "red":    (255, 0, 0),
    "blue":   (0, 0, 255),
    "orange": (255, 165, 0)
}

# -------------------- Game Core Modules --------------------
class GemTransformation:
    def transform_to_gems(self, tetromino, grid):
        # Convert locked tetromino blocks into colored gems using the mapping
        gem_color = COLOR_MAPPING[tetromino["shape"]]
        for (x, y) in tetromino["blocks"]:
            if 0 <= y < len(grid) and 0 <= x < len(grid[0]):
                grid[y][x] = gem_color
        return grid

class TetrisMechanics:
    def __init__(self, grid_width=GRID_COLS, grid_height=GRID_ROWS):
        self.grid_width = grid_width
        self.grid_height = grid_height
        self.grid = [[None for _ in range(grid_width)] for _ in range(grid_height)]
        self.current_tetromino = None
        self.gem_transformer = GemTransformation()

    def spawn_tetromino(self):
        shape = random.choice(list(SHAPES.keys()))
        pivot_x = self.grid_width // 2
        pivot_y = 0
        blocks = []
        for offset in SHAPES[shape]:
            x = pivot_x + offset[0]
            y = pivot_y + offset[1]
            blocks.append((x, y))
        self.current_tetromino = {
            "shape": shape,
            "pivot": (pivot_x, pivot_y),
            "blocks": blocks
        }

    def check_collision(self, blocks):
        for (x, y) in blocks:
            if x < 0 or x >= self.grid_width or y >= self.grid_height:
                return True
            if y >= 0 and self.grid[y][x] is not None:
                return True
        return False

    def move_tetromino(self, direction):
        if self.current_tetromino is None:
            return
        dx, dy = 0, 0
        if direction == 'left':
            dx = -1
        elif direction == 'right':
            dx = 1
        elif direction == 'down':
            dy = 1
        new_blocks = [(x + dx, y + dy) for (x, y) in self.current_tetromino["blocks"]]
        if not self.check_collision(new_blocks):
            self.current_tetromino["blocks"] = new_blocks
            pivot_x, pivot_y = self.current_tetromino["pivot"]
            self.current_tetromino["pivot"] = (pivot_x + dx, pivot_y + dy)
        elif direction == 'down':
            self.lock_piece()

    def rotate_tetromino(self):
        if self.current_tetromino is None:
            return
        pivot = self.current_tetromino["pivot"]
        new_blocks = []
        for (x, y) in self.current_tetromino["blocks"]:
            rel_x = x - pivot[0]
            rel_y = y - pivot[1]
            # Rotate clockwise: (x, y) -> (y, -x)
            new_x = pivot[0] + rel_y
            new_y = pivot[1] - rel_x
            new_blocks.append((new_x, new_y))
        if not self.check_collision(new_blocks):
            self.current_tetromino["blocks"] = new_blocks

    def lock_piece(self):
        if self.current_tetromino is None:
            return
        self.gem_transformer.transform_to_gems(self.current_tetromino, self.grid)
        self.current_tetromino = None

# -- Match-3 Clearing and Tetris Line Clear Logic --
class Match3Controller:
    def __init__(self, min_match=3):
        self.min_match = min_match

    def detect_matches(self, gem_grid):
        overall_matches = set()
        rows = len(gem_grid)
        cols = len(gem_grid[0])
        # Detect horizontal matches
        for r in range(rows):
            count = 1
            for c in range(1, cols):
                if gem_grid[r][c] is not None and gem_grid[r][c] == gem_grid[r][c - 1]:
                    count += 1
                else:
                    if count >= self.min_match:
                        positions = {(r, k) for k in range(c - count, c)}
                        overall_matches.update(positions)
                    count = 1
            if count >= self.min_match:
                positions = {(r, k) for k in range(cols - count, cols)}
                overall_matches.update(positions)
        # Detect vertical matches
        for c in range(cols):
            count = 1
            for r in range(1, rows):
                if gem_grid[r][c] is not None and gem_grid[r][c] == gem_grid[r - 1][c]:
                    count += 1
                else:
                    if count >= self.min_match:
                        positions = {(k, c) for k in range(r - count, r)}
                        overall_matches.update(positions)
                    count = 1
            if count >= self.min_match:
                positions = {(k, c) for k in range(rows - count, rows)}
                overall_matches.update(positions)
        # Diagonal detection (down-right)
        for r in range(rows):
            for c in range(cols):
                positions = [(r, c)]
                rr, cc = r + 1, c + 1
                while rr < rows and cc < cols and gem_grid[rr][cc] is not None and gem_grid[rr][cc] == gem_grid[r][c]:
                    positions.append((rr, cc))
                    rr += 1
                    cc += 1
                if len(positions) >= self.min_match:
                    overall_matches.update(positions)
        # Diagonal detection (down-left)
        for r in range(rows):
            for c in range(cols):
                positions = [(r, c)]
                rr, cc = r + 1, c - 1
                while rr < rows and cc >= 0 and gem_grid[rr][cc] is not None and gem_grid[rr][cc] == gem_grid[r][c]:
                    positions.append((rr, cc))
                    rr += 1
                    cc -= 1
                if len(positions) >= self.min_match:
                    overall_matches.update(positions)
        return overall_matches

    def clear_matches(self, gem_grid, matched_positions):
        cleared_count = 0
        for (r, c) in matched_positions:
            if gem_grid[r][c] is not None:
                gem_grid[r][c] = None
                cleared_count += 1
        return cleared_count

    def drop_gems(self, gem_grid):
        rows = len(gem_grid)
        cols = len(gem_grid[0])
        for c in range(cols):
            empty_slots = []
            for r in range(rows - 1, -1, -1):
                if gem_grid[r][c] is None:
                    empty_slots.append(r)
                elif empty_slots:
                    empty_r = empty_slots.pop(0)
                    gem_grid[empty_r][c] = gem_grid[r][c]
                    gem_grid[r][c] = None
                    empty_slots.append(r)
        return gem_grid

    def trigger_chain_reaction(self, gem_grid):
        chain_multiplier = 1
        total_bonus = 0
        while True:
            matches = self.detect_matches(gem_grid)
            if not matches:
                break
            cleared = self.clear_matches(gem_grid, matches)
            bonus = cleared * chain_multiplier * 10
            total_bonus += bonus
            gem_grid = self.drop_gems(gem_grid)
            chain_multiplier += 1
        return gem_grid, total_bonus

def clear_tetris_lines(grid):
    rows = len(grid)
    cols = len(grid[0])
    lines_cleared = 0
    new_grid = []
    for row in grid:
        if all(cell is not None for cell in row):
            lines_cleared += 1
        else:
            new_grid.append(row)
    while len(new_grid) < rows:
        new_grid.insert(0, [None for _ in range(cols)])
    return new_grid, lines_cleared

class ScoreManager:
    def __init__(self):
        self.total_score = 0

    def update_tetris_score(self, lines_cleared):
        self.total_score += lines_cleared * 100

    def update_match3_score(self, gems_cleared, bonus):
        self.total_score += gems_cleared * 5 + bonus

    def get_total_score(self):
        return self.total_score

# -------------------- GUI Module (Using Pygame) --------------------
class GameGUI:
    def __init__(self):
        pygame.init()
        self.screen = pygame.display.set_mode((WINDOW_WIDTH, WINDOW_HEIGHT))
        pygame.display.set_caption("Tetris-Bejeweled Fusion")
        self.clock = pygame.time.Clock()
        self.font = pygame.font.SysFont("arial", 20)

    def draw_grid(self, gem_grid):
        # Draw the game grid with each cell as a colored block (or black if empty)
        for row in range(GRID_ROWS):
            for col in range(GRID_COLS):
                cell_value = gem_grid[row][col]
                if cell_value is None:
                    color = (0, 0, 0)
                else:
                    color = RGB_GEMS.get(cell_value, (255, 255, 255))
                rect = pygame.Rect(GRID_ORIGIN[0] + col * CELL_SIZE,
                                   GRID_ORIGIN[1] + row * CELL_SIZE,
                                   CELL_SIZE, CELL_SIZE)
                pygame.draw.rect(self.screen, color, rect)
                pygame.draw.rect(self.screen, BORDER_COLOR, rect, 1)

    def draw_score(self, score):
        score_text = self.font.render("Score: " + str(score), True, TEXT_COLOR)
        self.screen.blit(score_text, SCORE_POS)

    def draw_next_tetromino(self, tetromino):
        # Represent the tetromino as a simple matrix using 1 for blocks and 0 for empty.
        # First, convert tetromino blocks to a minimal matrix by finding bounds.
        matrix = piece_to_matrix(tetromino)
        block_color = (200, 200, 200)
        for row_idx, row in enumerate(matrix):
            for col_idx, cell in enumerate(row):
                if cell:
                    rect = pygame.Rect(NEXT_ORIGIN[0] + col_idx * CELL_SIZE,
                                       NEXT_ORIGIN[1] + row_idx * CELL_SIZE,
                                       CELL_SIZE, CELL_SIZE)
                    pygame.draw.rect(self.screen, block_color, rect)
                    pygame.draw.rect(self.screen, BORDER_COLOR, rect, 1)
        header = self.font.render("Next", True, TEXT_COLOR)
        self.screen.blit(header, (NEXT_ORIGIN[0], NEXT_ORIGIN[1] - 25))

    def update_display(self):
        pygame.display.flip()

    def handle_input(self):
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()

def piece_to_matrix(piece):
    # Convert tetromino block positions into a minimal 2D matrix representation.
    coords = piece["blocks"]
    if not coords:
        return [[0]]
    xs = [x for x,y in coords]
    ys = [y for x,y in coords]
    min_x, min_y = min(xs), min(ys)
    max_x, max_y = max(xs), max(ys)
    width = max_x - min_x + 1
    height = max_y - min_y + 1
    matrix = [[0 for _ in range(width)] for _ in range(height)]
    for (x,y) in coords:
        mx = x - min_x
        my = y - min_y
        matrix[my][mx] = 1
    return matrix

# -------------------- Integration: Main Game Loop --------------------
def main():
    # Instantiate core modules
    mechanics = TetrisMechanics()
    matcher = Match3Controller()
    scorer = ScoreManager()
    gui = GameGUI()

    # Spawn first tetromino and set a next-piece preview
    mechanics.spawn_tetromino()
    next_piece = None
    if mechanics.current_tetromino:
        # Prepare a preview piece by generating a new tetromino without locking it immediately.
        next_piece = {}
        shape = random.choice(list(SHAPES.keys()))
        pivot = (GRID_COLS // 2, 0)
        blocks = [(pivot[0] + dx, pivot[1] + dy) for (dx,dy) in SHAPES[shape]]
        next_piece = {"shape": shape, "pivot": pivot, "blocks": blocks}

    last_fall = pygame.time.get_ticks()
    game_over = False

    while not game_over:
        gui.handle_input()

        # --- Handle user input for tetromino movement ---
        keys = pygame.key.get_pressed()
        if keys[pygame.K_LEFT]:
            mechanics.move_tetromino("left")
        if keys[pygame.K_RIGHT]:
            mechanics.move_tetromino("right")
        if keys[pygame.K_DOWN]:
            mechanics.move_tetromino("down")
        if keys[pygame.K_UP]:
            mechanics.rotate_tetromino()

        # --- Gravity: Automatic tetromino move down ---
        now = pygame.time.get_ticks()
        if now - last_fall > FALL_DELAY:
            mechanics.move_tetromino("down")
            last_fall = now

        # --- Check if tetromino has locked and process grid clearing ---
        if mechanics.current_tetromino is None:
            # First, clear any full lines (Tetris mechanic)
            mechanics.grid, lines = clear_tetris_lines(mechanics.grid)
            scorer.update_tetris_score(lines)
            # Then, check and process gem match-3 clearing with chain reactions
            before = sum(1 for row in mechanics.grid for cell in row if cell is not None)
            mechanics.grid, bonus = matcher.trigger_chain_reaction(mechanics.grid)
            after = sum(1 for row in mechanics.grid for cell in row if cell is not None)
            cleared_gems = before - after
            scorer.update_match3_score(cleared_gems, bonus)
            # Update current piece (use the pre-generated next_piece) and spawn a new next preview
            mechanics.spawn_tetromino()
            current = mechanics.current_tetromino
            next_piece = None
            shape = random.choice(list(SHAPES.keys()))
            pivot = (GRID_COLS // 2, 0)
            blocks = [(pivot[0] + dx, pivot[1] + dy) for (dx,dy) in SHAPES[shape]]
            next_piece = {"shape": shape, "pivot": pivot, "blocks": blocks}
            # Check for game over: if any block of the new tetromino collides with existing gems
            for (x, y) in current["blocks"]:
                if y < 0 or mechanics.grid[y][x] is not None:
                    game_over = True
                    break

        # --- GUI Rendering ---
        gui.screen.fill(BG_COLOR)
        gui.draw_grid(mechanics.grid)
        # Draw current falling tetromino if available
        if mechanics.current_tetromino:
            # Draw the tetromino by rendering each block with its corresponding gem color
            gem_color = RGB_GEMS[COLOR_MAPPING[mechanics.current_tetromino["shape"]]]
            for (x, y) in mechanics.current_tetromino["blocks"]:
                if y >= 0:
                    rect = pygame.Rect(GRID_ORIGIN[0] + x * CELL_SIZE, GRID_ORIGIN[1] + y * CELL_SIZE, CELL_SIZE, CELL_SIZE)
                    pygame.draw.rect(gui.screen, gem_color, rect)
                    pygame.draw.rect(gui.screen, BORDER_COLOR, rect, 1)
        gui.draw_score(scorer.get_total_score())
        if next_piece:
            gui.draw_next_tetromino(next_piece)
        gui.update_display()
        gui.clock.tick(60)

    # Game Over — show final score for a short moment then exit
    print("Game Over! Final Score:", scorer.get_total_score())
    time.sleep(2)
    pygame.quit()
    sys.exit()

if __name__ == "__main__":
    main()
