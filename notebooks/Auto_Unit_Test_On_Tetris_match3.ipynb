# %% [markdown]
# ## How to run workflow with validation?

# %% [markdown]
# Here, our FLOW will utilize the overall task you have provided to automatically generate the subtasks and agents within the workflow. When providing an overall task, please endeavor to articulate your requirements with clarity, including the desired output format and the specific content you expect. The more detailed your description, the more refined and accurate the results will be.

# %% [markdown]
# ### Requirement
# You need to have an OpenAI API Key.
# Notice that our default model is gpt-4o-mini, please feel free to replace it with the model you wish to use.
# However, for this case, we recommend use a reasoning-optimized GPT model, such as `"o1-mini"` or `"o3-mini"`.

# %%
import os
import sys

# Add the parent folder to the path
sys.path.append(os.path.abspath(".."))

from config import Config

Config.set("OPENAI_API_KEY", "your-api-key")
Config.set("GPT_MODEL", "o3-mini")

# %% [markdown]
# ### Import necessary module

# %%
import asyncio
import nest_asyncio
import json
from flow import Flow
from summary import Summary

# %% [markdown]
# ### Set your overall task

# %% [markdown]
# As you can observe, we have furnished an example herein for generating a website that contains context of ICLR 2025. Within this overall task, we have delineated the requisite output format along with the specific content details. At the very bottom of this notebook, you are able to witness the outcome of the execution.

# %%
overall_task: str = '''Develop a game that fuses Tetris and Bejeweled mechanics. 
Falling tetrominoes should lock into a grid and transform into colored gems. 
The game must support both Tetris line-clearing and Bejeweled match-3 clearing, triggering chain reactions and bonus points. 
Include a GUI (using a framework like Pygame) that displays the game grid, current score, and next tetromino preview, along with smooth animations.
No sound effects are needed'''

# %% [markdown]
# ### Set Model
# We recommend modifying the model setting in `config.py` to use a reasoning-optimized GPT model, such as `"o1-mini"` or `"o3-mini"`.

# %% [markdown]
# ### Run your workflow
#
# Here are some parameter explanations for the following code:
# refine_threshold: Refinement will be triggered after completing the threshold amount of subtasks.
# max_refine_itt: The number of max refine iteration times.
# n_candidate_graphs: The number of candidate workflow graphs.
# workflow: Predefined workflow, here should be None.
# max_validation_itt: The number of max validation iteration times.

# %%
manager = Flow(overall_task = overall_task, refine_threshold = 3, max_refine_itt=5, n_candidate_graphs=10, workflow=None, max_validation_itt=4)
nest_asyncio.apply()
asyncio.run(manager.run_async())
# Out:
# 2025-03-19 20:49:14 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-19 20:49:14 [INFO] GPT Response: ```json
# {
#   "task": "Develop a game that fuses Tetris and Bejeweled mechanics",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall game architecture, including the fusion of Tetris and Bejeweled mechanics."
#     },
#     {
#       "id": 1,
#       "objective": "Develop the core game logic that handles tetromino falling, grid locking, and transformation into gems."
#     },
#     {
#       "id": 2,
#       "objective": "Implement the match-3 mechanics that allow for gem clearing and triggering chain reactions."
#     },
#     {
#       "id": 3,
#       "objective": "Create the graphical user interface (GUI) using Pygame to display the game grid, current score, and next tetromino preview, including animations."
#     },
#     {
#       "id": 4,
#       "objective": "Implement scoring and bonus point systems to reward players for line clears and chain reactions."
#     },
#     {
#       "id": 5,
#       "objective": "Test and ensure the integration of game logic, mechanics, and GUI for a seamless player experience."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 1, "child": 3 },
#     { "parent": 2, "child": 3 },
#     { "parent": 1, "child": 4 },
#     { "parent": 2, "child": 4 },
#     { "parent": 3, "child": 5 },
#     { "parent": 4, "child": 5 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "Game Designer",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Game Logic Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Match-3 Mechanic Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "GUI Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Scoring Mechanic Developer",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "Quality Assurance Tester",
#       "subtasks": [5]
#     }
#   ]
# }
# ```
# 2025-03-19 20:49:15 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-19 20:49:15 [INFO] GPT Response: ```json
# {
#   "task": "Develop a Game that Fuses Tetris and Bejeweled Mechanics",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall game architecture, including mechanics for falling tetrominoes and gem transformation."
#     },
#     {
#       "id": 1,
#       "objective": "Implement the Tetris mechanics for tetromino movement and rotation on the grid."
#     },
#     {
#       "id": 2,
#       "objective": "Develop the gem transformation logic that converts locked tetrominoes into colored gems."
#     },
#     {
#       "id": 3,
#       "objective": "Implement the Bejeweled mechanics for match-3 clearing and chain reactions."
#     },
#     {
#       "id": 4,
#       "objective": "Create the graphical user interface (GUI) using Pygame to display game elements like the grid, score, and next tetromino preview."
#     },
#     {
#       "id": 5,
#       "objective": "Integrate all game components to ensure the transition from Tetris to Bejeweled mechanics triggers correctly with animations."
#     },
#     {
#       "id": 6,
#       "objective": "Conduct a review and fine-tune gameplay mechanics for optimal performance and balance."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 0, "child": 3 },
#     { "parent": 1, "child": 5 },
#     { "parent": 2, "child": 5 },
#     { "parent": 3, "child": 5 },
#     { "parent": 4, "child": 5 },
#     { "parent": 5, "child": 6 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "Game Designer",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Tetris Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Gem Logic Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "Bejeweled Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "GUI Developer",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "Integration Specialist",
#       "subtasks": [5]
#     },
#     {
#       "id": "Agent 6",
#       "role": "Gameplay Balancer",
#       "subtasks": [6]
#     }
#   ]
# }
# ```
# 2025-03-19 20:49:16 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-19 20:49:16 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-19 20:49:16 [INFO] GPT Response: ```json
# {
#   "task": "Develop a game that fuses Tetris and Bejeweled mechanics",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the game mechanics and rules, including Tetris line-clearing and Bejeweled match-3 interactions."
#     },
#     {
#       "id": 1,
#       "objective": "Implement the game logic for falling tetrominoes, grid locking, and transformation into colored gems."
#     },
#     {
#       "id": 2,
#       "objective": "Create the scoring system that rewards players for combinations, chain reactions, and clearing lines."
#     },
#     {
#       "id": 3,
#       "objective": "Develop the graphical user interface (GUI) using Pygame, including the game grid, current score display, and next tetromino preview."
#     },
#     {
#       "id": 4,
#       "objective": "Incorporate animations to ensure smooth transitions and effects during tetromino drops, gem transformations, and clearances."
#     },
#     {
#       "id": 5,
#       "objective": "Integrate all components into a cohesive game structure, ensuring proper interactions between game logic, scoring, and GUI."
#     },
#     {
#       "id": 6,
#       "objective": "Conduct user interface optimizations and finalize the game's visual and interaction design."
#     },
#     {
#       "id": 7,
#       "objective": "Prepare the game for deployment and ensure it runs seamlessly across supported platforms."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 1, "child": 3 },
#     { "parent": 1, "child": 5 },
#     { "parent": 2, "child": 5 },
#     { "parent": 3, "child": 4 },
#     { "parent": 4, "child": 5 },
#     { "parent": 5, "child": 6 },
#     { "parent": 6, "child": 7 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "Game Designer",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Game Logic Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Scoring System Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "GUI Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Animation Specialist",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "Integration Engineer",
#       "subtasks": [5]
#     },
#     {
#       "id": "Agent 6",
#       "role": "UI/UX Optimizer",
#       "subtasks": [6]
#     },
#     {
#       "id": "Agent 7",
#       "role": "Deployment Engineer",
#       "subtasks": [7]
#     }
#   ]
# }
# ```
# 2025-03-19 20:49:16 [INFO] GPT Response: ```json
# {
#   "task": "Develop a game that fuses Tetris and Bejeweled mechanics",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall game architecture, including the mechanics for Tetris and Bejeweled integration."
#     },
#     {
#       "id": 1,
#       "objective": "Develop the core game mechanics for Tetris including tetromino generation, movement, and locking into the grid."
#     },
#     {
#       "id": 2,
#       "objective": "Implement the mechanics for gem transformation and match-3 checking for Bejeweled style clearing."
#     },
#     {
#       "id": 3,
#       "objective": "Create the game's graphical user interface (GUI) using a framework like Pygame, including the game grid, current score, and next tetromino preview."
#     },
#     {
#       "id": 4,
#       "objective": "Develop the animation system to ensure smooth transitions and movements of tetrominoes and gem clearing effects."
#     },
#     {
#       "id": 5,
#       "objective": "Combine the Tetris and Bejeweled mechanics to allow for chain reactions and scoring dynamics."
#     },
#     {
#       "id": 6,
#       "objective": "Test and finalize the integrated gameplay experience, ensuring balance and enjoyment."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 0, "child": 3 },
#     { "parent": 1, "child": 4 },
#     { "parent": 2, "child": 5 },
#     { "parent": 3, "child": 5 },
#     { "parent": 4, "child": 5 },
#     { "parent": 5, "child": 6 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "Game Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Tetris Mechanic Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Bejeweled Mechanic Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "GUI Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Animation Specialist",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "Gameplay Integrator",
#       "subtasks": [5]
#     },
#     {
#       "id": "Agent 6",
#       "role": "Game Tester",
#       "subtasks": [6]
#     }
#   ]
# }
# ```
# 2025-03-19 20:49:16 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-19 20:49:16 [INFO] GPT Response: ```json
# {
#   "task": "Develop a game that fuses Tetris and Bejeweled mechanics",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall game architecture, including game rules and mechanics for Tetris and Bejeweled fusion."
#     },
#     {
#       "id": 1,
#       "objective": "Implement the tetromino generation and falling mechanics, ensuring proper locking into the grid."
#     },
#     {
#       "id": 2,
#       "objective": "Develop the gem transformation logic that converts locked tetrominoes into colored gems."
#     },
#     {
#       "id": 3,
#       "objective": "Create the match-3 clearing mechanics based on Bejeweled rules, triggering chain reactions and bonus scoring."
#     },
#     {
#       "id": 4,
#       "objective": "Design and implement the graphical user interface (GUI) using Pygame, including game grid, score display, and next tetromino preview."
#     },
#     {
#       "id": 5,
#       "objective": "Integrate the gameplay components, ensuring that the tetromino falling, gem transformation, and match-3 mechanics work smoothly together."
#     },
#     {
#       "id": 6,
#       "objective": "Test the overall gameplay to ensure all mechanics function correctly and the user experience is smooth."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 0, "child": 3 },
#     { "parent": 1, "child": 5 },
#     { "parent": 2, "child": 5 },
#     { "parent": 3, "child": 5 },
#     { "parent": 0, "child": 4 },
#     { "parent": 5, "child": 6 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "Game Designer",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Gameplay Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Gem Logic Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "Match-3 Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "GUI Developer",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "Integration Tester",
#       "subtasks": [5]
#     },
#     {
#       "id": "Agent 6",
#       "role": "Gameplay Tester",
#       "subtasks": [6]
#     }
#   ]
# }
# ```
# 2025-03-19 20:49:17 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-19 20:49:17 [INFO] GPT Response: ```json
# {
#   "task": "Develop a game that fuses Tetris and Bejeweled mechanics",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the game architecture and document the interaction between Tetris and Bejeweled mechanics."
#     },
#     {
#       "id": 1,
#       "objective": "Develop the core game logic that handles tetromino falling, grid locking, and gem transformation."
#     },
#     {
#       "id": 2,
#       "objective": "Implement the Tetris line-clearing mechanism and match-3 clearing logic for gems."
#     },
#     {
#       "id": 3,
#       "objective": "Create the graphical user interface (GUI) using Pygame, including the game grid, score display, and next tetromino preview."
#     },
#     {
#       "id": 4,
#       "objective": "Integrate animations for tetromino movements, locking into the grid, and gem transformations."
#     },
#     {
#       "id": 5,
#       "objective": "Combine all components and ensure smooth gameplay and interactions between Tetris and Bejeweled mechanics."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 1, "child": 2 },
#     { "parent": 0, "child": 3 },
#     { "parent": 1, "child": 4 },
#     { "parent": 3, "child": 5 },
#     { "parent": 2, "child": 5 },
#     { "parent": 4, "child": 5 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "Game Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Game Logic Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Mechanics Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "GUI Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Animation Specialist",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "Integration Engineer",
#       "subtasks": [5]
#     }
#   ]
# }
# ```
# 2025-03-19 20:49:17 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-19 20:49:17 [INFO] GPT Response: ```json
# {
#   "task": "Develop a game that fuses Tetris and Bejeweled mechanics",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the game architecture, defining the core gameplay mechanics combining Tetris and Bejeweled."
#     },
#     {
#       "id": 1,
#       "objective": "Develop the logic for falling tetrominoes, ensuring they lock into the grid appropriately and turn into colored gems."
#     },
#     {
#       "id": 2,
#       "objective": "Implement the Tetris line-clearing mechanic that interacts with the grid and triggers chain reactions."
#     },
#     {
#       "id": 3,
#       "objective": "Create the match-3 gem-clearing mechanism to allow for Bejeweled-style interactions and combinations."
#     },
#     {
#       "id": 4,
#       "objective": "Develop the game GUI using Pygame, which includes the grid display, current score, and next tetromino preview."
#     },
#     {
#       "id": 5,
#       "objective": "Implement smooth animations for the tetromino transitions and gem transformations within the GUI."
#     },
#     {
#       "id": 6,
#       "objective": "Integrate all game mechanics, ensuring that Tetris and Bejeweled features work harmoniously and provide feedback to the player."
#     },
#     {
#       "id": 7,
#       "objective": "Conduct final optimizations and prepare the game for deployment, ensuring all features are functional and the performance is smooth."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 0, "child": 3 },
#     { "parent": 1, "child": 6 },
#     { "parent": 2, "child": 6 },
#     { "parent": 3, "child": 6 },
#     { "parent": 0, "child": 4 },
#     { "parent": 4, "child": 5 },
#     { "parent": 5, "child": 6 },
#     { "parent": 6, "child": 7 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "Game Designer",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Game Logic Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Tetris Mechanic Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "Bejeweled Mechanic Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "GUI Developer",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "Animation Specialist",
#       "subtasks": [5]
#     },
#     {
#       "id": "Agent 6",
#       "role": "Integration Engineer",
#       "subtasks": [6]
#     },
#     {
#       "id": "Agent 7",
#       "role": "Optimization Specialist",
#       "subtasks": [7]
#     }
#   ]
# }
# ```
# 2025-03-19 20:49:17 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-19 20:49:17 [INFO] GPT Response: ```json
# {
#   "task": "Develop a game that fuses Tetris and Bejeweled mechanics",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the game architecture and define core mechanics for the fusion of Tetris and Bejeweled."
#     },
#     {
#       "id": 1,
#       "objective": "Implement tetromino generation and falling mechanics, ensuring they lock into a grid."
#     },
#     {
#       "id": 2,
#       "objective": "Create the gem transformation logic that converts tetrominoes into colored gems upon landing."
#     },
#     {
#       "id": 3,
#       "objective": "Develop the line-clearing logic for Tetris mechanics, ensuring completed lines trigger appropriate clearing."
#     },
#     {
#       "id": 4,
#       "objective": "Implement the match-3 clearing logic for the Bejeweled mechanics, enabling chain reactions and score calculations."
#     },
#     {
#       "id": 5,
#       "objective": "Design and implement the GUI with Pygame to display the game grid, current score, and next tetromino preview."
#     },
#     {
#       "id": 6,
#       "objective": "Develop game animations for tetromino drops, gem transformations, and clearing effects to ensure smooth gameplay."
#     },
#     {
#       "id": 7,
#       "objective": "Perform integration of all game mechanics and UI components to ensure they work cohesively."
#     },
#     {
#       "id": 8,
#       "objective": "Conduct final testing of the integrated game for functionality and performance, adjusting as needed."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 1, "child": 3 },
#     { "parent": 1, "child": 4 },
#     { "parent": 0, "child": 5 },
#     { "parent": 5, "child": 6 },
#     { "parent": 3, "child": 7 },
#     { "parent": 4, "child": 7 },
#     { "parent": 6, "child": 7 },
#     { "parent": 7, "child": 8 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "Game Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Tetris Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Gem Transformation Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "Tetris Mechanic Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Bejeweled Mechanic Developer",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "GUI Developer",
#       "subtasks": [5]
#     },
#     {
#       "id": "Agent 6",
#       "role": "Animator",
#       "subtasks": [6]
#     },
#     {
#       "id": "Agent 7",
#       "role": "Integration Specialist",
#       "subtasks": [7]
#     },
#     {
#       "id": "Agent 8",
#       "role": "Game Tester",
#       "subtasks": [8]
#     }
#   ]
# }
# ```
# 2025-03-19 20:49:18 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-19 20:49:18 [INFO] GPT Response: ```json
# {
#   "task": "Develop a game that fuses Tetris and Bejeweled mechanics",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall game architecture and define the mechanics for combining Tetris and Bejeweled functionalities."
#     },
#     {
#       "id": 1,
#       "objective": "Implement the Tetris mechanics including tetromino generation, movement, and rotation logic."
#     },
#     {
#       "id": 2,
#       "objective": "Create the gem transformation logic that converts locked tetrominoes into colored gems in the grid."
#     },
#     {
#       "id": 3,
#       "objective": "Develop the Bejeweled mechanics for match-3 clearing, chain reactions, and bonus points."
#     },
#     {
#       "id": 4,
#       "objective": "Implement the GUI using a framework like Pygame that includes the game grid, current score display, and next tetromino preview."
#     },
#     {
#       "id": 5,
#       "objective": "Integrate all mechanics and GUI components to ensure the game functions smoothly and cohesively."
#     },
#     {
#       "id": 6,
#       "objective": "Optimize performance and ensure smooth animations for animations and transitions in the game."
#     },
#     {
#       "id": 7,
#       "objective": "Conduct final adjustments and tweaks for gameplay balance and ensure responsiveness."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 0, "child": 3 },
#     { "parent": 1, "child": 5 },
#     { "parent": 2, "child": 5 },
#     { "parent": 3, "child": 5 },
#     { "parent": 4, "child": 5 },
#     { "parent": 5, "child": 6 },
#     { "parent": 6, "child": 7 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "Game Designer",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Tetris Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Gem Transformation Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "Bejeweled Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "GUI Developer",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "Integration Engineer",
#       "subtasks": [5]
#     },
#     {
#       "id": "Agent 6",
#       "role": "Performance Optimizer",
#       "subtasks": [6]
#     },
#     {
#       "id": "Agent 7",
#       "role": "Quality Assurance Specialist",
#       "subtasks": [7]
#     }
#   ]
# }
# ```
# 2025-03-19 20:49:20 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-19 20:49:20 [INFO] GPT Response: ```json
# {
#   "task": "Develop a Tetris and Bejeweled Fusion Game",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the game architecture, including the core mechanics for tetromino and gem interactions."
#     },
#     {
#       "id": 1,
#       "objective": "Implement the tetromino falling and locking mechanism within the game grid."
#     },
#     {
#       "id": 2,
#       "objective": "Develop the gem transformation logic that converts locked tetrominoes into colored gems."
#     },
#     {
#       "id": 3,
#       "objective": "Create the line-clearing functionality based on Tetris rules."
#     },
#     {
#       "id": 4,
#       "objective": "Implement match-3 mechanics that allow players to clear gems in Bejeweled style."
#     },
#     {
#       "id": 5,
#       "objective": "Develop the chain reaction logic that triggers bonus points for consecutive clears."
#     },
#     {
#       "id": 6,
#       "objective": "Create a graphical user interface (GUI) using Pygame to display the game grid, score, and next tetromino preview."
#     },
#     {
#       "id": 7,
#       "objective": "Implement smooth animations for tetromino movements and gem clearing effects within the GUI."
#     },
#     {
#       "id": 8,
#       "objective": "Integrate all components and ensure the game functions cohesively, supporting both Tetris and Bejeweled mechanics."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 1, "child": 3 },
#     { "parent": 2, "child": 4 },
#     { "parent": 3, "child": 5 },
#     { "parent": 6, "child": 7 },
#     { "parent": 1, "child": 8 },
#     { "parent": 2, "child": 8 },
#     { "parent": 3, "child": 8 },
#     { "parent": 4, "child": 8 },
#     { "parent": 5, "child": 8 },
#     { "parent": 6, "child": 8 },
#     { "parent": 7, "child": 8 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "Game Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Gameplay Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Game Mechanic Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "Tetris Functionality Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Bejeweled Functionality Developer",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "Chain Reaction Developer",
#       "subtasks": [5]
#     },
#     {
#       "id": "Agent 6",
#       "role": "GUI Developer",
#       "subtasks": [6]
#     },
#     {
#       "id": "Agent 7",
#       "role": "Animation Developer",
#       "subtasks": [7]
#     },
#     {
#       "id": "Agent 8",
#       "role": "Integration Specialist",
#       "subtasks": [8]
#     }
#   ]
# }
# ```
# 2025-03-19 20:49:20 [INFO] Executing task 'Design the overall game architecture, including the fusion of Tetris and Bejeweled mechanics.' with context: No completed previous tasks context available....
# 2025-03-19 20:49:20 [INFO] Task 'Design the overall game architecture, including the fusion of Tetris and Bejeweled mechanics.' started by agent '0'.
# Comparing...
#  Here is the detailed data.
# Dependency complexities:
# [0.4714045207910317, 1.2777531299998799, 0.82915619758885, 0.880630571852711, 1.1605769149479943, 0.4714045207910317, 1.224744871391589, 0.9162456945817024, 1.1989578808281798, 1.5234788000891208]
# Parallelisms:
# [2.75, 3.25, 2.0, 2.2, 2.75, 2.0, 2.8, 2.6, 3.4, 3.0]
# ***********run start*********************
#
#
# "# **Instructions:**
# "
# "1. Solve only your assigned subtask, referring to the context only if necessary.
# "
# "2. Ensure your solution aligns with the overall goal and is formatted so that it can be directly used as input for downstream tasks.
# "
# "3. Do not repeat any previous output verbatim.
# "
# "4. Output required result without adding any justifications."
# "5. Strictly follow the format constraint."
# ---
#
# # **The Overall Goal**
# Develop a game that fuses Tetris and Bejeweled mechanics.
# Falling tetrominoes should lock into a grid and transform into colored gems.
# The game must support both Tetris line-clearing and Bejeweled match-3 clearing, triggering chain reactions and bonus points.
# Include a GUI (using a framework like Pygame) that displays the game grid, current score, and next tetromino preview, along with smooth animations.
# No sound effects are needed
#
# ---
#
# # **Context from Upstream Tasks**
# No completed previous tasks context available.
#
# ---
#
# # **Downstream Tasks objectivesv**
# Task task1:
#   Objective: Develop the core game logic that handles tetromino falling, grid locking, and transformation into gems.
# Task task2:
#   Objective: Implement the match-3 mechanics that allow for gem clearing and triggering chain reactions.
#
#
# ---
#
# # **Current Task Requirements**
# Design the overall game architecture, including the fusion of Tetris and Bejeweled mechanics.
#
# ---
#
#
# ***********run end*********************
# 2025-03-19 20:49:28 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ------Run pythonValidator.is_python_code()------
# 2025-03-19 20:49:28 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-19 20:49:44 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ***********run start*********************
#
# "# **Instructions:**
# "
# "1. You need to revise the subtask results based on the latest feedback and historical information.
# "
# "2. Output required result without adding any justifications."
# "3. Strictly follow the format constraint."
# ---
#
# # **The Overall Goal**
# Develop a game that fuses Tetris and Bejeweled mechanics.
# Falling tetrominoes should lock into a grid and transform into colored gems.
# The game must support both Tetris line-clearing and Bejeweled match-3 clearing, triggering chain reactions and bonus points.
# Include a GUI (using a framework like Pygame) that displays the game grid, current score, and next tetromino preview, along with smooth animations.
# No sound effects are needed
#
# ---
#
# # **Context from Upstream Tasks**
# No completed previous tasks context available.
#
# ---
#
# # **Downstream Tasks objectives**
# Task task1:
#   Objective: Develop the core game logic that handles tetromino falling, grid locking, and transformation into gems.
# Task task2:
#   Objective: Implement the match-3 mechanics that allow for gem clearing and triggering chain reactions.
#
# ---
#
# # **Current Task Requirements**
# Design the overall game architecture, including the fusion of Tetris and Bejeweled mechanics.
#
# ---
#
# # **Current Task Historical Results and Their Feedbacks**
# ---
# ## **revision 0**
# # Game Architecture Design for Tetris-Bejeweled Fusion
#
# ## 1. Game Components
# - **Grid**: A 2D array representing the game area (e.g., 10 columns x 20 rows).
# - **Tetrominoes**: Various shapes (I, O, T, S, Z, J, L) that can fall and occupy grid spaces.
# - **Gems**: Colored blocks representing the transformed tetrominoes after locking.
# - **Score System**: Tracks the player's score, updating for line clears and gem matches.
# - **Game States**: Main menu, playing, paused, and game over states.
#
# ## 2. Game Logic
# ### 2.1 Tetromino Management
# - **Spawn**: Randomly generate a tetromino at the top of the grid.
# - **Movement**: Control tetromino movement (left, right, down) and rotation.
# - **Locking Mechanism**: When a tetromino cannot move down further, it locks into the grid, transforming into gems.
#
# ### 2.2 Grid Interaction
# - **Line Clearing**: Check for complete rows; remove completed rows and shift everything above down.
# - **Transformation**: Upon locking, convert locked tetrominoes into random colored gems.
#
# ## 3. Match-3 Mechanics (Overview)
# - **Gem Matching**: Check for groups of three or more adjacent gems of the same color.
# - **Clearing Gems**: Remove matched gems and trigger cascading clears if new matches occur.
# - **Score Update**: Increment the score based on the number of cleared gems and chains.
#
# ## 4. User Interface (GUI)
# ### 4.1 Layout
# - **Game Grid Display**: Render the grid and current state (tetrominoes and gems).
# - **Score Display**: Show current score prominently on the screen.
# - **Next Tetromino Preview**: Display the next tetromino that will fall.
#
# ### 4.2 Animations
# - **Falling Tetrominoes**: Smooth dropping animations as tetrominoes move down.
# - **Gem Transformations**: Visual effects for transforming tetrominoes into gems.
# - **Clearing Effects**: Animate the process of clearing matched gems.
#
# ## 5. Additional Features
# - **Difficulty Scaling**: Increase speed and frequency of tetromino drops as the score rises.
# - **Power-ups**: Implement special gems that can clear larger areas or all gems of a color.
#
# ## 6. Implementation Framework
# - **Game Development Framework**: Use Pygame for rendering, input handling, and animations.
#
# ## 7. Development Plan
# 1. Create the grid and implement tetromino spawning and locking logic.
# 2. Implement gem transformation and line clearing.
# 3. Develop match-3 detection and clearing mechanisms.
# 4. Design and implement the GUI components.
# 5. Integrate animations for a smooth player experience.
# 6. Test and refine gameplay mechanics for balance.
#
# This architecture serves as a foundational blueprint for development, guiding modular implementation of core features and interactions within the game.
#
# ## **Feedbacks to the revision
# Here are some feedbacks:
# 1. **Completeness and Clarity**: The design is generally comprehensive but could be more detailed in a few areas. Specifically, the interaction between Tetris and Bejeweled mechanics could benefit from additional explanation, such as how the transition between different gameplay elements occurs.
# 2. **Game Logic**: While the tetromino management and line clearing are well-addressed, clarifying how gem matching is integrated with the dropping of tetrominoes would enhance understanding of the gameplay flow.
# 3. **User Interface**: The UI section could include more specific details about controls (e.g., how the player interacts with the game) and feedback mechanisms (e.g., sound or visual cues for actions).
# 4. **Development Plan**: The steps could be more explicitly tied to the game mechanics detailed earlier in the document, ensuring clarity on how each step contributes to the overall architecture.
#
# Here are the changes:
# # Game Architecture Design for Tetris-Bejeweled Fusion
#
# ## 1. Game Components
# - **Grid**: A 2D array representing the game area (e.g., 10 columns x 20 rows).
# - **Tetrominoes**: Various shapes (I, O, T, S, Z, J, L) that can fall and occupy grid spaces.
# - **Gems**: Colored blocks representing the transformed tetrominoes after locking.
# - **Score System**: Tracks the player's score, updating for line clears and gem matches.
# - **Game States**: Main menu, playing, paused, and game over states.
# - **Controls**: Player controls for moving (left, right, down), rotating tetrominoes, and initiating special gem powers.
#
# ## 2. Game Logic
# ### 2.1 Tetromino Management
# - **Spawn**: Randomly generate a tetromino at the top of the grid.
# - **Movement**: Control tetromino movement (left, right, down) and rotation.
# - **Locking Mechanism**: When a tetromino cannot move down further, it locks into the grid, transforming into gems.
#
# ### 2.2 Grid Interaction
# - **Line Clearing**: Check for complete rows; remove completed rows and shift everything above down.
# - **Transformation**: Upon locking, convert locked tetrominoes into random colored gems.
# - **Interaction with Gems**: If a tetromino locks in a position that creates an adjacent gem formation, immediately trigger the gem matching mechanics.
#
# ## 3. Match-3 Mechanics (Overview)
# - **Gem Matching**: Check for groups of three or more adjacent gems of the same color.
# - **Clearing Gems**: Remove matched gems and trigger cascading clears if new matches occur.
# - **Cascading Effects**: After a tetromino locks, if a matching area occurs, it should trigger a clear and may lead to another score increment based on chain reactions.
# - **Score Update**: Increment the score based on the number of cleared gems and any consequential chains.
#
# ## 4. User Interface (GUI)
# ### 4.1 Layout
# - **Game Grid Display**: Render the grid and current state (tetrominoes and gems).
# - **Score Display**: Show current score prominently on the screen.
# - **Next Tetromino Preview**: Display the next tetromino that will fall.
# - **Controls Display**: Provide a reference for player controls (instructions on how to play and activate power-ups).
#
# ### 4.2 Animations
# - **Falling Tetrominoes**: Smooth dropping animations as tetrominoes move down.
# - **Gem Transformations**: Visual effects for transforming tetrominoes into gems.
# - **Clearing Effects**: Animate the process of clearing matched gems, with sound and visual cues to signal successful actions.
#
# ## 5. Additional Features
# - **Difficulty Scaling**: Increase speed and frequency of tetromino drops as the score rises.
# - **Power-ups**: Implement special gems that can clear larger areas or all gems of a color; these should be visually distinct to make them noticeable.
#
# ## 6. Implementation Framework
# - **Game Development Framework**: Use Pygame for rendering, input handling, and animations.
#
# ## 7. Development Plan
# 1. Create the grid and implement tetromino spawning and locking logic.
# 2. Implement gem transformation and line clearing.
# 3. Integrate interaction mechanics with gem matching post-tetromino lock.
# 4. Develop match-3 detection and clearing mechanisms.
# 5. Design and implement the GUI components, including control instructions.
# 6. Integrate animations for a smooth player experience with feedback.
# 7. Test and refine gameplay mechanics for balance.
#
# This architecture serves as a foundational blueprint for development, guiding modular implementation of core features and interactions within the game, while ensuring clarity and player engagement.**
#
#
# ---
#
# ***********run end*********************
# 2025-03-19 20:49:54 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ------Run pythonValidator.is_python_code()------
# 2025-03-19 20:49:54 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-19 20:49:55 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-19 20:49:55 [INFO] Task task0 done. Total completed so far: 1
# 2025-03-19 20:49:55 [INFO] Executing task 'Develop the core game logic that handles tetromino falling, grid locking, and transformation into gems.' with context: Task task0:
#   Objective: Design the overall game architecture, including the fusion of Tetris and Be...
# 2025-03-19 20:49:55 [INFO] Task 'Develop the core game logic that handles tetromino falling, grid locking, and transformation into gems.' started by agent '1'.
# 2025-03-19 20:49:55 [INFO] Executing task 'Implement the match-3 mechanics that allow for gem clearing and triggering chain reactions.' with context: Task task0:
#   Objective: Design the overall game architecture, including the fusion of Tetris and Be...
# 2025-03-19 20:49:55 [INFO] Task 'Implement the match-3 mechanics that allow for gem clearing and triggering chain reactions.' started by agent '2'.
# task0 ---Final status: completed
# 1 3
# ***********run start*********************
#
#
# "# **Instructions:**
# "
# "1. Solve only your assigned subtask, referring to the context only if necessary.
# "
# "2. Ensure your solution aligns with the overall goal and is formatted so that it can be directly used as input for downstream tasks.
# "
# "3. Do not repeat any previous output verbatim.
# "
# "4. Output required result without adding any justifications."
# "5. Strictly follow the format constraint."
# ---
#
# # **The Overall Goal**
# Develop a game that fuses Tetris and Bejeweled mechanics.
# Falling tetrominoes should lock into a grid and transform into colored gems.
# The game must support both Tetris line-clearing and Bejeweled match-3 clearing, triggering chain reactions and bonus points.
# Include a GUI (using a framework like Pygame) that displays the game grid, current score, and next tetromino preview, along with smooth animations.
# No sound effects are needed
#
# ---
#
# # **Context from Upstream Tasks**
# Task task0:
#   Objective: Design the overall game architecture, including the fusion of Tetris and Bejeweled mechanics.
#   Result: # Game Architecture Design for Tetris-Bejeweled Fusion
#
# ## 1. Game Components
# - **Grid**: A 2D array representing the game area (e.g., 10 columns x 20 rows).
# - **Tetrominoes**: Various shapes (I, O, T, S, Z, J, L) that can fall and occupy grid spaces.
# - **Gems**: Colored blocks representing the transformed tetrominoes after locking.
# - **Score System**: Tracks the player's score, updating for line clears and gem matches.
# - **Game States**: Main menu, playing, paused, and game over states.
# - **Controls**: Player controls for moving (left, right, down), rotating tetrominoes, and initiating special gem powers.
#
# ## 2. Game Logic
# ### 2.1 Tetromino Management
# - **Spawn**: Randomly generate a tetromino at the top of the grid.
# - **Movement**: Control tetromino movement (left, right, down) and rotation.
# - **Locking Mechanism**: When a tetromino cannot move down further, it locks into the grid, transforming into gems.
#
# ### 2.2 Grid Interaction
# - **Line Clearing**: Check for complete rows; remove completed rows and shift everything above down.
# - **Transformation**: Upon locking, convert locked tetrominoes into random colored gems.
# - **Interaction with Gems**: If a tetromino locks in a position that creates an adjacent gem formation, immediately trigger the gem matching mechanics.
#
# ## 3. Match-3 Mechanics (Overview)
# - **Gem Matching**: Check for groups of three or more adjacent gems of the same color.
# - **Clearing Gems**: Remove matched gems and trigger cascading clears if new matches occur.
# - **Cascading Effects**: After a tetromino locks, if a matching area occurs, it should trigger a clear and may lead to another score increment based on chain reactions.
# - **Score Update**: Increment the score based on the number of cleared gems and any consequential chains.
#
# ## 4. User Interface (GUI)
# ### 4.1 Layout
# - **Game Grid Display**: Render the grid and current state (tetrominoes and gems).
# - **Score Display**: Show current score prominently on the screen.
# - **Next Tetromino Preview**: Display the next tetromino that will fall.
# - **Controls Display**: Provide a reference for player controls (instructions on how to play and activate power-ups).
#
# ### 4.2 Animations
# - **Falling Tetrominoes**: Smooth dropping animations as tetrominoes move down.
# - **Gem Transformations**: Visual effects for transforming tetrominoes into gems.
# - **Clearing Effects**: Animate the process of clearing matched gems, with visual cues to signal successful actions.
#
# ## 5. Additional Features
# - **Difficulty Scaling**: Increase speed and frequency of tetromino drops as the score rises.
# - **Power-ups**: Implement special gems that can clear larger areas or all gems of a color; these should be visually distinct to make them noticeable.
#
# ## 6. Implementation Framework
# - **Game Development Framework**: Use Pygame for rendering, input handling, and animations.
#
# ## 7. Development Plan
# 1. Create the grid and implement tetromino spawning and locking logic.
# 2. Implement gem transformation and line clearing.
# 3. Integrate interaction mechanics with gem matching post-tetromino lock.
# 4. Develop match-3 detection and clearing mechanisms.
# 5. Design and implement the GUI components, including control instructions.
# 6. Integrate animations for a smooth player experience with feedback.
# 7. Test and refine gameplay mechanics for balance.
#
# This architecture serves as a foundational blueprint for development, guiding modular implementation of core features and interactions within the game, while ensuring clarity and player engagement.
#
# ---
#
# # **Downstream Tasks objectivesv**
# Task task3:
#   Objective: Create the graphical user interface (GUI) using Pygame to display the game grid, current score, and next tetromino preview, including animations.
# Task task4:
#   Objective: Implement scoring and bonus point systems to reward players for line clears and chain reactions.
#
#
# ---
#
# # **Current Task Requirements**
# Develop the core game logic that handles tetromino falling, grid locking, and transformation into gems.
#
# ---
#
#
# ***********run end*********************
# ***********run start*********************
#
#
# "# **Instructions:**
# "
# "1. Solve only your assigned subtask, referring to the context only if necessary.
# "
# "2. Ensure your solution aligns with the overall goal and is formatted so that it can be directly used as input for downstream tasks.
# "
# "3. Do not repeat any previous output verbatim.
# "
# "4. Output required result without adding any justifications."
# "5. Strictly follow the format constraint."
# ---
#
# # **The Overall Goal**
# Develop a game that fuses Tetris and Bejeweled mechanics.
# Falling tetrominoes should lock into a grid and transform into colored gems.
# The game must support both Tetris line-clearing and Bejeweled match-3 clearing, triggering chain reactions and bonus points.
# Include a GUI (using a framework like Pygame) that displays the game grid, current score, and next tetromino preview, along with smooth animations.
# No sound effects are needed
#
# ---
#
# # **Context from Upstream Tasks**
# Task task0:
#   Objective: Design the overall game architecture, including the fusion of Tetris and Bejeweled mechanics.
#   Result: # Game Architecture Design for Tetris-Bejeweled Fusion
#
# ## 1. Game Components
# - **Grid**: A 2D array representing the game area (e.g., 10 columns x 20 rows).
# - **Tetrominoes**: Various shapes (I, O, T, S, Z, J, L) that can fall and occupy grid spaces.
# - **Gems**: Colored blocks representing the transformed tetrominoes after locking.
# - **Score System**: Tracks the player's score, updating for line clears and gem matches.
# - **Game States**: Main menu, playing, paused, and game over states.
# - **Controls**: Player controls for moving (left, right, down), rotating tetrominoes, and initiating special gem powers.
#
# ## 2. Game Logic
# ### 2.1 Tetromino Management
# - **Spawn**: Randomly generate a tetromino at the top of the grid.
# - **Movement**: Control tetromino movement (left, right, down) and rotation.
# - **Locking Mechanism**: When a tetromino cannot move down further, it locks into the grid, transforming into gems.
#
# ### 2.2 Grid Interaction
# - **Line Clearing**: Check for complete rows; remove completed rows and shift everything above down.
# - **Transformation**: Upon locking, convert locked tetrominoes into random colored gems.
# - **Interaction with Gems**: If a tetromino locks in a position that creates an adjacent gem formation, immediately trigger the gem matching mechanics.
#
# ## 3. Match-3 Mechanics (Overview)
# - **Gem Matching**: Check for groups of three or more adjacent gems of the same color.
# - **Clearing Gems**: Remove matched gems and trigger cascading clears if new matches occur.
# - **Cascading Effects**: After a tetromino locks, if a matching area occurs, it should trigger a clear and may lead to another score increment based on chain reactions.
# - **Score Update**: Increment the score based on the number of cleared gems and any consequential chains.
#
# ## 4. User Interface (GUI)
# ### 4.1 Layout
# - **Game Grid Display**: Render the grid and current state (tetrominoes and gems).
# - **Score Display**: Show current score prominently on the screen.
# - **Next Tetromino Preview**: Display the next tetromino that will fall.
# - **Controls Display**: Provide a reference for player controls (instructions on how to play and activate power-ups).
#
# ### 4.2 Animations
# - **Falling Tetrominoes**: Smooth dropping animations as tetrominoes move down.
# - **Gem Transformations**: Visual effects for transforming tetrominoes into gems.
# - **Clearing Effects**: Animate the process of clearing matched gems, with visual cues to signal successful actions.
#
# ## 5. Additional Features
# - **Difficulty Scaling**: Increase speed and frequency of tetromino drops as the score rises.
# - **Power-ups**: Implement special gems that can clear larger areas or all gems of a color; these should be visually distinct to make them noticeable.
#
# ## 6. Implementation Framework
# - **Game Development Framework**: Use Pygame for rendering, input handling, and animations.
#
# ## 7. Development Plan
# 1. Create the grid and implement tetromino spawning and locking logic.
# 2. Implement gem transformation and line clearing.
# 3. Integrate interaction mechanics with gem matching post-tetromino lock.
# 4. Develop match-3 detection and clearing mechanisms.
# 5. Design and implement the GUI components, including control instructions.
# 6. Integrate animations for a smooth player experience with feedback.
# 7. Test and refine gameplay mechanics for balance.
#
# This architecture serves as a foundational blueprint for development, guiding modular implementation of core features and interactions within the game, while ensuring clarity and player engagement.
#
# ---
#
# # **Downstream Tasks objectivesv**
# Task task3:
#   Objective: Create the graphical user interface (GUI) using Pygame to display the game grid, current score, and next tetromino preview, including animations.
# Task task4:
#   Objective: Implement scoring and bonus point systems to reward players for line clears and chain reactions.
#
#
# ---
#
# # **Current Task Requirements**
# Implement the match-3 mechanics that allow for gem clearing and triggering chain reactions.
#
# ---
#
#
# ***********run end*********************
# 2025-03-19 20:50:02 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ------Run pythonValidator.is_python_code()------
# 2025-03-19 20:50:03 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-19 20:50:03 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ********remove pops begin************
# ------Run pythonValidator.is_python_code()------
# 2025-03-19 20:50:03 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-19 20:50:03 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ********remove pops begin************
#
# import random
#
# # Constants for game
# GRID_WIDTH = 10
# GRID_HEIGHT = 20
# ...
#             if all(self.grid[i]):
#                 self.clear_line(i)
#
#     def clear_line(self, line_index):
#         """Clears a specific line and shifts above lines down."""
#         del self.grid[line_index]
#         self.grid.insert(0, [None for _ in range(GRID_WIDTH)])
#
# # Example usage
# if __name__ == "__main__":
#     game = Game()
#     game.move_tetromino("down")
#     game.move_tetromino("down")
#     game.move_tetromino("down")
#
# def run_tests():
#     failures = []
#     game = Game()
#
#     try:
#         game.spawn_tetromino()
#         assert game.current_tetromino in TETROMINOES, "Test failed: current_tetromino should be one of TETROMINOES"
#     except AssertionError as e:
#         failures.append(str(e))
#
#     try:
#         initial_position = game.current_position
#         game.move_tetromino("down")
#         assert game.current_position == (initial_position[0] + 1, initial_position[1]), "Test failed: current_position should move down"
#     except AssertionError as e:
#         failures.append(str(e))
#
#     try:
#         initial_position = game.current_position
#         game.move_tetromino("left")
#         assert game.current_position == (initial_position[0], initial_position[1] - 1), "Test failed: current_position should move left"
#     except AssertionError as e:
#         failures.append(str(e))
#
#     try:
#         initial_position = game.current_position
#         game.move_tetromino("right")
#         assert game.current_position == (initial_position[0], initial_position[1] + 1), "Test failed: current_position should move right"
#     except AssertionError as e:
#         failures.append(str(e))
#
#     try:
#         full_row_index = 0
#         game.grid[full_row_index] = ['red'] * GRID_WIDTH
#         game.check_lines()
#         assert all(x is None for x in game.grid[full_row_index]), "Test failed: full row should be cleared"
#     except AssertionError as e:
#         failures.append(str(e))
#
#     try:
#         start_grid_state = [row[:] for row in game.grid]
#         game.lock_tetromino()
#         assert start_grid_state != game.grid, "Test failed: grid state should change after locking tetromino"
#     except AssertionError as e:
#         failures.append(str(e))
#
#     if failures:
#         print("Error executing code:")
#         for f in failures:
#             print(f)
#     else:
#         print("All tests passed!")
#
# run_tests()
# ```
# 2025-03-19 20:58:47 [INFO]  - task2: ```python
# import pygame
# import random
#
# # Initialize Pygame
# pygame.init()
#
# # Constants
# GRID_WIDTH, GRID_HEIGHT = 8, 8
# TILE_SIZE = 50
# SCREEN_WIDTH, SCREEN_HEIGHT = GRID_WIDTH * TILE_SIZE, GRID_HEIGHT * TILE_SIZE
# FPS = 60
#
# # Colors
# COLORS = [(255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 255, 0), (0, 255, 255), (255, 0, 255)]
#
# # Functions
# def create_grid():
#     return [[random.choice(COLORS) for _ in range(GRID_WIDTH)] for _ in range(GRID_HEIGHT)]
#
# def draw_grid(screen, grid):
#     for y in range(GRID_HEIGHT):
#         for x in range(GRID_WIDTH):
#             pygame.draw.rect(screen, grid[y][x], (x * TILE_SIZE, y * TILE_SIZE, TILE_SIZE, TILE_SIZE))
#             pygame.draw.rect(screen, (0, 0, 0), (x * TILE_SIZE, y * TILE_SIZE, TILE_SIZE, TILE_SIZE), 1)
#
# def check_matches(grid):
#     to_clear = set()
#
#     # Check horizontal matches
#     for y in range(GRID_HEIGHT):
#         for x in range(GRID_WIDTH - 2):
#             if grid[y][x] == grid[y][x + 1] == grid[y][x + 2]:
#                 to_clear.update({(y, x), (y, x + 1), (y, x + 2)})
#
#     # Check vertical matches
#     for x in range(GRID_WIDTH):
#         for y in range(GRID_HEIGHT - 2):
#             if grid[y][x] == grid[y + 1][x] == grid[y + 2][x]:
#                 to_clear.update({(y, x), (y + 1, x), (y + 2, x)})
#
#     return to_clear
#
# def clear_matches(grid, to_clear):
#     for y, x in to_clear:
#         grid[y][x] = None
#
#     # Drop down gems
#     for x in range(GRID_WIDTH):
#         column = [grid[y][x] for y in range(GRID_HEIGHT) if grid[y][x] is not None]
#         column = [*column, *[None] * (GRID_HEIGHT - len(column))]
#         for y in range(GRID_HEIGHT):
#             grid[y][x] = column[y]
#
# def handle_click(grid, pos):
#     x, y = pos
#     grid_x, grid_y = x // TILE_SIZE, y // TILE_SIZE
#     if grid_x >= 0 and grid_x < GRID_WIDTH and grid_y >= 0 and grid_y < GRID_HEIGHT:
#         selected_color = grid[grid_y][grid_x]
#         if selected_color:
#             to_clear = { (grid_y, grid_x) }
#             for dir_x, dir_y in [(1, 0), (-1, 0), (0, 1), (0, -1)]:
#                 check_adjacent(grid, grid_x, grid_y, selected_color, to_clear, dir_x, dir_y)
#             if len(to_clear) >= 3:
#                 clear_matches(grid, to_clear)
#
# def check_adjacent(grid, x, y, color, to_clear, dir_x, dir_y):
#     new_x, new_y = x + dir_x, y + dir_y
#     if 0 <= new_x < GRID_WIDTH and 0 <= new_y < GRID_HEIGHT and grid[new_y][new_x] == color:
#         to_clear.add((new_y, new_x))
#         check_adjacent(grid, new_x, new_y, color, to_clear, dir_x, dir_y)
#
# # Main Game Loop
# def main():
#     screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
#     pygame.display.set_caption('Gem Match Game')
#     clock = pygame.time.Clock()
#     grid = create_grid()
#
#     running = True
#     while running:
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 running = False
#             elif event.type == pygame.MOUSEBUTTONDOWN:
#                 if event.button == 1:  # Left mouse button
#                     handle_click(grid, event.pos)
#
#         screen.fill((255, 255, 255))
#         draw_grid(screen, grid)
#
#         pygame.display.flip()
#         clock.tick(FPS)
#
#     pygame.quit()
#
# if __name__ == "__main__":
#     main()
# ```
# 2025-03-19 20:58:47 [INFO]  - task3: ```python
# import pygame
# import random
#
# # Initialize Pygame
# pygame.init()
#
# # Constants
# GRID_WIDTH, GRID_HEIGHT = 10, 20
# TILE_SIZE = 30
# SCREEN_WIDTH, SCREEN_HEIGHT = GRID_WIDTH * TILE_SIZE, GRID_HEIGHT * TILE_SIZE + 100
# FPS = 60
#
# # Colors
# COLORS = {'red': (255, 0, 0), 'green': (0, 255, 0), 'blue': (0, 0, 255), 'yellow': (255, 255, 0),
#           'purple': (128, 0, 128), 'cyan': (0, 255, 255)}
#
# # Class for the Game GUI
# class GameGUI:
#     def __init__(self):
#         self.screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
#         pygame.display.set_caption('Tetris Bejeweled Fusion')
#         self.clock = pygame.time.Clock()
#         self.score = 0
#         self.grid = [[None for _ in range(GRID_WIDTH)] for _ in range(GRID_HEIGHT)]
#         self.current_tetromino = None
#         self.current_position = (0, GRID_WIDTH // 2)
#
#     def draw_grid(self):
#         for y in range(GRID_HEIGHT):
#             for x in range(GRID_WIDTH):
#                 if self.grid[y][x]:
#                     pygame.draw.rect(self.screen, COLORS[self.grid[y][x]],
#                                      (x * TILE_SIZE, y * TILE_SIZE, TILE_SIZE, TILE_SIZE))
#                 pygame.draw.rect(self.screen, (0, 0, 0),
#                                  (x * TILE_SIZE, y * TILE_SIZE, TILE_SIZE, TILE_SIZE), 1)
#
#     def draw_score(self):
#         font = pygame.font.Font(None, 36)
#         score_text = font.render(f'Score: {self.score}', True, (0, 0, 0))
#         self.screen.blit(score_text, (10, GRID_HEIGHT * TILE_SIZE + 10))
#
#     def draw_next_tetromino(self):
#         font = pygame.font.Font(None, 36)
#         next_text = font.render('Next:', True, (0, 0, 0))
#         self.screen.blit(next_text, (GRID_WIDTH * TILE_SIZE - 60, GRID_HEIGHT * TILE_SIZE + 10))
#         if self.current_tetromino:
#             pygame.draw.rect(self.screen, COLORS[self.current_tetromino],
#                              (GRID_WIDTH * TILE_SIZE - 60, GRID_HEIGHT * TILE_SIZE + 40, 30, 30))
#
#     def update(self):
#         self.screen.fill((255, 255, 255))
#         self.draw_grid()
#         self.draw_score()
#         self.draw_next_tetromino()
#         pygame.display.flip()
#
#     def run_game(self):
#         running = True
#         while running:
#             for event in pygame.event.get():
#                 if event.type == pygame.QUIT:
#                     running = False
#
#             self.update()
#             self.clock.tick(FPS)
#
#         pygame.quit()
#
# # Main function
# if __name__ == "__main__":
#     gui = GameGUI()
#     gui.run_game()
# ```
# 2025-03-19 20:58:47 [INFO]  - task4: ```python
# class Scoring:
#     def __init__(self):
#         self.score = 0
#         self.bonus_multiplier = 1
#
#     def line_clear_score(self, lines_cleared):
#         """Calculate and return the score based on lines cleared."""
#         base_score = 100
#         return base_score * lines_cleared * self.bonus_multiplier
#
#     def chain_reaction_score(self, chain_length):
#         """Calculate and return the score for chain reactions."""
#         base_chain_score = 50
#         return base_chain_score * chain_length * self.bonus_multiplier
#
#     def add_score(self, score):
#         """Add score to the current total score."""
#         self.score += score
#
#     def reset_multiplier(self):
#         """Reset bonus multiplier after a chain reaction."""
#         self.bonus_multiplier = 1
#
#     def increase_multiplier(self):
#         """Increase the bonus multiplier after successful matches."""
#         self.bonus_multiplier += 1
#
# # Integration in Game Logic
# class Game:
#     def __init__(self):
#         # Other initializations...
#         self.scoring = Scoring()
#
#     def clear_lines(self, lines):
#         score = self.scoring.line_clear_score(len(lines))
#         self.scoring.add_score(score)
#
#     def handle_chain_reaction(self, chain_length):
#         score = self.scoring.chain_reaction_score(chain_length)
#         self.scoring.add_score(score)
#         self.scoring.increase_multiplier()
#
#     def display_score(self):
#         print(f"Current Score: {self.scoring.score}")
#
# # Example interaction workflow
# if __name__ == "__main__":
#     game = Game()
#     # Simulate clearing lines
#     game.clear_lines([0, 1])
#     game.display_score()
#     # Simulate chain reaction
#     game.handle_chain_reaction(3)
#     game.display_score()
# ```
# 2025-03-19 20:58:47 [INFO]  - task5: ```python
# import pygame
# import random
#
# # Initialize Pygame
# pygame.init()
#
# # Constants
# GRID_WIDTH, GRID_HEIGHT = 10, 20
# TILE_SIZE = 30
# SCREEN_WIDTH, SCREEN_HEIGHT = GRID_WIDTH * TILE_SIZE, GRID_HEIGHT * TILE_SIZE + 100
# FPS = 60
#
# # Colors
# COLORS = {'red': (255, 0, 0), 'green': (0, 255, 0), 'blue': (0, 0, 255),
#           'yellow': (255, 255, 0), 'purple': (128, 0, 128), 'cyan': (0, 255, 255)}
#
# class GameGUI:
#     def __init__(self, scoring):
#         self.screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
#         pygame.display.set_caption('Tetris Bejeweled Fusion')
#         self.clock = pygame.time.Clock()
#         self.score = scoring
#         self.grid = [[None for _ in range(GRID_WIDTH)] for _ in range(GRID_HEIGHT)]
#         self.current_tetromino = None
#         self.current_position = (0, GRID_WIDTH // 2)
#
#     def draw_grid(self):
#         for y in range(GRID_HEIGHT):
#             for x in range(GRID_WIDTH):
#                 if self.grid[y][x]:
#                     pygame.draw.rect(self.screen, COLORS[self.grid[y][x]],
#                                      (x * TILE_SIZE, y * TILE_SIZE, TILE_SIZE, TILE_SIZE))
#                 pygame.draw.rect(self.screen, (0, 0, 0),
#                                  (x * TILE_SIZE, y * TILE_SIZE, TILE_SIZE, TILE_SIZE), 1)
#
#     def draw_score(self):
#         font = pygame.font.Font(None, 36)
#         score_text = font.render(f'Score: {self.score.score}', True, (0, 0, 0))
#         self.screen.blit(score_text, (10, GRID_HEIGHT * TILE_SIZE + 10))
#
#     def draw_next_tetromino(self):
#         font = pygame.font.Font(None, 36)
#         next_text = font.render('Next:', True, (0, 0, 0))
#         self.screen.blit(next_text, (GRID_WIDTH * TILE_SIZE - 60, GRID_HEIGHT * TILE_SIZE + 10))
#         if self.current_tetromino:
#             pygame.draw.rect(self.screen, COLORS[self.current_tetromino],
#                              (GRID_WIDTH * TILE_SIZE - 60, GRID_HEIGHT * TILE_SIZE + 40, 30, 30))
#
#     def update(self):
#         self.screen.fill((255, 255, 255))
#         self.draw_grid()
#         self.draw_score()
#         self.draw_next_tetromino()
#         pygame.display.flip()
#
#     def run_game(self):
#         running = True
#         while running:
#             for event in pygame.event.get():
#                 if event.type == pygame.QUIT:
#                     running = False
#             # Add game logic here
#             self.update()
#             self.clock.tick(FPS)
#
#         pygame.quit()
#
# class Scoring:
#     def __init__(self):
#         self.score = 0
#         self.bonus_multiplier = 1
#
#     def line_clear_score(self, lines_cleared):
#         base_score = 100
#         return base_score * lines_cleared * self.bonus_multiplier
#
#     def chain_reaction_score(self, chain_length):
#         base_chain_score = 50
#         return base_chain_score * chain_length * self.bonus_multiplier
#
#     def add_score(self, score):
#         self.score += score
#
#     def reset_multiplier(self):
#         self.bonus_multiplier = 1
#
#     def increase_multiplier(self):
#         self.bonus_multiplier += 1
#
# class Game:
#     def __init__(self):
#         self.scoring = Scoring()
#         self.gui = GameGUI(self.scoring)
#
#     def clear_lines(self, lines):
#         score = self.scoring.line_clear_score(len(lines))
#         self.scoring.add_score(score)
#
#     def handle_chain_reaction(self, chain_length):
#         score = self.scoring.chain_reaction_score(chain_length)
#         self.scoring.add_score(score)
#         self.scoring.increase_multiplier()
#
#     def display_score(self):
#         print(f"Current Score: {self.scoring.score}")
#
# if __name__ == "__main__":
#     game = Game()
#     game.gui.run_game()
# ```
# 2025-03-19 20:58:47 [INFO]  - task6: ```python
# import pygame
# import random
#
# # Initialize Pygame
# pygame.init()
#
# # Constants
# GRID_WIDTH, GRID_HEIGHT = 8, 8
# TILE_SIZE = 50
# SCREEN_WIDTH, SCREEN_HEIGHT = GRID_WIDTH * TILE_SIZE, GRID_HEIGHT * TILE_SIZE
# FPS = 60
#
# # Colors
# COLORS = [(255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 255, 0), (0, 255, 255), (255, 0, 255)]
#
# # Functions
# def create_grid():
#     return [[random.choice(COLORS) for _ in range(GRID_WIDTH)] for _ in range(GRID_HEIGHT)]
#
# def draw_grid(screen, grid):
#     for y in range(GRID_HEIGHT):
#         for x in range(GRID_WIDTH):
#             pygame.draw.rect(screen, grid[y][x], (x * TILE_SIZE, y * TILE_SIZE, TILE_SIZE, TILE_SIZE))
#             pygame.draw.rect(screen, (0, 0, 0), (x * TILE_SIZE, y * TILE_SIZE, TILE_SIZE, TILE_SIZE), 1)
#
# def check_matches(grid):
#     to_clear = set()
#
#     # Check horizontal matches
#     for y in range(GRID_HEIGHT):
#         for x in range(GRID_WIDTH - 2):
#             if grid[y][x] == grid[y][x + 1] == grid[y][x + 2]:
#                 to_clear.update({(y, x), (y, x + 1), (y, x + 2)})
#
#     # Check vertical matches
#     for x in range(GRID_WIDTH):
#         for y in range(GRID_HEIGHT - 2):
#             if grid[y][x] == grid[y + 1][x] == grid[y + 2][x]:
#                 to_clear.update({(y, x), (y + 1, x), (y + 2, x)})
#
#     return to_clear
#
# def clear_matches(grid, to_clear):
#     for y, x in to_clear:
#         grid[y][x] = None
#
#     # Drop down gems
#     for x in range(GRID_WIDTH):
#         column = [grid[y][x] for y in range(GRID_HEIGHT) if grid[y][x] is not None]
#         column = [*column, *[None] * (GRID_HEIGHT - len(column))]
#         for y in range(GRID_HEIGHT):
#             grid[y][x] = column[y]
#
# # Main Game Loop
# def main():
#     screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
#     pygame.display.set_caption('Gem Match Game')
#     clock = pygame.time.Clock()
#     grid = create_grid()
#
#     running = True
#     while running:
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 running = False
#
#         screen.fill((255, 255, 255))
#         draw_grid(screen, grid)
#
#         matches = check_matches(grid)
#         if matches:
#             clear_matches(grid, matches)
#
#         pygame.display.flip()
#         clock.tick(FPS)
#
#     pygame.quit()
#
# if __name__ == "__main__":
#     main()
# ```
# ***Python code with no bugs***
# task5 ---Final status: completed
# 3 3

# %% [markdown]
# ### Store necessary information and summary the output

# %%
workflow_data = {}

for tid, task in manager.workflow.tasks.items():
    custom_task_data = {
        'id': task.id,
        'objective': task.objective,
        'agent_id': task.agent_id,
        'next': task.next,
        'prev': task.prev,
        'status': task.status,
        'remaining_dependencies': task.remaining_dependencies,
        'agent': task.agent,
        'history': task.history.get_latest_result(),
    }
    
    workflow_data[tid] = custom_task_data
    
# Store the final workflow
with open('manually_result.json', 'w', encoding='utf-8') as file:
    json.dump(workflow_data, file, indent=4)

summary = Summary()

# Generate and save a summary of the workflow results
chat_result = summary.summary(overall_task, workflow_data)
with open("example.txt", "w", encoding="utf-8") as file:
    file.write(chat_result)
# Out:
# 2025-03-19 20:59:02 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"

# %% [markdown]
# The following python file represents the outcome generated by our FLOW.

# %%
import sys, random, pygame, time

# -------------------- Constants & Global Settings --------------------
WINDOW_WIDTH = 400
WINDOW_HEIGHT = 500
GRID_COLS = 10
GRID_ROWS = 20
CELL_SIZE = 24
GRID_ORIGIN = (20, 20)
NEXT_ORIGIN = (300, 50)
SCORE_POS = (300, 250)
BG_COLOR = (30, 30, 30)
BORDER_COLOR = (50, 50, 50)
TEXT_COLOR = (255, 255, 255)
FALL_DELAY = 500  # milliseconds delay for tetromino fall

# Tetromino Shapes (list of (dx, dy) offsets relative to a pivot)
SHAPES = {
    "I": [(-1, 0), (0, 0), (1, 0), (2, 0)],
    "O": [(0, 0), (1, 0), (0, 1), (1, 1)],
    "T": [(-1, 0), (0, 0), (1, 0), (0, 1)],
    "S": [(0, 0), (1, 0), (-1, 1), (0, 1)],
    "Z": [(-1, 0), (0, 0), (0, 1), (1, 1)],
    "J": [(-1, 0), (0, 0), (1, 0), (-1, 1)],
    "L": [(-1, 0), (0, 0), (1, 0), (1, 1)]
}

# Mapping tetromino shape to gem color strings
COLOR_MAPPING = {
    "I": "cyan",
    "O": "yellow",
    "T": "purple",
    "S": "green",
    "Z": "red",
    "J": "blue",
    "L": "orange"
}

# Map color names to RGB values (for display in grid)
RGB_GEMS = {
    "cyan":   (0, 255, 255),
    "yellow": (255, 255, 0),
    "purple": (128, 0, 128),
    "green":  (0, 255, 0),
    "red":    (255, 0, 0),
    "blue":   (0, 0, 255),
    "orange": (255, 165, 0)
}

# -------------------- Game Core Modules --------------------
class GemTransformation:
    def transform_to_gems(self, tetromino, grid):
        # Convert locked tetromino blocks into colored gems using the mapping
        gem_color = COLOR_MAPPING[tetromino["shape"]]
        for (x, y) in tetromino["blocks"]:
            if 0 <= y < len(grid) and 0 <= x < len(grid[0]):
                grid[y][x] = gem_color
        return grid

class TetrisMechanics:
    def __init__(self, grid_width=GRID_COLS, grid_height=GRID_ROWS):
        self.grid_width = grid_width
        self.grid_height = grid_height
        self.grid = [[None for _ in range(grid_width)] for _ in range(grid_height)]
        self.current_tetromino = None
        self.gem_transformer = GemTransformation()

    def spawn_tetromino(self):
        shape = random.choice(list(SHAPES.keys()))
        pivot_x = self.grid_width // 2
        pivot_y = 0
        blocks = []
        for offset in SHAPES[shape]:
            x = pivot_x + offset[0]
            y = pivot_y + offset[1]
            blocks.append((x, y))
        self.current_tetromino = {
            "shape": shape,
            "pivot": (pivot_x, pivot_y),
            "blocks": blocks
        }

    def check_collision(self, blocks):
        for (x, y) in blocks:
            if x < 0 or x >= self.grid_width or y >= self.grid_height:
                return True
            if y >= 0 and self.grid[y][x] is not None:
                return True
        return False

    def move_tetromino(self, direction):
        if self.current_tetromino is None:
            return
        dx, dy = 0, 0
        if direction == 'left':
            dx = -1
        elif direction == 'right':
            dx = 1
        elif direction == 'down':
            dy = 1
        new_blocks = [(x + dx, y + dy) for (x, y) in self.current_tetromino["blocks"]]
        if not self.check_collision(new_blocks):
            self.current_tetromino["blocks"] = new_blocks
            pivot_x, pivot_y = self.current_tetromino["pivot"]
            self.current_tetromino["pivot"] = (pivot_x + dx, pivot_y + dy)
        elif direction == 'down':
            self.lock_piece()

    def rotate_tetromino(self):
        if self.current_tetromino is None:
            return
        pivot = self.current_tetromino["pivot"]
        new_blocks = []
        for (x, y) in self.current_tetromino["blocks"]:
            rel_x = x - pivot[0]
            rel_y = y - pivot[1]
            # Rotate clockwise: (x, y) -> (y, -x)
            new_x = pivot[0] + rel_y
            new_y = pivot[1] - rel_x
            new_blocks.append((new_x, new_y))
        if not self.check_collision(new_blocks):
            self.current_tetromino["blocks"] = new_blocks

    def lock_piece(self):
        if self.current_tetromino is None:
            return
        self.gem_transformer.transform_to_gems(self.current_tetromino, self.grid)
        self.current_tetromino = None

# -- Match-3 Clearing and Tetris Line Clear Logic --
class Match3Controller:
    def __init__(self, min_match=3):
        self.min_match = min_match

    def detect_matches(self, gem_grid):
        overall_matches = set()
        rows = len(gem_grid)
        cols = len(gem_grid[0])
        # Detect horizontal matches
        for r in range(rows):
            count = 1
            for c in range(1, cols):
                if gem_grid[r][c] is not None and gem_grid[r][c] == gem_grid[r][c - 1]:
                    count += 1
                else:
                    if count >= self.min_match:
                        positions = {(r, k) for k in range(c - count, c)}
                        overall_matches.update(positions)
                    count = 1
            if count >= self.min_match:
                positions = {(r, k) for k in range(cols - count, cols)}
                overall_matches.update(positions)
        # Detect vertical matches
        for c in range(cols):
            count = 1
            for r in range(1, rows):
                if gem_grid[r][c] is not None and gem_grid[r][c] == gem_grid[r - 1][c]:
                    count += 1
                else:
                    if count >= self.min_match:
                        positions = {(k, c) for k in range(r - count, r)}
                        overall_matches.update(positions)
                    count = 1
            if count >= self.min_match:
                positions = {(k, c) for k in range(rows - count, rows)}
                overall_matches.update(positions)
        # Diagonal detection (down-right)
        for r in range(rows):
            for c in range(cols):
                positions = [(r, c)]
                rr, cc = r + 1, c + 1
                while rr < rows and cc < cols and gem_grid[rr][cc] is not None and gem_grid[rr][cc] == gem_grid[r][c]:
                    positions.append((rr, cc))
                    rr += 1
                    cc += 1
                if len(positions) >= self.min_match:
                    overall_matches.update(positions)
        # Diagonal detection (down-left)
        for r in range(rows):
            for c in range(cols):
                positions = [(r, c)]
                rr, cc = r + 1, c - 1
                while rr < rows and cc >= 0 and gem_grid[rr][cc] is not None and gem_grid[rr][cc] == gem_grid[r][c]:
                    positions.append((rr, cc))
                    rr += 1
                    cc -= 1
                if len(positions) >= self.min_match:
                    overall_matches.update(positions)
        return overall_matches

    def clear_matches(self, gem_grid, matched_positions):
        cleared_count = 0
        for (r, c) in matched_positions:
            if gem_grid[r][c] is not None:
                gem_grid[r][c] = None
                cleared_count += 1
        return cleared_count

    def drop_gems(self, gem_grid):
        rows = len(gem_grid)
        cols = len(gem_grid[0])
        for c in range(cols):
            empty_slots = []
            for r in range(rows - 1, -1, -1):
                if gem_grid[r][c] is None:
                    empty_slots.append(r)
                elif empty_slots:
                    empty_r = empty_slots.pop(0)
                    gem_grid[empty_r][c] = gem_grid[r][c]
                    gem_grid[r][c] = None
                    empty_slots.append(r)
        return gem_grid

    def trigger_chain_reaction(self, gem_grid):
        chain_multiplier = 1
        total_bonus = 0
        while True:
            matches = self.detect_matches(gem_grid)
            if not matches:
                break
            cleared = self.clear_matches(gem_grid, matches)
            bonus = cleared * chain_multiplier * 10
            total_bonus += bonus
            gem_grid = self.drop_gems(gem_grid)
            chain_multiplier += 1
        return gem_grid, total_bonus

def clear_tetris_lines(grid):
    rows = len(grid)
    cols = len(grid[0])
    lines_cleared = 0
    new_grid = []
    for row in grid:
        if all(cell is not None for cell in row):
            lines_cleared += 1
        else:
            new_grid.append(row)
    while len(new_grid) < rows:
        new_grid.insert(0, [None for _ in range(cols)])
    return new_grid, lines_cleared

class ScoreManager:
    def __init__(self):
        self.total_score = 0

    def update_tetris_score(self, lines_cleared):
        self.total_score += lines_cleared * 100

    def update_match3_score(self, gems_cleared, bonus):
        self.total_score += gems_cleared * 5 + bonus

    def get_total_score(self):
        return self.total_score

# -------------------- GUI Module (Using Pygame) --------------------
class GameGUI:
    def __init__(self):
        pygame.init()
        self.screen = pygame.display.set_mode((WINDOW_WIDTH, WINDOW_HEIGHT))
        pygame.display.set_caption("Tetris-Bejeweled Fusion")
        self.clock = pygame.time.Clock()
        self.font = pygame.font.SysFont("arial", 20)

    def draw_grid(self, gem_grid):
        # Draw the game grid with each cell as a colored block (or black if empty)
        for row in range(GRID_ROWS):
            for col in range(GRID_COLS):
                cell_value = gem_grid[row][col]
                if cell_value is None:
                    color = (0, 0, 0)
                else:
                    color = RGB_GEMS.get(cell_value, (255, 255, 255))
                rect = pygame.Rect(GRID_ORIGIN[0] + col * CELL_SIZE,
                                   GRID_ORIGIN[1] + row * CELL_SIZE,
                                   CELL_SIZE, CELL_SIZE)
                pygame.draw.rect(self.screen, color, rect)
                pygame.draw.rect(self.screen, BORDER_COLOR, rect, 1)

    def draw_score(self, score):
        score_text = self.font.render("Score: " + str(score), True, TEXT_COLOR)
        self.screen.blit(score_text, SCORE_POS)

    def draw_next_tetromino(self, tetromino):
        # Represent the tetromino as a simple matrix using 1 for blocks and 0 for empty.
        # First, convert tetromino blocks to a minimal matrix by finding bounds.
        matrix = piece_to_matrix(tetromino)
        block_color = (200, 200, 200)
        for row_idx, row in enumerate(matrix):
            for col_idx, cell in enumerate(row):
                if cell:
                    rect = pygame.Rect(NEXT_ORIGIN[0] + col_idx * CELL_SIZE,
                                       NEXT_ORIGIN[1] + row_idx * CELL_SIZE,
                                       CELL_SIZE, CELL_SIZE)
                    pygame.draw.rect(self.screen, block_color, rect)
                    pygame.draw.rect(self.screen, BORDER_COLOR, rect, 1)
        header = self.font.render("Next", True, TEXT_COLOR)
        self.screen.blit(header, (NEXT_ORIGIN[0], NEXT_ORIGIN[1] - 25))

    def update_display(self):
        pygame.display.flip()

    def handle_input(self):
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()

def piece_to_matrix(piece):
    # Convert tetromino block positions into a minimal 2D matrix representation.
    coords = piece["blocks"]
    if not coords:
        return [[0]]
    xs = [x for x,y in coords]
    ys = [y for x,y in coords]
    min_x, min_y = min(xs), min(ys)
    max_x, max_y = max(xs), max(ys)
    width = max_x - min_x + 1
    height = max_y - min_y + 1
    matrix = [[0 for _ in range(width)] for _ in range(height)]
    for (x,y) in coords:
        mx = x - min_x
        my = y - min_y
        matrix[my][mx] = 1
    return matrix

# -------------------- Integration: Main Game Loop --------------------
def main():
    # Instantiate core modules
    mechanics = TetrisMechanics()
    matcher = Match3Controller()
    scorer = ScoreManager()
    gui = GameGUI()

    # Spawn first tetromino and set a next-piece preview
    mechanics.spawn_tetromino()
    next_piece = None
    if mechanics.current_tetromino:
        # Prepare a preview piece by generating a new tetromino without locking it immediately.
        next_piece = {}
        shape = random.choice(list(SHAPES.keys()))
        pivot = (GRID_COLS // 2, 0)
        blocks = [(pivot[0] + dx, pivot[1] + dy) for (dx,dy) in SHAPES[shape]]
        next_piece = {"shape": shape, "pivot": pivot, "blocks": blocks}

    last_fall = pygame.time.get_ticks()
    game_over = False

    while not game_over:
        gui.handle_input()

        # --- Handle user input for tetromino movement ---
        keys = pygame.key.get_pressed()
        if keys[pygame.K_LEFT]:
            mechanics.move_tetromino("left")
        if keys[pygame.K_RIGHT]:
            mechanics.move_tetromino("right")
        if keys[pygame.K_DOWN]:
            mechanics.move_tetromino("down")
        if keys[pygame.K_UP]:
            mechanics.rotate_tetromino()

        # --- Gravity: Automatic tetromino move down ---
        now = pygame.time.get_ticks()
        if now - last_fall > FALL_DELAY:
            mechanics.move_tetromino("down")
            last_fall = now

        # --- Check if tetromino has locked and process grid clearing ---
        if mechanics.current_tetromino is None:
            # First, clear any full lines (Tetris mechanic)
            mechanics.grid, lines = clear_tetris_lines(mechanics.grid)
            scorer.update_tetris_score(lines)
            # Then, check and process gem match-3 clearing with chain reactions
            before = sum(1 for row in mechanics.grid for cell in row if cell is not None)
            mechanics.grid, bonus = matcher.trigger_chain_reaction(mechanics.grid)
            after = sum(1 for row in mechanics.grid for cell in row if cell is not None)
            cleared_gems = before - after
            scorer.update_match3_score(cleared_gems, bonus)
            # Update current piece (use the pre-generated next_piece) and spawn a new next preview
            mechanics.spawn_tetromino()
            current = mechanics.current_tetromino
            next_piece = None
            shape = random.choice(list(SHAPES.keys()))
            pivot = (GRID_COLS // 2, 0)
            blocks = [(pivot[0] + dx, pivot[1] + dy) for (dx,dy) in SHAPES[shape]]
            next_piece = {"shape": shape, "pivot": pivot, "blocks": blocks}
            # Check for game over: if any block of the new tetromino collides with existing gems
            for (x, y) in current["blocks"]:
                if y < 0 or mechanics.grid[y][x] is not None:
                    game_over = True
                    break

        # --- GUI Rendering ---
        gui.screen.fill(BG_COLOR)
        gui.draw_grid(mechanics.grid)
        # Draw current falling tetromino if available
        if mechanics.current_tetromino:
            # Draw the tetromino by rendering each block with its corresponding gem color
            gem_color = RGB_GEMS[COLOR_MAPPING[mechanics.current_tetromino["shape"]]]
            for (x, y) in mechanics.current_tetromino["blocks"]:
                if y >= 0:
                    rect = pygame.Rect(GRID_ORIGIN[0] + x * CELL_SIZE, GRID_ORIGIN[1] + y * CELL_SIZE, CELL_SIZE, CELL_SIZE)
                    pygame.draw.rect(gui.screen, gem_color, rect)
                    pygame.draw.rect(gui.screen, BORDER_COLOR, rect, 1)
        gui.draw_score(scorer.get_total_score())
        if next_piece:
            gui.draw_next_tetromino(next_piece)
        gui.update_display()
        gui.clock.tick(60)

    # Game Over — show final score for a short moment then exit
    print("Game Over! Final Score:", scorer.get_total_score())
    time.sleep(2)
    pygame.quit()
    sys.exit()

if __name__ == "__main__":
    main()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Game Over! Final Score: 2325
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# d:\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
