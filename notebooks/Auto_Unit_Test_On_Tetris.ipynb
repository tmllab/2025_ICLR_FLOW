# %% [markdown]
# ## How to run workflow with validation?

# %% [markdown]
# Here, our FLOW will utilize the overall task you have provided to automatically generate the subtasks and agents within the workflow. When providing an overall task, please endeavor to articulate your requirements with clarity, including the desired output format and the specific content you expect. The more detailed your description, the more refined and accurate the results will be.

# %% [markdown]
# ### Requirement
# You need to have an OpenAI API Key.
# Notice that our default model is gpt-4o-mini, please feel free to replace it with the model you wish to use.
# However, for this case, we recommend use a reasoning-optimized GPT model, such as `"o1-mini"` or `"o3-mini"`.

# %%
import os
import sys

# Add the parent folder to the path
sys.path.append(os.path.abspath(".."))

from config import Config

Config.set("OPENAI_API_KEY", "your-api-key")
Config.set("GPT_MODEL", "o3-mini")

# %% [markdown]
# ### Import necessary module

# %%
import asyncio
import nest_asyncio
import json
from flow import Flow
from summary import Summary

# %% [markdown]
# ### Set your overall task

# %% [markdown]
# As you can observe, we have furnished an example herein for generating a website that contains context of ICLR 2025. Within this overall task, we have delineated the requisite output format along with the specific content details. At the very bottom of this notebook, you are able to witness the outcome of the execution.

# %%
overall_task: str = '''Create a Tetris game using Python with the pygame library. 
The game should feature a standard 10x20 grid for gameplay. 
Display the current falling tetromino and the next upcoming piece. 
Include a score counter, a display for the number of cleared lines, and a simple border to distinguish the game area. 
Each tetromino type should have a unique, vibrant color for clear visibility. 
The interface should be clean and modern, emphasizing gameplay clarity and user experience.'''

# %% [markdown]
# ### Run your workflow
#
# Here are some parameter explanations for the following code:
# refine_threshold: Refinement will be triggered after completing the threshold amount of subtasks.
# max_refine_itt: The number of max refine iteration times.
# n_candidate_graphs: The number of candidate workflow graphs.
# workflow: Predefined workflow, here should be None.
# max_validation_itt: The number of max validation iteration times.

# %%
manager = Flow(overall_task = overall_task, refine_threshold = 3, max_refine_itt=5, n_candidate_graphs=10, workflow=None, max_validation_itt=4)
nest_asyncio.apply()
asyncio.run(manager.run_async())
# Out:
# 2025-03-20 10:55:00 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 10:55:00 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library featuring a 10x20 grid, falling tetrominoes with a preview of the next piece, a score counter, a cleared lines display, and a simple border with vibrant colors for each tetromino.",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall game architecture. Define modules (game state, grid management, tetromino handling, UI rendering, input management, and scoring) and outline the data flow and interactions."
#     },
#     {
#       "id": 1,
#       "objective": "Develop the game mechanics module. Implement the logic for a standard 10x20 grid, falling tetromino behavior, collision detection with boundaries and placed pieces, rotation, and line clearing."
#     },
#     {
#       "id": 2,
#       "objective": "Create the user interface module using pygame. Render the game area with a clear border, display the current falling tetromino, preview the next tetromino, and include score and cleared lines counters. Ensure each tetromino type is rendered with a unique vibrant color for clarity."
#     },
#     {
#       "id": 3,
#       "objective": "Integrate the game mechanics with the UI. Connect grid updates, tetromino movement, and collision handling with the rendering engine to ensure smooth gameplay and real-time updates of scores and cleared lines."
#     },
#     {
#       "id": 4,
#       "objective": "Polish and finalize the game. Refine the UI for a clean, modern look, adjust colors and layout for optimal clarity, and ensure that all modules interact seamlessly."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 1, "child": 3 },
#     { "parent": 2, "child": 3 },
#     { "parent": 3, "child": 4 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "System Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Game Mechanics Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "UI/Rendering Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "Integration Specialist",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Polish and Optimization Engineer",
#       "subtasks": [4]
#     }
#   ]
# }
# 2025-03-20 10:55:02 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 10:55:02 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall game architecture, defining key components such as the game grid (10x20), tetromino data structures, game state, and module interactions."
#     },
#     {
#       "id": 1,
#       "objective": "Implement the game logic module including grid representation, tetromino behavior (movement, rotation, collision detection), score counter, and line clear calculations."
#     },
#     {
#       "id": 2,
#       "objective": "Develop the user interface using pygame to render the 10x20 gameplay grid, current falling tetromino with vibrant colors, next-piece preview, score display, cleared lines counter, and a simple border for game area clarity."
#     },
#     {
#       "id": 3,
#       "objective": "Integrate the game logic with the UI and implement event handling for keyboard inputs to control tetromino movements and rotations."
#     },
#     {
#       "id": 4,
#       "objective": "Perform final integration and code refinement to optimize performance, ensure a clean and modern interface, and enhance gameplay clarity and user experience."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 1, "child": 3 },
#     { "parent": 2, "child": 3 },
#     { "parent": 3, "child": 4 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "System Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Game Logic Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "UI/Graphics Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "Integration Specialist",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Code Optimizer",
#       "subtasks": [4]
#     }
#   ]
# }
# 2025-03-20 10:55:04 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 10:55:04 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Define the overall game architecture including module decomposition for grid management, tetromino management, scoring, and event handling."
#     },
#     {
#       "id": 1,
#       "objective": "Develop the game board module: implement a 10x20 grid, draw a simple border, and create functions for rendering the grid using pygame."
#     },
#     {
#       "id": 2,
#       "objective": "Implement the tetromino module: define tetromino shapes and their unique, vibrant colors; manage the current falling tetromino and the upcoming piece display."
#     },
#     {
#       "id": 3,
#       "objective": "Create the scoring and line clearing module: implement logic for updating the score, counting cleared lines, and providing a clean display for these statistics."
#     },
#     {
#       "id": 4,
#       "objective": "Develop the main game loop and event handling module: process keyboard inputs, control tetromino movement (falling, rotation, and lateral shifts), and manage game timing."
#     },
#     {
#       "id": 5,
#       "objective": "Integrate all modules (grid, tetromino, scoring, and event handling) into a cohesive game, ensuring the interface is clean and modern with emphasis on gameplay clarity and user experience."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 0, "child": 3 },
#     { "parent": 0, "child": 4 },
#     { "parent": 1, "child": 4 },
#     { "parent": 2, "child": 4 },
#     { "parent": 3, "child": 4 },
#     { "parent": 4, "child": 5 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "Game Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Grid Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Tetromino Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "Scoring & Lines Module Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Event Handling and Game Loop Developer",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "Integration Specialist",
#       "subtasks": [5]
#     }
#   ]
# }
# 2025-03-20 10:55:06 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 10:55:06 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library that features a standard 10x20 grid, displays the current falling tetromino along with the next upcoming piece, includes a score counter and cleared lines display, a simple border delineating the game area, and assigns each tetromino a unique, vibrant color with a clean and modern interface.",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall architecture and game design specifications, including grid dimensions, tetromino definitions, color schemes, UI layout, and game logic flow."
#     },
#     {
#       "id": 1,
#       "objective": "Implement the game board user interface, drawing a standard 10x20 grid with a clear border to delineate the game area."
#     },
#     {
#       "id": 2,
#       "objective": "Develop the Tetromino module by coding the seven tetromino types with unique, vibrant colors and defining initial shapes and rotations."
#     },
#     {
#       "id": 3,
#       "objective": "Implement core game mechanics including tetromino falling, movement, rotation, and collision detection, utilizing definitions from the Tetromino module."
#     },
#     {
#       "id": 4,
#       "objective": "Develop the module to display the next upcoming tetromino, ensuring that it accurately previews the piece queued to enter play."
#     },
#     {
#       "id": 5,
#       "objective": "Implement the scoring system and line-clear detection logic, updating the score counter and displaying the number of cleared lines during gameplay."
#     },
#     {
#       "id": 6,
#       "objective": "Integrate all modules by constructing the main game loop, managing user input, and ensuring synchronization between UI, tetromino mechanics, and scoring."
#     },
#     {
#       "id": 7,
#       "objective": "Polish the final interface and gameplay experience by refining UI aesthetics, ensuring modern, clean visuals and a smooth user experience."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 2, "child": 3 },
#     { "parent": 2, "child": 4 },
#     { "parent": 3, "child": 5 },
#     { "parent": 1, "child": 6 },
#     { "parent": 3, "child": 6 },
#     { "parent": 4, "child": 6 },
#     { "parent": 5, "child": 6 },
#     { "parent": 6, "child": 7 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "System Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "UI Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Tetromino Module Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "Game Mechanics Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Upcoming Piece Display Developer",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "Scoring and Line-Clear Developer",
#       "subtasks": [5]
#     },
#     {
#       "id": "Agent 6",
#       "role": "Integration Specialist",
#       "subtasks": [6]
#     },
#     {
#       "id": "Agent 7",
#       "role": "UI/UX Polisher",
#       "subtasks": [7]
#     }
#   ]
# }
# 2025-03-20 10:55:07 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 10:55:07 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library featuring a standard 10x20 grid, current and next tetromino displays, score counter, cleared lines display, and a clean, modern interface with vibrant colored tetrominoes.",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall game architecture, defining modules (game logic, tetromino management, and UI rendering), data structures (grid, score, line count), and the integration strategy."
#     },
#     {
#       "id": 1,
#       "objective": "Implement the core game mechanics, including grid management, game loop, tetromino movement, collision detection, line clearing, and score updates."
#     },
#     {
#       "id": 2,
#       "objective": "Develop the tetromino module to generate pieces with unique, vibrant colors and manage both the current falling tetromino and the upcoming next piece."
#     },
#     {
#       "id": 3,
#       "objective": "Create the user interface using pygame to render the 10x20 grid, draw a simple border, and display the score counter, cleared lines, current tetromino, and next piece with a clean and modern look."
#     },
#     {
#       "id": 4,
#       "objective": "Integrate the game mechanics, tetromino module, and UI components ensuring smooth interactions and overall game functionality."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 0, "child": 3 },
#     { "parent": 1, "child": 4 },
#     { "parent": 2, "child": 4 },
#     { "parent": 3, "child": 4 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "System Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Gameplay Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Tetromino Module Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "UI/Graphics Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Integration Specialist",
#       "subtasks": [4]
#     }
#   ]
# }
# 2025-03-20 10:55:09 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 10:55:09 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Initialize the pygame environment and create a basic game window to serve as the foundation for the game."
#     },
#     {
#       "id": 1,
#       "objective": "Render the 10x20 gameplay grid along with a simple border to clearly delineate the game area."
#     },
#     {
#       "id": 2,
#       "objective": "Develop a tetromino module that defines all tetromino shapes with their geometries and assigns each a unique, vibrant color."
#     },
#     {
#       "id": 3,
#       "objective": "Implement the core game mechanics including tetromino falling, movement, rotation, collision detection, and line clearing."
#     },
#     {
#       "id": 4,
#       "objective": "Develop a preview component that displays the next upcoming tetromino alongside the current falling piece."
#     },
#     {
#       "id": 5,
#       "objective": "Integrate UI elements such as the score counter and cleared lines display to provide real-time game stats."
#     },
#     {
#       "id": 6,
#       "objective": "Integrate all modules (grid, tetromino logic, game mechanics, preview, and UI elements) to ensure smooth gameplay and a clean, modern interface."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 3 },
#     { "parent": 1, "child": 3 },
#     { "parent": 2, "child": 3 },
#     { "parent": 2, "child": 4 },
#     { "parent": 3, "child": 5 },
#     { "parent": 4, "child": 6 },
#     { "parent": 5, "child": 6 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "Environment & Window Setup Specialist",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Graphics/UI Engineer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Tetromino Module Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "Game Mechanics Engineer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Preview Interface Developer",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "Score & Stats UI Specialist",
#       "subtasks": [5]
#     },
#     {
#       "id": "Agent 6",
#       "role": "Integration Specialist",
#       "subtasks": [6]
#     }
#   ]
# }
# 2025-03-20 10:55:09 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 10:55:09 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library featuring a standard 10x20 grid, a display for both the current falling tetromino and the next piece, a score counter, a cleared lines counter, a distinct border around the game area, and uniquely colored tetromino types with a clean, modern interface.",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall system architecture for the Tetris game, outlining core modules (game loop, grid renderer, tetromino module, UI components, and game mechanics) and defining class/function responsibilities."
#     },
#     {
#       "id": 1,
#       "objective": "Set up the pygame environment: initialize pygame, create the game window, draw the 10x20 grid, and implement a simple border to define the game area."
#     },
#     {
#       "id": 2,
#       "objective": "Develop the tetromino module that defines the shapes, unique vibrant colors, and basic movement/rotation mechanics for each tetromino."
#     },
#     {
#       "id": 3,
#       "objective": "Implement core game mechanics: code the logic for the falling piece behavior, collision detection with the grid, line clearing, and scoring system based on cleared lines."
#     },
#     {
#       "id": 4,
#       "objective": "Build user interface components: create displays for the current falling tetromino, the next upcoming piece, the score counter, and the number of cleared lines to ensure clear game state visualization."
#     },
#     {
#       "id": 5,
#       "objective": "Integrate all modules into a cohesive Tetris game: combine the pygame environment, tetromino logic, game mechanics, and UI components into a robust game loop with responsive user inputs."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 0, "child": 4 },
#     { "parent": 2, "child": 3 },
#     { "parent": 1, "child": 5 },
#     { "parent": 3, "child": 5 },
#     { "parent": 4, "child": 5 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "System Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Graphics Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Tetromino & Movement Specialist",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "Game Mechanics Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "UI Developer",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "Integration Specialist",
#       "subtasks": [5]
#     }
#   ]
# }
# 2025-03-20 10:55:14 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 10:55:14 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall game architecture and module breakdown, detailing the separation between game logic and UI, and defining clear interfaces for grid management, tetromino behavior, and user interaction."
#     },
#     {
#       "id": 1,
#       "objective": "Set up the Python development environment: install pygame and establish a structured project layout with necessary directories and initial configuration files."
#     },
#     {
#       "id": 2,
#       "objective": "Develop the core game mechanics: implement the 10x20 grid, falling tetromino logic, collision detection, piece placement, and line clearance algorithms."
#     },
#     {
#       "id": 3,
#       "objective": "Implement tetromino functionality: define all tetromino shapes with rotation logic, assign a unique vibrant color to each type, and add a next piece generation and preview module."
#     },
#     {
#       "id": 4,
#       "objective": "Develop UI components: create the score counter, cleared lines display, and design a simple border to distinctly outline the game area."
#     },
#     {
#       "id": 5,
#       "objective": "Integrate the game logic with pygame’s rendering system to build a clean, modern, and interactive user interface that updates in real-time."
#     },
#     {
#       "id": 6,
#       "objective": "Finalize integration: perform code cleanup, refine gameplay dynamics, and enhance user experience with minor performance and visual improvements."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 2 },
#     { "parent": 0, "child": 3 },
#     { "parent": 0, "child": 4 },
#     { "parent": 2, "child": 5 },
#     { "parent": 3, "child": 5 },
#     { "parent": 4, "child": 5 },
#     { "parent": 5, "child": 6 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "System Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Environment Setup Engineer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Game Mechanics Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "Tetromino Functionality Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "UI Components Developer",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "UI and Rendering Specialist",
#       "subtasks": [5]
#     },
#     {
#       "id": "Agent 6",
#       "role": "Integration and Polish Engineer",
#       "subtasks": [6]
#     }
#   ]
# }
# 2025-03-20 10:55:15 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 10:55:15 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Define the overall architecture and design document outlining key components: game board, tetromino representation, game logic, UI display, and input handling."
#     },
#     {
#       "id": 1,
#       "objective": "Develop the game board module by creating a 10x20 grid with a simple border using pygame. This module sets up the background and grid structure for gameplay."
#     },
#     {
#       "id": 2,
#       "objective": "Implement the tetromino module that defines the various tetromino shapes with unique, vibrant colors, and encapsulates their behavior (movement, rotation, and collision detection)."
#     },
#     {
#       "id": 3,
#       "objective": "Create the UI display module to render the current falling tetromino, the next upcoming piece, the score counter, and the cleared lines counter, ensuring a clean and modern interface."
#     },
#     {
#       "id": 4,
#       "objective": "Develop the game logic and input handling module to drive the main game loop. This includes managing tetromino falling, player inputs for movement and rotation, and line-clearing mechanics."
#     },
#     {
#       "id": 5,
#       "objective": "Integrate all modules into a complete Tetris game. Refine interactions between the board, tetromino, display, and game logic, and perform final code cleanup to ensure smooth gameplay and balanced performance."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 0, "child": 2 },
#     { "parent": 1, "child": 3 },
#     { "parent": 2, "child": 3 },
#     { "parent": 1, "child": 4 },
#     { "parent": 2, "child": 4 },
#     { "parent": 3, "child": 5 },
#     { "parent": 4, "child": 5 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "System Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Game Board Developer",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Tetromino Module Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "UI/Display Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Game Logic and Input Developer",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "Integration Engineer",
#       "subtasks": [5]
#     }
#   ]
# }
# 2025-03-20 10:55:15 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 10:55:16 [INFO] GPT Response: {
#   "task": "Create a Tetris game using Python with the pygame library",
#   "subtasks": [
#     {
#       "id": 0,
#       "objective": "Design the overall system architecture and layout for the Tetris game, including modules, data structures (e.g., the 10x20 grid), and UI components (current and next tetromino displays, score counter, and line counter)."
#     },
#     {
#       "id": 1,
#       "objective": "Set up the development environment by installing Python and the pygame library, and initializing the project structure."
#     },
#     {
#       "id": 2,
#       "objective": "Develop the grid module representing the standard 10x20 gameplay area, including the data structures and functions for grid management."
#     },
#     {
#       "id": 3,
#       "objective": "Implement the tetromino module to define all tetromino shapes with unique, vibrant colors and the logic for rotations and placements."
#     },
#     {
#       "id": 4,
#       "objective": "Create the core game mechanics including the falling tetromino logic, collision detection, piece locking, and line clearance, integrating the grid and tetromino modules."
#     },
#     {
#       "id": 5,
#       "objective": "Design and implement the user interface components such as drawing the game board with a border, rendering the current falling tetromino, displaying the next piece preview, and showing the score and number of cleared lines."
#     },
#     {
#       "id": 6,
#       "objective": "Integrate all modules into the main game loop, handling user inputs, updating game states, and coordinating the UI with the underlying game mechanics."
#     },
#     {
#       "id": 7,
#       "objective": "Polish the game by performing final integration adjustments, optimizing performance, and fine-tuning the user experience for a clean and modern interface."
#     }
#   ],
#   "subtask_dependencies": [
#     { "parent": 0, "child": 1 },
#     { "parent": 1, "child": 2 },
#     { "parent": 1, "child": 3 },
#     { "parent": 2, "child": 4 },
#     { "parent": 3, "child": 4 },
#     { "parent": 2, "child": 5 },
#     { "parent": 3, "child": 5 },
#     { "parent": 4, "child": 6 },
#     { "parent": 5, "child": 6 },
#     { "parent": 6, "child": 7 }
#   ],
#   "agents": [
#     {
#       "id": "Agent 0",
#       "role": "System Architect",
#       "subtasks": [0]
#     },
#     {
#       "id": "Agent 1",
#       "role": "Environment Setup Specialist",
#       "subtasks": [1]
#     },
#     {
#       "id": "Agent 2",
#       "role": "Grid Module Developer",
#       "subtasks": [2]
#     },
#     {
#       "id": "Agent 3",
#       "role": "Tetromino Module Developer",
#       "subtasks": [3]
#     },
#     {
#       "id": "Agent 4",
#       "role": "Game Mechanics Engineer",
#       "subtasks": [4]
#     },
#     {
#       "id": "Agent 5",
#       "role": "UI/Graphics Developer",
#       "subtasks": [5]
#     },
#     {
#       "id": "Agent 6",
#       "role": "Integration Specialist",
#       "subtasks": [6]
#     },
#     {
#       "id": "Agent 7",
#       "role": "Polishing and Optimization Engineer",
#       "subtasks": [7]
#     }
#   ]
# }
# 2025-03-20 10:55:16 [INFO] Executing task 'Define the overall architecture and design document outlining key components: game board, tetromino representation, game logic, UI display, and input handling.' with context: No completed previous tasks context available....
# 2025-03-20 10:55:16 [INFO] Task 'Define the overall architecture and design document outlining key components: game board, tetromino representation, game logic, UI display, and input handling.' started by agent '0'.
# Comparing...
#  Here is the detailed data.
# Dependency complexities:
# [0.6324555320336759, 0.6324555320336759, 1.3743685418725535, 1.118033988749895, 0.4898979485566356, 0.6998542122237652, 0.4714045207910317, 1.1952286093343936, 0.4714045207910317, 0.8660254037844386]
# Parallelisms:
# [1.75, 1.75, 3.0, 2.3333333333333335, 2.3333333333333335, 2.8, 2.0, 2.75, 2.75, 2.6666666666666665]
# ***********run start*********************
#
#
# "# **Instructions:**
# "
# "1. Solve only your assigned subtask, referring to the context only if necessary.
# "
# "2. Ensure your solution aligns with the overall goal and is formatted so that it can be directly used as input for downstream tasks.
# "
# "3. Do not repeat any previous output verbatim.
# "
# "4. Output required result without adding any justifications."
# "5. Strictly follow the format constraint."
# ---
#
# # **The Overall Goal**
# Create a Tetris game using Python with the pygame library.
# The game should feature a standard 10x20 grid for gameplay.
# Display the current falling tetromino and the next upcoming piece.
# Include a score counter, a display for the number of cleared lines, and a simple border to distinguish the game area.
# Each tetromino type should have a unique, vibrant color for clear visibility.
# The interface should be clean and modern, emphasizing gameplay clarity and user experience.
#
# ---
#
# # **Context from Upstream Tasks**
# No completed previous tasks context available.
#
# ---
#
# # **Downstream Tasks objectivesv**
# Task task1:
#   Objective: Develop the game board module by creating a 10x20 grid with a simple border using pygame. This module sets up the background and grid structure for gameplay.
# Task task2:
#   Objective: Implement the tetromino module that defines the various tetromino shapes with unique, vibrant colors, and encapsulates their behavior (movement, rotation, and collision detection).
#
#
# ---
#
# # **Current Task Requirements**
# Define the overall architecture and design document outlining key components: game board, tetromino representation, game logic, UI display, and input handling.
#
# ---
#
#
# ***********run end*********************
# 2025-03-20 10:55:21 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ***********run start*********************
#
# "# **Instructions:**
# "
# "1. You need to revise the subtask results based on the latest feedback and historical information.
# "
# "2. Output required result without adding any justifications."
# "3. Strictly follow the format constraint."
# ---
#
# # **The Overall Goal**
# Create a Tetris game using Python with the pygame library.
# The game should feature a standard 10x20 grid for gameplay.
# Display the current falling tetromino and the next upcoming piece.
# Include a score counter, a display for the number of cleared lines, and a simple border to distinguish the game area.
# Each tetromino type should have a unique, vibrant color for clear visibility.
# The interface should be clean and modern, emphasizing gameplay clarity and user experience.
#
# ---
#
# # **Context from Upstream Tasks**
# No completed previous tasks context available.
#
# ---
#
# # **Downstream Tasks objectives**
# Task task1:
#   Objective: Develop the game board module by creating a 10x20 grid with a simple border using pygame. This module sets up the background and grid structure for gameplay.
# Task task2:
#   Objective: Implement the tetromino module that defines the various tetromino shapes with unique, vibrant colors, and encapsulates their behavior (movement, rotation, and collision detection).
#
# ---
#
# # **Current Task Requirements**
# Define the overall architecture and design document outlining key components: game board, tetromino representation, game logic, UI display, and input handling.
#
# ---
#
# # **Current Task Historical Results and Their Feedbacks**
#
#
# ***********run end*********************
# 2025-03-20 10:55:33 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ------Run pythonValidator.is_python_code()------
# 2025-03-20 10:55:36 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 10:55:39 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 10:55:39 [INFO] Task task0 done. Total completed so far: 1
# 2025-03-20 10:55:39 [INFO] Executing task 'Develop the game board module by creating a 10x20 grid with a simple border using pygame. This module sets up the background and grid structure for gameplay.' with context: Task task0:
#   Objective: Define the overall architecture and design document outlining key component...
# 2025-03-20 10:55:39 [INFO] Task 'Develop the game board module by creating a 10x20 grid with a simple border using pygame. This module sets up the background and grid structure for gameplay.' started by agent '1'.
# 2025-03-20 10:55:39 [INFO] Executing task 'Implement the tetromino module that defines the various tetromino shapes with unique, vibrant colors, and encapsulates their behavior (movement, rotation, and collision detection).' with context: Task task0:
#   Objective: Define the overall architecture and design document outlining key component...
# 2025-03-20 10:55:39 [INFO] Task 'Implement the tetromino module that defines the various tetromino shapes with unique, vibrant colors, and encapsulates their behavior (movement, rotation, and collision detection).' started by agent '2'.
# 1 3
# ***********run start*********************
#
#
# "# **Instructions:**
# "
# "1. Solve only your assigned subtask, referring to the context only if necessary.
# "
# "2. Ensure your solution aligns with the overall goal and is formatted so that it can be directly used as input for downstream tasks.
# "
# "3. Do not repeat any previous output verbatim.
# "
# "4. Output required result without adding any justifications."
# "5. Strictly follow the format constraint."
# ---
#
# # **The Overall Goal**
# Create a Tetris game using Python with the pygame library.
# The game should feature a standard 10x20 grid for gameplay.
# Display the current falling tetromino and the next upcoming piece.
# Include a score counter, a display for the number of cleared lines, and a simple border to distinguish the game area.
# Each tetromino type should have a unique, vibrant color for clear visibility.
# The interface should be clean and modern, emphasizing gameplay clarity and user experience.
#
# ---
#
# # **Context from Upstream Tasks**
# Task task0:
#   Objective: Define the overall architecture and design document outlining key components: game board, tetromino representation, game logic, UI display, and input handling.
#   Result: Overall Architecture and Design Document
#
# 1. Game Board Module
#    - Create a 10x20 grid representing each cell as a drawable rectangle.
#    - Define the grid boundaries and a simple border for the game area.
#    - Handle background rendering using the pygame library.
#
# 2. Tetromino Module
#    - Represent each tetromino as an object with properties for shape and position.
#    - Define tetromino shapes using matrices or coordinate lists.
#    - Assign a unique, vibrant color to each tetromino type.
#    - Include methods for movement (left, right, down), rotation, and collision detection with the game board and other tetrominoes.
#
# 3. Game Logic Module
#    - Control the falling tetromino behavior (automatic descent, collision checking, locking in place).
#    - Manage line clearance by identifying and removing completed rows.
#    - Update the grid state following tetromino placement and line clearance.
#    - Integrate scoring system logic where points awarded depend on the number of lines cleared simultaneously.
#    - Maintain level progression based on score or lines cleared.
#
# 4. UI Display Module
#    - Render the game board grid including the border.
#    - Display the current falling tetromino on the grid.
#    - Provide a preview area showing the next tetromino piece.
#    - Render a score counter and a cleared lines counter on the screen.
#    - Use a clean and modern interface style to ensure gameplay clarity and an engaging user experience.
#
# 5. Input Handling Module
#    - Process user inputs (keyboard events) for moving and rotating tetrominoes.
#    - Allow for pausing and restarting the game.
#    - Ensure inputs are responsive and do not interfere with ongoing game logic.
#
# 6. Integration and Main Game Loop
#    - Initialize pygame and set up the game display.
#    - Create instances of the game board and tetromino modules.
#    - Implement the main game loop to repeatedly update game logic, process user input, and refresh the display.
#    - Control the game timing and speed adjustments as the game progresses.
#
# 7. Additional Considerations
#    - Ensure modular design to facilitate future enhancements or refactoring.
#    - Employ collision detection both in tetromino movement and rotation to prevent illegal moves.
#    - Incorporate error handling to manage unexpected game states and input events.
#    - Optimize rendering to maintain smooth performance even on lower-end hardware.
#
# ---
#
# # **Downstream Tasks objectivesv**
# Task task3:
#   Objective: Create the UI display module to render the current falling tetromino, the next upcoming piece, the score counter, and the cleared lines counter, ensuring a clean and modern interface.
# Task task4:
#   Objective: Develop the game logic and input handling module to drive the main game loop. This includes managing tetromino falling, player inputs for movement and rotation, and line-clearing mechanics.
#
#
# ---
#
# # **Current Task Requirements**
# Develop the game board module by creating a 10x20 grid with a simple border using pygame. This module sets up the background and grid structure for gameplay.
#
# ---
#
#
# ***********run end*********************
# ***********run start*********************
#
#
# "# **Instructions:**
# "
# "1. Solve only your assigned subtask, referring to the context only if necessary.
# "
# "2. Ensure your solution aligns with the overall goal and is formatted so that it can be directly used as input for downstream tasks.
# "
# "3. Do not repeat any previous output verbatim.
# "
# "4. Output required result without adding any justifications."
# "5. Strictly follow the format constraint."
# ---
#
# # **The Overall Goal**
# Create a Tetris game using Python with the pygame library.
# The game should feature a standard 10x20 grid for gameplay.
# Display the current falling tetromino and the next upcoming piece.
# Include a score counter, a display for the number of cleared lines, and a simple border to distinguish the game area.
# Each tetromino type should have a unique, vibrant color for clear visibility.
# The interface should be clean and modern, emphasizing gameplay clarity and user experience.
#
# ---
#
# # **Context from Upstream Tasks**
# Task task0:
#   Objective: Define the overall architecture and design document outlining key components: game board, tetromino representation, game logic, UI display, and input handling.
#   Result: Overall Architecture and Design Document
#
# 1. Game Board Module
#    - Create a 10x20 grid representing each cell as a drawable rectangle.
#    - Define the grid boundaries and a simple border for the game area.
#    - Handle background rendering using the pygame library.
#
# 2. Tetromino Module
#    - Represent each tetromino as an object with properties for shape and position.
#    - Define tetromino shapes using matrices or coordinate lists.
#    - Assign a unique, vibrant color to each tetromino type.
#    - Include methods for movement (left, right, down), rotation, and collision detection with the game board and other tetrominoes.
#
# 3. Game Logic Module
#    - Control the falling tetromino behavior (automatic descent, collision checking, locking in place).
#    - Manage line clearance by identifying and removing completed rows.
#    - Update the grid state following tetromino placement and line clearance.
#    - Integrate scoring system logic where points awarded depend on the number of lines cleared simultaneously.
#    - Maintain level progression based on score or lines cleared.
#
# 4. UI Display Module
#    - Render the game board grid including the border.
#    - Display the current falling tetromino on the grid.
#    - Provide a preview area showing the next tetromino piece.
#    - Render a score counter and a cleared lines counter on the screen.
#    - Use a clean and modern interface style to ensure gameplay clarity and an engaging user experience.
#
# 5. Input Handling Module
#    - Process user inputs (keyboard events) for moving and rotating tetrominoes.
#    - Allow for pausing and restarting the game.
#    - Ensure inputs are responsive and do not interfere with ongoing game logic.
#
# 6. Integration and Main Game Loop
#    - Initialize pygame and set up the game display.
#    - Create instances of the game board and tetromino modules.
#    - Implement the main game loop to repeatedly update game logic, process user input, and refresh the display.
#    - Control the game timing and speed adjustments as the game progresses.
#
# 7. Additional Considerations
#    - Ensure modular design to facilitate future enhancements or refactoring.
#    - Employ collision detection both in tetromino movement and rotation to prevent illegal moves.
#    - Incorporate error handling to manage unexpected game states and input events.
#    - Optimize rendering to maintain smooth performance even on lower-end hardware.
#
# ---
#
# # **Downstream Tasks objectivesv**
# Task task3:
#   Objective: Create the UI display module to render the current falling tetromino, the next upcoming piece, the score counter, and the cleared lines counter, ensuring a clean and modern interface.
# Task task4:
#   Objective: Develop the game logic and input handling module to drive the main game loop. This includes managing tetromino falling, player inputs for movement and rotation, and line-clearing mechanics.
#
#
# ---
#
# # **Current Task Requirements**
# Implement the tetromino module that defines the various tetromino shapes with unique, vibrant colors, and encapsulates their behavior (movement, rotation, and collision detection).
#
# ---
#
#
# ***********run end*********************
# 2025-03-20 10:55:48 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ***********run start*********************
#
# "# **Instructions:**
# "
# "1. You need to revise the subtask results based on the latest feedback and historical information.
# "
# "2. Output required result without adding any justifications."
# "3. Strictly follow the format constraint."
# ---
#
# # **The Overall Goal**
# Create a Tetris game using Python with the pygame library.
# The game should feature a standard 10x20 grid for gameplay.
# Display the current falling tetromino and the next upcoming piece.
# Include a score counter, a display for the number of cleared lines, and a simple border to distinguish the game area.
# Each tetromino type should have a unique, vibrant color for clear visibility.
# The interface should be clean and modern, emphasizing gameplay clarity and user experience.
#
# ---
#
# # **Context from Upstream Tasks**
# Task task0:
#   Objective: Define the overall architecture and design document outlining key components: game board, tetromino representation, game logic, UI display, and input handling.
#   Result: Overall Architecture and Design Document
#
# 1. Game Board Module
#    - Create a 10x20 grid representing each cell as a drawable rectangle.
#    - Define the grid boundaries and a simple border for the game area.
#    - Handle background rendering using the pygame library.
#
# 2. Tetromino Module
#    - Represent each tetromino as an object with properties for shape and position.
#    - Define tetromino shapes using matrices or coordinate lists.
#    - Assign a unique, vibrant color to each tetromino type.
#    - Include methods for movement (left, right, down), rotation, and collision detection with the game board and other tetrominoes.
#
# 3. Game Logic Module
#    - Control the falling tetromino behavior (automatic descent, collision checking, locking in place).
#    - Manage line clearance by identifying and removing completed rows.
#    - Update the grid state following tetromino placement and line clearance.
#    - Integrate scoring system logic where points awarded depend on the number of lines cleared simultaneously.
#    - Maintain level progression based on score or lines cleared.
#
# 4. UI Display Module
#    - Render the game board grid including the border.
#    - Display the current falling tetromino on the grid.
#    - Provide a preview area showing the next tetromino piece.
#    - Render a score counter and a cleared lines counter on the screen.
#    - Use a clean and modern interface style to ensure gameplay clarity and an engaging user experience.
#
# 5. Input Handling Module
#    - Process user inputs (keyboard events) for moving and rotating tetrominoes.
#    - Allow for pausing and restarting the game.
#    - Ensure inputs are responsive and do not interfere with ongoing game logic.
#
# 6. Integration and Main Game Loop
#    - Initialize pygame and set up the game display.
#    - Create instances of the game board and tetromino modules.
#    - Implement the main game loop to repeatedly update game logic, process user input, and refresh the display.
#    - Control the game timing and speed adjustments as the game progresses.
#
# 7. Additional Considerations
#    - Ensure modular design to facilitate future enhancements or refactoring.
#    - Employ collision detection both in tetromino movement and rotation to prevent illegal moves.
#    - Incorporate error handling to manage unexpected game states and input events.
#    - Optimize rendering to maintain smooth performance even on lower-end hardware.
#
# ---
#
# # **Downstream Tasks objectives**
# Task task3:
#   Objective: Create the UI display module to render the current falling tetromino, the next upcoming piece, the score counter, and the cleared lines counter, ensuring a clean and modern interface.
# Task task4:
#   Objective: Develop the game logic and input handling module to drive the main game loop. This includes managing tetromino falling, player inputs for movement and rotation, and line-clearing mechanics.
#
# ---
#
# # **Current Task Requirements**
# Implement the tetromino module that defines the various tetromino shapes with unique, vibrant colors, and encapsulates their behavior (movement, rotation, and collision detection).
#
# ---
#
# # **Current Task Historical Results and Their Feedbacks**
#
#
# ***********run end*********************
# 2025-03-20 10:55:49 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ***********run start*********************
#
# "# **Instructions:**
# "
# "1. You need to revise the subtask results based on the latest feedback and historical information.
# "
# "2. Output required result without adding any justifications."
# "3. Strictly follow the format constraint."
# ---
#
# # **The Overall Goal**
# Create a Tetris game using Python with the pygame library.
# The game should feature a standard 10x20 grid for gameplay.
# Display the current falling tetromino and the next upcoming piece.
# Include a score counter, a display for the number of cleared lines, and a simple border to distinguish the game area.
# Each tetromino type should have a unique, vibrant color for clear visibility.
# The interface should be clean and modern, emphasizing gameplay clarity and user experience.
#
# ---
#
# # **Context from Upstream Tasks**
# Task task0:
#   Objective: Define the overall architecture and design document outlining key components: game board, tetromino representation, game logic, UI display, and input handling.
#   Result: Overall Architecture and Design Document
#
# 1. Game Board Module
#    - Create a 10x20 grid representing each cell as a drawable rectangle.
#    - Define the grid boundaries and a simple border for the game area.
#    - Handle background rendering using the pygame library.
#
# 2. Tetromino Module
#    - Represent each tetromino as an object with properties for shape and position.
#    - Define tetromino shapes using matrices or coordinate lists.
#    - Assign a unique, vibrant color to each tetromino type.
#    - Include methods for movement (left, right, down), rotation, and collision detection with the game board and other tetrominoes.
#
# 3. Game Logic Module
#    - Control the falling tetromino behavior (automatic descent, collision checking, locking in place).
#    - Manage line clearance by identifying and removing completed rows.
#    - Update the grid state following tetromino placement and line clearance.
#    - Integrate scoring system logic where points awarded depend on the number of lines cleared simultaneously.
#    - Maintain level progression based on score or lines cleared.
#
# 4. UI Display Module
#    - Render the game board grid including the border.
#    - Display the current falling tetromino on the grid.
#    - Provide a preview area showing the next tetromino piece.
#    - Render a score counter and a cleared lines counter on the screen.
#    - Use a clean and modern interface style to ensure gameplay clarity and an engaging user experience.
#
# 5. Input Handling Module
#    - Process user inputs (keyboard events) for moving and rotating tetrominoes.
#    - Allow for pausing and restarting the game.
#    - Ensure inputs are responsive and do not interfere with ongoing game logic.
#
# 6. Integration and Main Game Loop
#    - Initialize pygame and set up the game display.
#    - Create instances of the game board and tetromino modules.
#    - Implement the main game loop to repeatedly update game logic, process user input, and refresh the display.
#    - Control the game timing and speed adjustments as the game progresses.
#
# 7. Additional Considerations
#    - Ensure modular design to facilitate future enhancements or refactoring.
#    - Employ collision detection both in tetromino movement and rotation to prevent illegal moves.
#    - Incorporate error handling to manage unexpected game states and input events.
#    - Optimize rendering to maintain smooth performance even on lower-end hardware.
#
# ---
#
# ...
# SURFACE_BG_COLOR = (30, 30, 30)
# FONT_COLOR = (255, 255, 255)
#
# TETROMINO_SHAPES = {
#     'I': [[1, 1, 1, 1]],
#     'O': [[1, 1],
#           [1, 1]],
#     'T': [[0, 1, 0],
#           [1, 1, 1]],
#     'S': [[0, 1, 1],
#           [1, 1, 0]],
#     'Z': [[1, 1, 0],
#           [0, 1, 1]],
#     'J': [[1, 0, 0],
#           [1, 1, 1]],
#     'L': [[0, 0, 1],
#           [1, 1, 1]]
# }
#
# TETROMINO_COLORS = {
#     'I': (0, 255, 255),
#     'O': (255, 255, 0),
#     'T': (128, 0, 128),
#     'S': (0, 255, 0),
#     'Z': (255, 0, 0),
#     'J': (0, 0, 255),
#     'L': (255, 165, 0)
# }
#
# def rotate_matrix(matrix):
#     return [list(row) for row in zip(*matrix[::-1])]
#
# class Tetromino:
#     def __init__(self, shape, position=(3, 0)):
#         self.type = shape
#         self.matrix = copy.deepcopy(TETROMINO_SHAPES[shape])
#         self.color = TETROMINO_COLORS[shape]
#         self.position = list(position)
#     def get_cells(self):
#         cells = []
#         for i, row in enumerate(self.matrix):
#             for j, cell in enumerate(row):
#                 if cell:
#                     cells.append((self.position[0] + j, self.position[1] + i))
#         return cells
#     def valid_position(self, grid, grid_width, grid_height):
#         for x, y in self.get_cells():
#             if x < 0 or x >= grid_width or y < 0 or y >= grid_height:
#                 return False
#             if grid[y][x]:
#                 return False
#         return True
#     def move_left(self, grid, grid_width, grid_height):
#         self.position[0] -= 1
#         if not self.valid_position(grid, grid_width, grid_height):
#             self.position[0] += 1
#             return False
#         return True
#     def move_right(self, grid, grid_width, grid_height):
#         self.position[0] += 1
#         if not self.valid_position(grid, grid_width, grid_height):
#             self.position[0] -= 1
#             return False
#         return True
#     def move_down(self, grid, grid_width, grid_height):
#         self.position[1] += 1
#         if not self.valid_position(grid, grid_width, grid_height):
#             self.position[1] -= 1
#             return False
#         return True
#     def rotate(self, grid, grid_width, grid_height):
#         old_matrix = copy.deepcopy(self.matrix)
#         self.matrix = rotate_matrix(self.matrix)
#         if not self.valid_position(grid, grid_width, grid_height):
#             self.matrix = old_matrix
#             return False
#         return True
#
# class GameBoard:
#     def __init__(self, surface, pos_x, pos_y):
#         self.surface = surface
#         self.x = pos_x
#         self.y = pos_y
#         self.width = GRID_WIDTH
#         self.height = GRID_HEIGHT
#         self.rect = pygame.Rect(self.x, self.y, self.width, self.height)
#     def draw(self, grid):
#         pygame.draw.rect(self.surface, BACKGROUND_COLOR, self.rect)
#         for row in range(ROWS):
#             for col in range(COLS):
#                 cell_rect = pygame.Rect(
#                     self.x + col * CELL_SIZE,
#                     self.y + row * CELL_SIZE,
#                     CELL_SIZE,
#                     CELL_SIZE
#                 )
#                 if grid[row][col]:
#                     pygame.draw.rect(self.surface, grid[row][col], cell_rect)
#                 pygame.draw.rect(self.surface, GRID_LINE_COLOR, cell_rect, 1)
#         pygame.draw.rect(self.surface, BORDER_COLOR, self.rect, BORDER_WIDTH)
#
# def create_grid():
#     return [[0 for _ in range(COLS)] for _ in range(ROWS)]
#
# def merge_tetromino(grid, tetromino):
#     for x, y in tetromino.get_cells():
#         if y >= 0:
#             grid[y][x] = tetromino.color
#
# def clear_lines(grid):
#     cleared = 0
#     new_grid = [row for row in grid if 0 in row]
#     cleared = ROWS - len(new_grid)
#     for _ in range(cleared):
#         new_grid.insert(0, [0 for _ in range(COLS)])
#     return new_grid, cleared
#
# def draw_tetromino(surface, tetromino, offset_x, offset_y):
#     for i, row in enumerate(tetromino.matrix):
#         for j, cell in enumerate(row):
#             if cell:
#                 cell_rect = pygame.Rect(
#                     offset_x + j * CELL_SIZE,
#                     offset_y + i * CELL_SIZE,
#                     CELL_SIZE,
#                     CELL_SIZE
#                 )
#                 pygame.draw.rect(surface, tetromino.color, cell_rect)
#                 pygame.draw.rect(surface, GRID_LINE_COLOR, cell_rect, 1)
#
# def main():
#     pygame.init()
#     window_width = GRID_WIDTH + 200
#     window_height = GRID_HEIGHT + 100
#     screen = pygame.display.set_mode((window_width, window_height))
#     pygame.display.set_caption("Tetris")
#     clock = pygame.time.Clock()
#     font = pygame.font.SysFont("Arial", 24)
#
#     board = GameBoard(screen, 50, 50)
#     grid = create_grid()
#
#     current_piece = Tetromino(random.choice(list(TETROMINO_SHAPES.keys())))
#     next_piece = Tetromino(random.choice(list(TETROMINO_SHAPES.keys())))
#     fall_time = 0
#     fall_speed = 500
#     score = 0
#     lines_cleared_total = 0
#
#     running = True
#     while running:
#         dt = clock.tick(60)
#         fall_time += dt
#
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 running = False
#                 break
#             if event.type == pygame.KEYDOWN:
#                 if event.key == pygame.K_LEFT:
#                     current_piece.move_left(grid, COLS, ROWS)
#                 elif event.key == pygame.K_RIGHT:
#                     current_piece.move_right(grid, COLS, ROWS)
#                 elif event.key == pygame.K_DOWN:
#                     current_piece.move_down(grid, COLS, ROWS)
#                 elif event.key == pygame.K_UP:
#                     current_piece.rotate(grid, COLS, ROWS)
#
#         if fall_time >= fall_speed:
#             fall_time = 0
#             if not current_piece.move_down(grid, COLS, ROWS):
#                 merge_tetromino(grid, current_piece)
#                 grid, cleared = clear_lines(grid)
#                 if cleared:
#                     lines_cleared_total += cleared
#                     score += cleared * 10
#                 current_piece = next_piece
#                 next_piece = Tetromino(random.choice(list(TETROMINO_SHAPES.keys())))
#                 if not current_piece.valid_position(grid, COLS, ROWS):
#                     running = False
#
#         screen.fill(SURFACE_BG_COLOR)
#         board.draw(grid)
#
#         for x, y in current_piece.get_cells():
#             if y >= 0:
#                 cell_rect = pygame.Rect(
#                     board.x + x * CELL_SIZE,
#                     board.y + y * CELL_SIZE,
#                     CELL_SIZE,
#                     CELL_SIZE
#                 )
#                 pygame.draw.rect(screen, current_piece.color, cell_rect)
#                 pygame.draw.rect(screen, GRID_LINE_COLOR, cell_rect, 1)
#
#         next_label = font.render("Next:", True, FONT_COLOR)
#         screen.blit(next_label, (GRID_WIDTH + 70, 50))
#         draw_tetromino(screen, next_piece, GRID_WIDTH + 70, 80)
#
#         score_text = font.render("Score: " + str(score), True, FONT_COLOR)
#         screen.blit(score_text, (GRID_WIDTH + 70, 200))
#         lines_text = font.render("Lines: " + str(lines_cleared_total), True, FONT_COLOR)
#         screen.blit(lines_text, (GRID_WIDTH + 70, 240))
#
#         pygame.display.flip()
#
#     pygame.quit()
#     sys.exit()
#
# if __name__ == "__main__":
#     main()
# 2025-03-20 11:00:15 [INFO]  - task5: #!/usr/bin/env python3
# import sys
# import pygame
# import random
# import copy
#
# # Global constants
# CELL_SIZE = 30
# COLS = 10
# ROWS = 20
# GRID_WIDTH = COLS * CELL_SIZE
# GRID_HEIGHT = ROWS * CELL_SIZE
# BORDER_WIDTH = 4
# BORDER_COLOR = (255, 255, 255)
# GRID_LINE_COLOR = (50, 50, 50)
# BACKGROUND_COLOR = (0, 0, 0)
# SURFACE_BG_COLOR = (30, 30, 30)
# FONT_COLOR = (255, 255, 255)
#
# # Tetromino data
# TETROMINO_SHAPES = {
#     'I': [[1, 1, 1, 1]],
#     'O': [[1, 1],
#           [1, 1]],
#     'T': [[0, 1, 0],
#           [1, 1, 1]],
#     'S': [[0, 1, 1],
#           [1, 1, 0]],
#     'Z': [[1, 1, 0],
#           [0, 1, 1]],
#     'J': [[1, 0, 0],
#           [1, 1, 1]],
#     'L': [[0, 0, 1],
#           [1, 1, 1]]
# }
#
# TETROMINO_COLORS = {
#     'I': (0, 255, 255),
#     'O': (255, 255, 0),
#     'T': (128, 0, 128),
#     'S': (0, 255, 0),
#     'Z': (255, 0, 0),
#     'J': (0, 0, 255),
#     'L': (255, 165, 0)
# }
#
# def rotate_matrix(matrix):
#     return [list(row) for row in zip(*matrix[::-1])]
#
# class Tetromino:
#     def __init__(self, shape, position=(3, 0)):
#         self.type = shape
#         self.matrix = copy.deepcopy(TETROMINO_SHAPES[shape])
#         self.color = TETROMINO_COLORS[shape]
#         self.position = list(position)
#
#     def get_cells(self):
#         cells = []
#         for i, row in enumerate(self.matrix):
#             for j, cell in enumerate(row):
#                 if cell:
#                     cells.append((self.position[0] + j, self.position[1] + i))
#         return cells
#
#     def valid_position(self, grid, grid_width, grid_height):
#         for x, y in self.get_cells():
#             if x < 0 or x >= grid_width or y < 0 or y >= grid_height:
#                 return False
#             if grid[y][x]:
#                 return False
#         return True
#
#     def move_left(self, grid, grid_width, grid_height):
#         self.position[0] -= 1
#         if not self.valid_position(grid, grid_width, grid_height):
#             self.position[0] += 1
#             return False
#         return True
#
#     def move_right(self, grid, grid_width, grid_height):
#         self.position[0] += 1
#         if not self.valid_position(grid, grid_width, grid_height):
#             self.position[0] -= 1
#             return False
#         return True
#
#     def move_down(self, grid, grid_width, grid_height):
#         self.position[1] += 1
#         if not self.valid_position(grid, grid_width, grid_height):
#             self.position[1] -= 1
#             return False
#         return True
#
#     def rotate(self, grid, grid_width, grid_height):
#         old_matrix = copy.deepcopy(self.matrix)
#         self.matrix = rotate_matrix(self.matrix)
#         if not self.valid_position(grid, grid_width, grid_height):
#             self.matrix = old_matrix
#             return False
#         return True
#
# class GameBoard:
#     def __init__(self, surface, pos_x, pos_y):
#         self.surface = surface
#         self.x = pos_x
#         self.y = pos_y
#         self.width = GRID_WIDTH
#         self.height = GRID_HEIGHT
#         self.rect = pygame.Rect(self.x, self.y, self.width, self.height)
#
#     def draw(self, grid):
#         pygame.draw.rect(self.surface, BACKGROUND_COLOR, self.rect)
#         for row in range(ROWS):
#             for col in range(COLS):
#                 cell_rect = pygame.Rect(
#                     self.x + col * CELL_SIZE,
#                     self.y + row * CELL_SIZE,
#                     CELL_SIZE,
#                     CELL_SIZE
#                 )
#                 if grid[row][col]:
#                     pygame.draw.rect(self.surface, grid[row][col], cell_rect)
#                 pygame.draw.rect(self.surface, GRID_LINE_COLOR, cell_rect, 1)
#         pygame.draw.rect(self.surface, BORDER_COLOR, self.rect, BORDER_WIDTH)
#
# class UIDisplay:
#     def __init__(self, surface):
#         self.surface = surface
#         pygame.font.init()
#         self.font = pygame.font.SysFont("Arial", 24)
#         self.title_font = pygame.font.SysFont("Arial", 28, bold=True)
#         self.ui_color = (255, 255, 255)
#         self.next_piece_rect = pygame.Rect(GRID_WIDTH + 70, 50, CELL_SIZE * 4, CELL_SIZE * 4)
#         self.score_position = (GRID_WIDTH + 70, 200)
#         self.lines_position = (GRID_WIDTH + 70, 240)
#         self.title_position = (GRID_WIDTH + 70, 20)
#
#     def draw_current_tetromino(self, tetromino, board_rect):
#         for x, y in tetromino.get_cells():
#             if y >= 0:
#                 cell_x = board_rect.x + x * CELL_SIZE
#                 cell_y = board_rect.y + y * CELL_SIZE
#                 cell_rect = pygame.Rect(cell_x, cell_y, CELL_SIZE, CELL_SIZE)
#                 pygame.draw.rect(self.surface, tetromino.color, cell_rect)
#                 pygame.draw.rect(self.surface, GRID_LINE_COLOR, cell_rect, 1)
#
#     def draw_next_piece(self, tetromino):
#         pygame.draw.rect(self.surface, BACKGROUND_COLOR, self.next_piece_rect)
#         for i, row in enumerate(tetromino.matrix):
#             for j, cell in enumerate(row):
#                 if cell:
#                     cell_rect = pygame.Rect(
#                         self.next_piece_rect.x + j * CELL_SIZE,
#                         self.next_piece_rect.y + i * CELL_SIZE,
#                         CELL_SIZE,
#                         CELL_SIZE
#                     )
#                     pygame.draw.rect(self.surface, tetromino.color, cell_rect)
#                     pygame.draw.rect(self.surface, GRID_LINE_COLOR, cell_rect, 1)
#         pygame.draw.rect(self.surface, BORDER_COLOR, self.next_piece_rect, BORDER_WIDTH)
#
#     def draw_score(self, score):
#         score_text = self.font.render(f"Score: {score}", True, self.ui_color)
#         self.surface.blit(score_text, self.score_position)
#
#     def draw_lines(self, lines):
#         lines_text = self.font.render(f"Lines: {lines}", True, self.ui_color)
#         self.surface.blit(lines_text, self.lines_position)
#
#     def draw_title(self):
#         title_text = self.title_font.render("NEXT", True, self.ui_color)
#         self.surface.blit(title_text, (self.next_piece_rect.x, self.next_piece_rect.y - 30))
#
# def create_grid():
#     return [[0 for _ in range(COLS)] for _ in range(ROWS)]
#
# def merge_tetromino(grid, tetromino):
#     for x, y in tetromino.get_cells():
#         if y >= 0:
#             grid[y][x] = tetromino.color
#
# def clear_lines(grid):
#     cleared = 0
#     new_grid = [row for row in grid if 0 in row]
#     cleared = ROWS - len(new_grid)
#     for _ in range(cleared):
#         new_grid.insert(0, [0 for _ in range(COLS)])
#     return new_grid, cleared
#
# def main():
#     pygame.init()
#     window_width = GRID_WIDTH + 250
#     window_height = GRID_HEIGHT + 100
#     screen = pygame.display.set_mode((window_width, window_height))
#     pygame.display.set_caption("Tetris")
#     clock = pygame.time.Clock()
#
#     board = GameBoard(screen, 50, 50)
#     ui = UIDisplay(screen)
#     grid = create_grid()
#
#     current_piece = Tetromino(random.choice(list(TETROMINO_SHAPES.keys())))
#     next_piece = Tetromino(random.choice(list(TETROMINO_SHAPES.keys())), position=(0,0))
#     fall_time = 0
#     fall_speed = 500
#     score = 0
#     lines_cleared_total = 0
#
#     running = True
#     while running:
#         dt = clock.tick(60)
#         fall_time += dt
#
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 running = False
#                 break
#             if event.type == pygame.KEYDOWN:
#                 if event.key == pygame.K_LEFT:
#                     current_piece.move_left(grid, COLS, ROWS)
#                 elif event.key == pygame.K_RIGHT:
#                     current_piece.move_right(grid, COLS, ROWS)
#                 elif event.key == pygame.K_DOWN:
#                     current_piece.move_down(grid, COLS, ROWS)
#                 elif event.key == pygame.K_UP:
#                     current_piece.rotate(grid, COLS, ROWS)
#
#         if fall_time >= fall_speed:
#             fall_time = 0
#             if not current_piece.move_down(grid, COLS, ROWS):
#                 merge_tetromino(grid, current_piece)
#                 grid, cleared = clear_lines(grid)
#                 if cleared:
#                     lines_cleared_total += cleared
#                     score += cleared * 10
#                 current_piece = next_piece
#                 next_piece = Tetromino(random.choice(list(TETROMINO_SHAPES.keys())), position=(0,0))
#                 if not current_piece.valid_position(grid, COLS, ROWS):
#                     running = False
#
#         screen.fill(SURFACE_BG_COLOR)
#         board.draw(grid)
#         ui.draw_current_tetromino(current_piece, board.rect)
#         ui.draw_title()
#         ui.draw_next_piece(next_piece)
#         ui.draw_score(score)
#         ui.draw_lines(lines_cleared_total)
#         pygame.display.flip()
#
#     pygame.quit()
#     sys.exit()
#
# if __name__ == "__main__":
#     main()
# ------Run pythonValidator.execute_python_code------
# ***Python code with no bugs***
# 3 3

# %% [markdown]
# ### Store necessary information and summary the output

# %%
workflow_data = {}

for tid, task in manager.workflow.tasks.items():
    custom_task_data = {
        'id': task.id,
        'objective': task.objective,
        'agent_id': task.agent_id,
        'next': task.next,
        'prev': task.prev,
        'status': task.status,
        'remaining_dependencies': task.remaining_dependencies,
        'agent': task.agent,
        'history': task.history.get_latest_result(),
    }
    
    workflow_data[tid] = custom_task_data
    
# Store the final workflow
with open('manually_result.json', 'w', encoding='utf-8') as file:
    json.dump(workflow_data, file, indent=4)

summary = Summary()

# Generate and save a summary of the workflow results
chat_result = summary.summary(overall_task, workflow_data)
with open("example.txt", "w", encoding="utf-8") as file:
    file.write(chat_result)
# Out:
# 2025-03-20 11:00:55 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 11:00:55 [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"

# %% [markdown]
# The following python file represents the outcome generated by our FLOW.

# %%
#!/usr/bin/env python3
import tkinter as tk
import random

# Game configuration and constants
BOARD_WIDTH = 10
BOARD_HEIGHT = 20
BLOCK_SIZE = 30
BOARD_PIXEL_WIDTH = BOARD_WIDTH * BLOCK_SIZE
BOARD_PIXEL_HEIGHT = BOARD_HEIGHT * BLOCK_SIZE
NEXT_PREVIEW_SIZE = 4 * BLOCK_SIZE
FALL_INTERVAL = 500  # Milliseconds between automatic falls

# Tetromino shapes and corresponding colors
TETROMINO_SHAPES = {
    "I": [[1, 1, 1, 1]],
    "O": [[1, 1],
          [1, 1]],
    "T": [[0, 1, 0],
          [1, 1, 1]],
    "S": [[0, 1, 1],
          [1, 1, 0]],
    "Z": [[1, 1, 0],
          [0, 1, 1]],
    "J": [[1, 0, 0],
          [1, 1, 1]],
    "L": [[0, 0, 1],
          [1, 1, 1]]
}

TETROMINO_COLORS = {
    "I": "cyan",
    "O": "yellow",
    "T": "purple",
    "S": "green",
    "Z": "red",
    "J": "blue",
    "L": "orange"
}

def rotate_shape(shape):
    """Rotate a tetromino shape clockwise."""
    return [list(row) for row in zip(*shape[::-1])]

class Tetromino:
    def __init__(self, shape_key, shape, color):
        self.shape_key = shape_key
        self.shape = shape  # 2D list representing the tetromino
        self.color = color
        # Spawn position centered at the top row
        self.x = BOARD_WIDTH // 2 - len(shape[0]) // 2
        self.y = 0

    def rotate(self):
        self.shape = rotate_shape(self.shape)

class TetrisGUI:
    def __init__(self, root):
        self.root = root
        self.root.title("Tetris")
        self.setup_widgets()

    def setup_widgets(self):
        # Main frame with some padding
        self.main_frame = tk.Frame(self.root, bg="black")
        self.main_frame.pack(padx=10, pady=10)
        # Game board canvas
        self.board_canvas = tk.Canvas(
            self.main_frame, width=BOARD_PIXEL_WIDTH, height=BOARD_PIXEL_HEIGHT, bg="white"
        )
        self.board_canvas.grid(row=0, column=0, rowspan=2, padx=10, pady=10)
        # Score label
        self.score_label = tk.Label(self.main_frame, text="Score: 0", font=("Arial", 16))
        self.score_label.grid(row=0, column=1, padx=10, pady=10, sticky="n")
        # Next tetromino preview
        self.next_label = tk.Label(self.main_frame, text="Next:", font=("Arial", 16))
        self.next_label.grid(row=1, column=1, padx=10, pady=(20,5), sticky="nw")
        self.next_canvas = tk.Canvas(
            self.main_frame, width=NEXT_PREVIEW_SIZE, height=NEXT_PREVIEW_SIZE, bg="white"
        )
        self.next_canvas.grid(row=1, column=1, padx=10, pady=(60,10), sticky="nw")

    def update_score(self, score):
        self.score_label.config(text=f"Score: {score}")

    def draw_board(self, board):
        self.board_canvas.delete("all")
        for y in range(BOARD_HEIGHT):
            for x in range(BOARD_WIDTH):
                cell = board[y][x]
                if cell:
                    self.board_canvas.create_rectangle(
                        x * BLOCK_SIZE, y * BLOCK_SIZE,
                        (x + 1) * BLOCK_SIZE, (y + 1) * BLOCK_SIZE,
                        fill=cell, outline="black"
                    )

    def draw_next_tetromino(self, tetromino):
        self.next_canvas.delete("all")
        shape = tetromino.shape
        for y, row in enumerate(shape):
            for x, cell in enumerate(row):
                if cell:
                    self.next_canvas.create_rectangle(
                        x * BLOCK_SIZE, y * BLOCK_SIZE,
                        (x + 1) * BLOCK_SIZE, (y + 1) * BLOCK_SIZE,
                        fill=tetromino.color, outline="black"
                    )

    def display_game_over(self):
        self.board_canvas.create_text(
            BOARD_PIXEL_WIDTH // 2, BOARD_PIXEL_HEIGHT // 2,
            text="GAME OVER", fill="red", font=("Helvetica", 24)
        )

class TetrisGame:
    def __init__(self, gui):
        self.gui = gui
        self.root = gui.root
        # Initialize the game board (a grid with None in empty cells)
        self.board = [[None for _ in range(BOARD_WIDTH)] for _ in range(BOARD_HEIGHT)]
        self.score = 0
        self.current_tetromino = self.generate_new_tetromino()
        self.next_tetromino = self.generate_new_tetromino()
        self.bind_keys()
        self.running = True
        self.update_gui()
        self.schedule_fall()

    def generate_new_tetromino(self):
        key = random.choice(list(TETROMINO_SHAPES.keys()))
        # Make a copy of the shape so that rotations are independent per piece
        shape = [row[:] for row in TETROMINO_SHAPES[key]]
        color = TETROMINO_COLORS[key]
        return Tetromino(key, shape, color)

    def bind_keys(self):
        # Bind keyboard events to control the tetromino
        self.root.bind("<Left>", self.move_left)
        self.root.bind("<Right>", self.move_right)
        self.root.bind("<Up>", self.rotate)
        self.root.bind("<Down>", self.soft_drop)

    def move_left(self, event):
        if self.is_valid_position(self.current_tetromino, dx=-1, dy=0):
            self.current_tetromino.x -= 1
            self.update_gui()

    def move_right(self, event):
        if self.is_valid_position(self.current_tetromino, dx=1, dy=0):
            self.current_tetromino.x += 1
            self.update_gui()

    def soft_drop(self, event):
        if self.is_valid_position(self.current_tetromino, dx=0, dy=1):
            self.current_tetromino.y += 1
        else:
            self.lock_tetromino()
        self.update_gui()

    def rotate(self, event):
        original_shape = [row[:] for row in self.current_tetromino.shape]
        self.current_tetromino.rotate()
        # If new rotation is invalid, revert back
        if not self.is_valid_position(self.current_tetromino, dx=0, dy=0):
            self.current_tetromino.shape = original_shape
        self.update_gui()

    def is_valid_position(self, tetromino, dx, dy):
        new_x = tetromino.x + dx
        new_y = tetromino.y + dy
        for y, row in enumerate(tetromino.shape):
            for x, cell in enumerate(row):
                if cell:
                    board_x = new_x + x
                    board_y = new_y + y
                    # Check boundaries
                    if board_x < 0 or board_x >= BOARD_WIDTH or board_y < 0 or board_y >= BOARD_HEIGHT:
                        return False
                    # Check for collision with locked pieces
                    if board_y >= 0 and self.board[board_y][board_x]:
                        return False
        return True

    def lock_tetromino(self):
        # Add the current tetromino's blocks to the board
        for y, row in enumerate(self.current_tetromino.shape):
            for x, cell in enumerate(row):
                if cell:
                    board_x = self.current_tetromino.x + x
                    board_y = self.current_tetromino.y + y
                    if 0 <= board_y < BOARD_HEIGHT and 0 <= board_x < BOARD_WIDTH:
                        self.board[board_y][board_x] = self.current_tetromino.color
        self.clear_lines()
        # Set the next tetromino as current and generate a new next tetromino
        self.current_tetromino = self.next_tetromino
        self.next_tetromino = self.generate_new_tetromino()
        # Check for game over condition
        if not self.is_valid_position(self.current_tetromino, dx=0, dy=0):
            self.running = False
            self.gui.display_game_over()

    def clear_lines(self):
        # Identify and clear complete horizontal lines
        full_lines = [i for i, row in enumerate(self.board) if all(row)]
        for i in full_lines:
            del self.board[i]
            self.board.insert(0, [None for _ in range(BOARD_WIDTH)])
        if full_lines:
            self.score += 100 * len(full_lines)
            self.gui.update_score(self.score)

    def fall(self):
        if self.running:
            if self.is_valid_position(self.current_tetromino, dx=0, dy=1):
                self.current_tetromino.y += 1
            else:
                self.lock_tetromino()
            self.update_gui()
            self.schedule_fall()

    def schedule_fall(self):
        self.root.after(FALL_INTERVAL, self.fall)

    def update_gui(self):
        # Create a temporary board which includes the locked pieces and the current tetromino's position
        temp_board = [row[:] for row in self.board]
        for y, row in enumerate(self.current_tetromino.shape):
            for x, cell in enumerate(row):
                if cell:
                    board_x = self.current_tetromino.x + x
                    board_y = self.current_tetromino.y + y
                    if 0 <= board_y < BOARD_HEIGHT and 0 <= board_x < BOARD_WIDTH:
                        temp_board[board_y][board_x] = self.current_tetromino.color
        self.gui.draw_board(temp_board)
        self.gui.draw_next_tetromino(self.next_tetromino)

if __name__ == "__main__":
    root = tk.Tk()
    gui = TetrisGUI(root)
    game = TetrisGame(gui)
    root.mainloop()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# d:\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
